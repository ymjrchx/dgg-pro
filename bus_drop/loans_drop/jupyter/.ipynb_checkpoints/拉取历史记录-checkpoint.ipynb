# %%
import numpy as np
import pandas as pd
from pymysql import *
from tqdm import tqdm_notebook as tqdm
host_name = '172.16.0.205'
port_name = 3306
user_name = 'root'
psw = 'root123456'

# %%
def column_from_mysql(database_name,table_name):
    conn=connect(host = host_name,port = port_name,user = user_name, password = psw,charset = 'utf8',database = database_name)
    cs1 = conn.cursor()
    


    count2 = cs1.execute('SHOW FULL FIELDS FROM %s' % table_name)
    result2 = list(cs1.fetchall())
    columns = [column_set[0] for column_set in result2]

    cs1.close()
    conn.close()
    print("查询到%d条数据:" % count2)
    return columns

# %%
columns = column_from_mysql('IBOSS_ MACHINE_LEARNING','customer_record')
columns
# Out:
# 查询到19条数据:
# ['id',
#  'record_id',
#  'business_id',
#  'table_name',
#  'customer_id',
#  'from_user_id',
#  'to_user_id',
#  'create_time',
#  'content',
#  'OpCode',
#  'OpName',
#  'YtCode',
#  'YtName',
#  'creater_id',
#  'phoneNumber',
#  'login_name',
#  'real_name',
#  'followStart',
#  'followEnd']

# %%
import datetime
import time
datetime.date.today()
# Out:
# datetime.date(2019, 4, 22)

# %%
orgin_date = datetime.datetime.strptime("2019-01-01 00:00","%Y-%m-%d %H:%M")
orgin_date
# Out:
# datetime.datetime(2019, 1, 1, 0, 0)

# %%
orgin_date.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2019-01-01 00:00:00'

# %%
orgin_date+datetime.timedelta(days=10)
# Out:
# datetime.datetime(2019, 1, 11, 0, 0)

# %% [markdown]
# # iboss数据获取

# %%
# conn=connect(host = host_name,port = port_name,user = user_name, password = psw,charset = 'utf8',database = 'db_iboss2')
# cs1 = conn.cursor()
# #     sql = "SELECT db_iboss2.uc_customer_record.table_id,db_iboss2.uc_customer_record.create_time,db_iboss2.sys_user_info.login_name,db_iboss2.sys_org_main.name,db_iboss2.cms_tree_book.name FROM db_iboss2.uc_customer_record,db_iboss2.sys_user_info,db_iboss2.sys_org_main,db_iboss2.cms_tree_book WHERE db_iboss2.uc_customer_record.remark_type = db_iboss2.cms_tree_book.code AND db_iboss2.cms_tree_book.name LIKE '%跟进%' AND db_iboss2.cms_tree_book.pcode = 'BUS_OPERATE' AND db_iboss2.sys_user_info.id = db_iboss2.uc_customer_record.from_user_id AND db_iboss2.sys_org_main.id = db_iboss2.sys_user_info.org_id AND db_iboss2.sys_org_main.name LIKE '%融资%' AND "
# #     sql = sql + "db_iboss2.uc_customer_record.create_time > '2019-03-10 00:00:00' And db_iboss2.uc_customer_record.create_time < '2019-03-10 23:59:59';"
# result = []
# columns = ['table_id','create_time','creater_name','remark_type','content']
# for i in tqdm(range(100)):
#     current_date = orgin_date+datetime.timedelta(days=i)
#     current_date = current_date.strftime("%Y-%m-%d")
#     print(current_date)
# #         sql = "SELECT * FROM `uc_customer_record` WHERE create_time>'%s 00:00:00' AND create_time<'%s 23:59:59' AND remark_type='BUS_3';" % (current_date, current_date)
#     sql = "SELECT db_iboss2.uc_customer_record.table_id,db_iboss2.uc_customer_record.create_time,db_iboss2.uc_customer_record.creater_name,db_iboss2.uc_customer_record.remark_type,db_iboss2.uc_customer_record.content FROM db_iboss2.uc_customer_record,(SELECT id,type_code FROM `bus_business` WHERE type_code LIKE 'BUS_YT_DK%%')b WHERE db_iboss2.uc_customer_record.remark_type = 'BUS_3'  AND db_iboss2.uc_customer_record.table_id = b.id AND db_iboss2.uc_customer_record.create_time > '%s 00:00:00' AND db_iboss2.uc_customer_record.create_time < '%s 23:59:59';" % (current_date, current_date)
#     count = cs1.execute(sql)
#     print(count)
#     result = result + [list(column_set) for column_set in list(cs1.fetchall())]
#     if i in [10,30,50,70,99,100,101]:
#         df = pd.DataFrame(result, index=list(range(len(result))), columns=columns)
#         print(df.shape)
#         df.to_csv('跟进记录.csv', mode='a', header=False)
#         del(df)
#         result = []

# cs1.close()
# conn.close()

# %% [markdown]
# # 分配、跟进历史数据--徐志强

# %%
conn=connect(host = host_name,port = port_name,user = user_name, password = psw,charset = 'utf8',database = 'IBOSS_ MACHINE_LEARNING')
cs1 = conn.cursor()
result = []
# columns = ['table_id','create_time','creater_name','remark_type','content']
for i in tqdm(range(365)):
    current_date = orgin_date+datetime.timedelta(days=i)
    current_date = current_date.strftime("%Y-%m-%d")
    print(current_date)
#         sql = "SELECT * FROM `uc_customer_record` WHERE create_time>'%s 00:00:00' AND create_time<'%s 23:59:59' AND remark_type='BUS_3';" % (current_date, current_date)
    sql = "SELECT * FROM customer_record WHERE create_time > '%s 00:00:00' AND create_time < '%s 23:59:59';" % (current_date, current_date)
    count = cs1.execute(sql)
    print(count)
    result = result + [list(column_set) for column_set in list(cs1.fetchall())]
    if i % 30 == 0 or i == 364 or i == 365:
        print(i)
        df = pd.DataFrame(result, index=list(range(len(result))), columns=columns)
        print(df.shape)
        df.to_csv('分配记录.csv', mode='a', header=False)
        del(df)
        result = []

cs1.close()
conn.close()
# Out:
# HBox(children=(IntProgress(value=0, max=365), HTML(value='')))
# 2019-01-01
# 0
# 0
# (0, 19)
# 2019-01-02
# 0
# 2019-01-03
# 0
# 2019-01-04
# 0
# 2019-01-05
# 0
# 2019-01-06
# 0
# 2019-01-07
# 0
# 2019-01-08
# 0
# 2019-01-09
# 0
# 2019-01-10
# 0
# 2019-01-11
# 0
# 2019-01-12
# 0
# 2019-01-13
# 0
# 2019-01-14
# 0
# 2019-01-15
# 0
# 2019-01-16
# 0
# 2019-01-17
# 0
# 2019-01-18
# 0
# 2019-01-19
# 0
# 2019-01-20
# 0
# 2019-01-21
# 0
# 2019-01-22
# 0
# 2019-01-23
# 0
# 2019-01-24
# 0
# 2019-01-25
# 0
# 2019-01-26
# 0
# 2019-01-27
# 0
# 2019-01-28
# 0
# 2019-01-29
# 0
# 2019-01-30
# 0
# 2019-01-31
# 0
# 30
# (0, 19)
# 2019-02-01
# 0
# 2019-02-02
# 0
# 2019-02-03
# 0
# 2019-02-04
# 0
# 2019-02-05
# 0
# 2019-02-06
# 0
# 2019-02-07
# 0
# 2019-02-08
# 0
# 2019-02-09
# 0
# 2019-02-10
# 0
# 2019-02-11
# 0
# 2019-02-12
# 0
# 2019-02-13
# 0
# 2019-02-14
# 0
# 2019-02-15
# 0
# 2019-02-16
# 0
# 2019-02-17
# 0
# 2019-02-18
# 0
# 2019-02-19
# 0
# 2019-02-20
# 0
# 2019-02-21
# 0
# 2019-02-22
# 0
# 2019-02-23
# 0
# 2019-02-24
# 0
# 2019-10-23
# 0
# 2019-10-24
# 0
# 2019-10-25
# 0
# 2019-10-26
# 0
# 2019-10-27
# 0
# 2019-10-28
# 0
# 300
# (0, 19)
# 2019-10-29
# 0
# 2019-10-30
# 0
# 2019-10-31
# 0
# 2019-11-01
# 0
# 2019-11-02
# 0
# 2019-11-03
# 0
# 2019-11-04
# 0
# 2019-11-05
# 0
# 2019-11-06
# 0
# 2019-11-07
# 0
# 2019-11-08
# 0
# 2019-11-09
# 0
# 2019-11-10
# 0
# 2019-11-11
# 0
# 2019-11-12
# 0
# 2019-11-13
# 0
# 2019-11-14
# 0
# 2019-11-15
# 0
# 2019-11-16
# 0
# 2019-11-17
# 0
# 2019-11-18
# 0
# 2019-11-19
# 0
# 2019-11-20
# 0
# 2019-11-21
# 0
# 2019-11-22
# 0
# 2019-11-23
# 0
# 2019-11-24
# 0
# 2019-11-25
# 0
# 2019-11-26
# 0
# 2019-11-27
# 0
# 330
# (0, 19)
# 2019-11-28
# 0
# 2019-11-29
# 0
# 2019-11-30
# 0
# 2019-12-01
# 0
# 2019-12-02
# 0
# 2019-12-03
# 0
# 2019-12-04
# 0
# 2019-12-05
# 0
# 2019-12-06
# 0
# 2019-12-07
# 0
# 2019-12-08
# 0
# 2019-12-09
# 0
# 2019-12-10
# 0
# 2019-12-11
# 0
# 2019-12-12
# 0
# 2019-12-13
# 0
# 2019-12-14
# 0
# 2019-12-15
# 0
# 2019-12-16
# 0
# 2019-12-17
# 0
# 2019-12-18
# 0
# 2019-12-19
# 0
# 2019-12-20
# 0
# 2019-12-21
# 0
# 2019-12-22
# 0
# 2019-12-23
# 0
# 2019-12-24
# 0
# 2019-12-25
# 0
# 2019-12-26
# 0
# 2019-12-27
# 0
# 360
# (0, 19)
# 2019-12-28
# 0
# 2019-12-29
# 0
# 2019-12-30
# 0
# 2019-12-31
# 0
# 364
# (0, 19)

# %% [markdown]
# # 历史通话记录--徐志强

# %%
conn=connect(host = host_name,port = port_name,user = user_name, password = psw,charset = 'utf8',database = 'IBOSS_ MACHINE_LEARNING')
cs1 = conn.cursor()
result = []
# columns = ['table_id','create_time','creater_name','remark_type','content']
for i in tqdm(range(2004)):
   
    
#         sql = "SELECT * FROM `uc_customer_record` WHERE create_time>'%s 00:00:00' AND create_time<'%s 23:59:59' AND remark_type='BUS_3';" % (current_date, current_date)
    sql = "SELECT * FROM `IBOSS_ MACHINE_LEARNING`.`call_record` LIMIT %d, 1000;" % (i * 1000)
    count = cs1.execute(sql)

    result = result + [list(column_set) for column_set in list(cs1.fetchall())]
    if i % 30 == 0 or i == 2003 or i == 2004:
        print(i)
        df = pd.DataFrame(result, index=list(range(len(result))))
        print(df.shape)
        df.to_csv('通话记录.csv', mode='a', header=False)
        del(df)
        result = []

cs1.close()
conn.close()
# Out:
# HBox(children=(IntProgress(value=0, max=2004), HTML(value='')))
# 1000
# 0
# (1000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 30
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 60
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 90
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 120
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 150
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 180
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 210
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 240
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 270
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 300
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 330
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 360
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 390
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 420
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 450
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 480
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 510
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 540
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 570
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 600
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 630
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 660
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 690
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 720
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 750
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 780
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 810
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 840
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 870
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 900
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 930
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 960
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 990
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1020
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1050
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1080
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1110
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1140
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1170
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1200
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1230
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1260
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1290
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1320
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1350
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1380
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1410
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1440
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1470
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1500
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1530
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1560
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1590
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1620
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1650
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1680
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1710
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1740
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1770
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1800
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1830
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1860
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1890
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1920
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1950
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1980
# (30000, 6)
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 38
# 2003
# (22038, 6)

# %%
def table_from_mysql(database_name,table_name):
    conn=connect(host = host_name,port = port_name,user = user_name, password = psw,charset = 'utf8',database = database_name)
    cs1 = conn.cursor()
#     sql = "SELECT db_iboss2.uc_customer_record.table_id,db_iboss2.uc_customer_record.create_time,db_iboss2.sys_user_info.login_name,db_iboss2.sys_org_main.name,db_iboss2.cms_tree_book.name FROM db_iboss2.uc_customer_record,db_iboss2.sys_user_info,db_iboss2.sys_org_main,db_iboss2.cms_tree_book WHERE db_iboss2.uc_customer_record.remark_type = db_iboss2.cms_tree_book.code AND db_iboss2.cms_tree_book.name LIKE '%跟进%' AND db_iboss2.cms_tree_book.pcode = 'BUS_OPERATE' AND db_iboss2.sys_user_info.id = db_iboss2.uc_customer_record.from_user_id AND db_iboss2.sys_org_main.id = db_iboss2.sys_user_info.org_id AND db_iboss2.sys_org_main.name LIKE '%融资%' AND "
#     sql = sql + "db_iboss2.uc_customer_record.create_time > '2019-03-10 00:00:00' And db_iboss2.uc_customer_record.create_time < '2019-03-10 23:59:59';"
    result = []
    columns = ['table_id','create_time','creater_name','remark_type','content']
    for i in tqdm(range(100)):
        current_date = orgin_date+datetime.timedelta(days=i)
        current_date = current_date.strftime("%Y-%m-%d")
        print(current_date)
#         sql = "SELECT * FROM `uc_customer_record` WHERE create_time>'%s 00:00:00' AND create_time<'%s 23:59:59' AND remark_type='BUS_3';" % (current_date, current_date)
        sql = "SELECT db_iboss2.uc_customer_record.table_id,db_iboss2.uc_customer_record.create_time,db_iboss2.uc_customer_record.creater_name,db_iboss2.uc_customer_record.remark_type,db_iboss2.uc_customer_record.content FROM db_iboss2.uc_customer_record,(SELECT id,type_code FROM `bus_business` WHERE type_code LIKE 'BUS_YT_DK%') b WHERE db_iboss2.uc_customer_record.remark_type = 'BUS_3' AND b.type_code  LIKE 'BUS_YT_DK%' AND db_iboss2.uc_customer_record.table_id = b.id AND db_iboss2.uc_customer_record.create_time > '%s 00:00:00' AND db_iboss2.uc_customer_record.create_time < '%s 23:59:59';" % (current_date, current_date)
        count = cs1.execute(sql)
        result = result + [list(column_set) for column_set in list(cs1.fetchall())]
        if i % 100 == 0:
            df = pd.DataFrame(result, index=list(range(len(result))), columns=columns)
            print(df.shape)
            df.to_csv('跟进记录.csv', mode='a', header=False)
            del(df)
            result = []

    cs1.close()
    conn.close()
    print("查询到%d条数据:" % len(result))
    return result

# %%
with codecs.open('vaild_rsdq.txt','w',encoding='utf-8') as train_file:
    for i in tqdm(range(len(df))):
        label = df.iloc[i]['label']
        label = label.strip()
        content = df.iloc[i]['content']
        if isinstance(label,float) or isinstance(content,float):
            continue
        line = label +'\t'+content+'\n'
        train_file.write(line)

# %%
data = table_from_mysql('db_iboss2','uc_customer_record')
print(len(data))
print(data[-1])

# %%
df = pd.DataFrame(data, index=list(range(len(data))), columns=columns)
print(df.shape)
df.tail()

# %%
writer = pd.ExcelWriter('跟单记录1.1-4.8.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()
