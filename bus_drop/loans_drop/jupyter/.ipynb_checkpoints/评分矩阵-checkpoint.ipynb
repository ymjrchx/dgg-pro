# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random
from tqdm import tqdm_notebook as tqdm
import re 

from pymysql import *
host_name = '172.16.0.205'
port_name = 3306
user_name = 'root'
psw = 'root123456'

# %% [markdown]
# # 读取通话记录

# %%
call_df = pd.read_csv('call_record.csv',encoding = 'utf-8',names = ['id','phoneNumber','creater_id','login_name','customer_id','call_duration'])
print(call_df.shape)
print(call_df.info())
call_df.head()
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow_gpu\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (2003038, 6)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2003038 entries, 0 to 22037
# Data columns (total 6 columns):
# id               int64
# phoneNumber      object
# creater_id       int64
# login_name       object
# customer_id      int64
# call_duration    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 107.0+ MB
# None
#    id                       phoneNumber           creater_id login_name  \
# 0   1  009DBED95AEF9383677FC4BF0A74242C  7750899339529601024     100008
# 1   2  009DBED95AEF9383677FC4BF0A74242C  7750899339529601024     100008
# 2   3  00DF0F708C23D4702B814B19DCD1FC5B  7750899339529601024     100008
# 3   4  01AB4CCE0002C1098DCDFD828277551E  7750899339529601024     100008
# 4   5  01AB4CCE0002C1098DCDFD828277551E  7750899339529601024     100008
#
#            customer_id  call_duration
# 0  7798519551527272448            0.0
# 1  7798519551527272448            0.0
# 2  7704841561720360960            0.0
# 3             16198845            0.0
# 4             16198845            0.0

# %% [markdown]
# # 读取历史分配记录、调库记录

# %%
def column_from_mysql(database_name,table_name):
    conn=connect(host = host_name,port = port_name,user = user_name, password = psw,charset = 'utf8',database = database_name)
    cs1 = conn.cursor()
    


    count2 = cs1.execute('SHOW FULL FIELDS FROM %s' % table_name)
    result2 = list(cs1.fetchall())
    columns = [column_set[0] for column_set in result2]

    cs1.close()
    conn.close()
    print("查询到%d条数据:" % count2)
    return columns

columns = column_from_mysql('IBOSS_ MACHINE_LEARNING','customer_record')
columns
# Out:
# 查询到19条数据:
# ['id',
#  'record_id',
#  'business_id',
#  'table_name',
#  'customer_id',
#  'from_user_id',
#  'to_user_id',
#  'create_time',
#  'content',
#  'OpCode',
#  'OpName',
#  'YtCode',
#  'YtName',
#  'creater_id',
#  'phoneNumber',
#  'login_name',
#  'real_name',
#  'followStart',
#  'followEnd']

# %%
allocation_df = pd.read_csv('customer_record.csv',encoding = 'utf-8',names = columns)
print(allocation_df.shape)
print(allocation_df.info())
allocation_df.head()
# Out:
# (3816581, 19)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3816581 entries, 0 to 2053757
# Data columns (total 19 columns):
# id              int64
# record_id       int64
# business_id     int64
# table_name      object
# customer_id     int64
# from_user_id    float64
# to_user_id      float64
# create_time     object
# content         object
# OpCode          object
# OpName          object
# YtCode          object
# YtName          object
# creater_id      int64
# phoneNumber     object
# login_name      object
# real_name       object
# followStart     object
# followEnd       object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 582.4+ MB
# None
#    id            record_id          business_id    table_name  \
# 0   1  7796908554573365248             17995339  bus_business
# 1   2  7796908554925686784  7667130008686829568  bus_business
# 2   3  7796908554937614336  7794068173515440128  bus_business
# 3   4  7796908555747770368  7793601322146652160  bus_business
# 4   5  7796908555763892224  7774622885687336960  bus_business
#
#            customer_id  from_user_id    to_user_id          create_time  \
# 0              3420755           NaN           NaN  2019-03-21 11:14:32
# 1  7667130008707801088           NaN           NaN  2019-03-21 11:14:32
# 2  7794068182228058112           NaN           NaN  2019-03-21 11:14:32
# 3               885775           NaN           NaN  2019-03-21 11:14:33
# 4  7774622886081601536           NaN  7.733555e+18  2019-03-21 11:14:33
#
#          content         OpCode OpName            YtCode   YtName  \
# 0            打电话  CALL_CUSTOMER    打电话    BUS_YT_DK_XYDK     信用贷款
# 1            打电话  CALL_CUSTOMER    打电话  BUS_YT_DK_XYDK_1  信贷小贷（禁）
# 2            打电话  CALL_CUSTOMER    打电话    BUS_YT_DK_XYDK     信用贷款
# 3  无人应答或客户暂时无法接听          BUS_3     跟进    BUS_YT_DK_XYDK     信用贷款
# 4          拾回自跟进       BUS_IN_4  拾回自跟进    BUS_YT_DK_XYDK     信用贷款
#
#             creater_id                       phoneNumber login_name real_name  \
# 0  7794384374728024064  9BB57F2AA23BEAAB6BB303094654ED42     103214       李林娟
# 1  7727417444839636992  17A97B8BD3B41299210F3D4EE7E13C86  923978593       徐江俊
# 2  7786511542414139392  0FEA17714DE3C60A3DF31136ED1E2B97     101624       谢腾腾
# 3  7764014573878435840  0F8755E2E9DD60B7E1CC6D345CBD2B46     100967       钟晓芹
# 4  7733554909571760128  1B0B8527EA843E2E6D2439667578BA87  973547908       钱家伟
#
#            followStart            followEnd
# 0  2019-03-21 11:14:32  2019-03-21 11:25:09
# 1  2019-03-21 11:14:32  2019-04-02 14:15:08
# 2  2019-03-21 11:14:32  2019-03-26 10:12:48
# 3  2019-03-21 11:14:33  2019-03-26 16:25:31
# 4  2019-03-21 11:14:33  2019-03-25 17:19:15

# %%
allocation_df = allocation_df[['customer_id','business_id','login_name','content','followStart','followEnd']]
allocation_df.dropna(inplace=True)
print(allocation_df.shape)
print(allocation_df.info())
allocation_df.head()
# Out:
# (2366629, 6)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2366629 entries, 0 to 2053743
# Data columns (total 6 columns):
# customer_id    int64
# business_id    int64
# login_name     object
# content        object
# followStart    object
# followEnd      object
# dtypes: int64(2), object(4)
# memory usage: 126.4+ MB
# None
#            customer_id          business_id login_name        content  \
# 0              3420755             17995339     103214            打电话
# 1  7667130008707801088  7667130008686829568  923978593            打电话
# 2  7794068182228058112  7794068173515440128     101624            打电话
# 3               885775  7793601322146652160     100967  无人应答或客户暂时无法接听
# 4  7774622886081601536  7774622885687336960  973547908          拾回自跟进
#
#            followStart            followEnd
# 0  2019-03-21 11:14:32  2019-03-21 11:25:09
# 1  2019-03-21 11:14:32  2019-04-02 14:15:08
# 2  2019-03-21 11:14:32  2019-03-26 10:12:48
# 3  2019-03-21 11:14:33  2019-03-26 16:25:31
# 4  2019-03-21 11:14:33  2019-03-25 17:19:15

# %% [markdown]
# # 构造新特征--跟进总天数、分配次数

# %%
import time
allocation_df['follow_days']=pd.to_datetime(allocation_df["followEnd"]) - pd.to_datetime(allocation_df["followStart"])
allocation_df['follow_hour']=pd.to_datetime(allocation_df['follow_days']).dt.hour 
allocation_df['follow_minute']=pd.to_datetime(allocation_df['follow_days']).dt.minute
allocation_df['follow_days']=pd.to_datetime(allocation_df['follow_days']).dt.day 
allocation_df.head()
# Out:
#            customer_id          business_id login_name        content  \
# 0              3420755             17995339     103214            打电话
# 1  7667130008707801088  7667130008686829568  923978593            打电话
# 2  7794068182228058112  7794068173515440128     101624            打电话
# 3               885775  7793601322146652160     100967  无人应答或客户暂时无法接听
# 4  7774622886081601536  7774622885687336960  973547908          拾回自跟进
#
#            followStart            followEnd  follow_days  follow_hour  \
# 0  2019-03-21 11:14:32  2019-03-21 11:25:09            1            0
# 1  2019-03-21 11:14:32  2019-04-02 14:15:08           13            3
# 2  2019-03-21 11:14:32  2019-03-26 10:12:48            5           22
# 3  2019-03-21 11:14:33  2019-03-26 16:25:31            6            5
# 4  2019-03-21 11:14:33  2019-03-25 17:19:15            5            6
#
#    follow_minute
# 0             10
# 1              0
# 2             58
# 3             10
# 4              4

# %% [markdown]
# # 计算通话时长的MinMaxScaler

# %%
call_group = call_df.groupby(['login_name','customer_id']).agg({'call_duration':np.sum}).reset_index()
call_group.dropna(inplace=True)
print(call_group.shape)
print(call_group.info())
call_group.head()
# Out:
# (642464, 3)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 642464 entries, 0 to 642463
# Data columns (total 3 columns):
# login_name       642464 non-null object
# customer_id      642464 non-null int64
# call_duration    642464 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 19.6+ MB
# None
#   login_name  customer_id  call_duration
# 0     100008       138905           17.0
# 1     100008      3676655            0.0
# 2     100008      4182405            0.0
# 3     100008      4268785            0.0
# 4     100008      4367905            0.0

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

minmax_scale = preprocessing.MinMaxScaler().fit(call_group[['call_duration']])
call_group['call_score'] = minmax_scale.transform(call_group[['call_duration']])
call_group.head()
# Out:
#   login_name  customer_id  call_duration  call_score
# 0     100008       138905           17.0    0.000466
# 1     100008      3676655            0.0    0.000000
# 2     100008      4182405            0.0    0.000000
# 3     100008      4268785            0.0    0.000000
# 4     100008      4367905            0.0    0.000000

# %%
minmax_scale = preprocessing.StandardScaler().fit(call_group[['call_duration']])
call_group['call_score'] = minmax_scale.transform(call_group[['call_duration']])
call_group.head()
# Out:
#   login_name  customer_id  call_duration  call_score
# 0     100008       138905           17.0   -0.231503
# 1     100008      3676655            0.0   -0.281563
# 2     100008      4182405            0.0   -0.281563
# 3     100008      4268785            0.0   -0.281563
# 4     100008      4367905            0.0   -0.281563

# %% [markdown]
# # 计算跟进天数的MinMaxScaler

# %%
allocation_group = allocation_df.groupby(['login_name','customer_id']).agg({'business_id':lambda x: x.value_counts().index[0],'content':np.sum,'follow_days':np.sum,'follow_hour':np.sum}).reset_index()
allocation_group.dropna(inplace=True)
print(allocation_group.shape)
print(allocation_group.info())
allocation_group.head()
# Out:
# (775910, 6)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775910 entries, 0 to 775909
# Data columns (total 6 columns):
# login_name     775910 non-null object
# customer_id    775910 non-null int64
# business_id    775910 non-null int64
# content        775910 non-null object
# follow_days    775910 non-null int64
# follow_hour    775910 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 41.4+ MB
# None
#   login_name  customer_id          business_id  \
# 0     100008       138905  7662899713867522048
# 1     100008      3676655  7709527585121767424
# 2     100008      4268785  7747633295609044992
# 3     100008      4367905              5948435
# 4     100008      4738045  7725647421052821504
#
#                                             content  follow_days  follow_hour
# 0                     打电话打电话剔除商机。原因：客户三无客户已经明确表示不需要            4            0
# 1                                               打电话            1            0
# 2                                               打电话            1            0
# 3  打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听           42          132
# 4                                               打电话            1            0

# %%
allocation_group['follow_days'] = allocation_group['follow_days'] + allocation_group['follow_hour'] / 8 # 每天工作8小时
allocation_group.head()
# Out:
#   login_name  customer_id          business_id  \
# 0     100008       138905  7662899713867522048
# 1     100008      3676655  7709527585121767424
# 2     100008      4268785  7747633295609044992
# 3     100008      4367905              5948435
# 4     100008      4738045  7725647421052821504
#
#                                             content  follow_days  follow_hour
# 0                     打电话打电话剔除商机。原因：客户三无客户已经明确表示不需要          4.0            0
# 1                                               打电话          1.0            0
# 2                                               打电话          1.0            0
# 3  打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听         58.5          132
# 4                                               打电话          1.0            0

# %%
minmax_scale = preprocessing.MinMaxScaler().fit(allocation_group[['follow_days']])
allocation_group['follow_score'] = minmax_scale.transform(allocation_group[['follow_days']])
allocation_group.head()
# Out:
#   login_name  customer_id          business_id  \
# 0     100008       138905  7662899713867522048
# 1     100008      3676655  7709527585121767424
# 2     100008      4268785  7747633295609044992
# 3     100008      4367905              5948435
# 4     100008      4738045  7725647421052821504
#
#                                             content  follow_days  follow_hour  \
# 0                     打电话打电话剔除商机。原因：客户三无客户已经明确表示不需要          4.0            0
# 1                                               打电话          1.0            0
# 2                                               打电话          1.0            0
# 3  打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听         58.5          132
# 4                                               打电话          1.0            0
#
#    follow_score
# 0      0.000136
# 1      0.000000
# 2      0.000000
# 3      0.002608
# 4      0.000000

# %%
minmax_scale = preprocessing.StandardScaler().fit(allocation_group[['follow_days']])
allocation_group['follow_score'] = minmax_scale.transform(allocation_group[['follow_days']])
allocation_group.head()
# Out:
#   login_name  customer_id          business_id  \
# 0     100008       138905  7662899713867522048
# 1     100008      3676655  7709527585121767424
# 2     100008      4268785  7747633295609044992
# 3     100008      4367905              5948435
# 4     100008      4738045  7725647421052821504
#
#                                             content  follow_days  follow_hour  \
# 0                     打电话打电话剔除商机。原因：客户三无客户已经明确表示不需要          4.0            0
# 1                                               打电话          1.0            0
# 2                                               打电话          1.0            0
# 3  打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听         58.5          132
# 4                                               打电话          1.0            0
#
#    follow_score
# 0     -0.136506
# 1     -0.161284
# 2     -0.161284
# 3      0.313625
# 4     -0.161284

# %% [markdown]
# # 合并分配记录

# %%
merge_df = pd.merge(call_group, allocation_group, on=['customer_id','login_name'], how = 'right')
print(merge_df.shape)
print(merge_df.info())
merge_df.head()
# Out:
# (775910, 9)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775910 entries, 0 to 775909
# Data columns (total 9 columns):
# login_name       775910 non-null object
# customer_id      775910 non-null int64
# call_duration    4807 non-null float64
# call_score       4807 non-null float64
# business_id      775910 non-null int64
# content          775910 non-null object
# follow_days      775910 non-null float64
# follow_hour      775910 non-null int64
# follow_score     775910 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 59.2+ MB
# None
#   login_name  customer_id  call_duration  call_score          business_id  \
# 0  992133032      2792115          180.0    0.248476              3939595
# 1  992133032      3052625          147.0    0.151302              4283025
# 2  992133032      3117825          387.0    0.858020  7738855340040790016
# 3  992133032      3347755          202.0    0.313258              4658535
# 4  992133032      3839065           69.0   -0.078381              5295335
#
#                                              content  follow_days  \
# 0  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话打电话无人应答或客户暂时...      104.250
# 1                     无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进        1.000
# 2  打电话打电话无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进客户最近需要150万...       89.375
# 3  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进无人应答或客户暂时无法接听 、...       29.625
# 4  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话无人应答或客户暂时无法接...       86.875
#
#    follow_hour  follow_score
# 0           18      0.691486
# 1            0     -0.161284
# 2          115      0.568630
# 3           69      0.075138
# 4           15      0.547982

# %%
merge_df = merge_df[['login_name','business_id','call_duration','follow_days','call_score','follow_score','content']]
print(merge_df.shape)
print(merge_df.info())
merge_df.head()
# Out:
# (775910, 7)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775910 entries, 0 to 775909
# Data columns (total 7 columns):
# login_name       775910 non-null object
# business_id      775910 non-null int64
# call_duration    4807 non-null float64
# follow_days      775910 non-null float64
# call_score       4807 non-null float64
# follow_score     775910 non-null float64
# content          775910 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 47.4+ MB
# None
#   login_name          business_id  call_duration  follow_days  call_score  \
# 0  992133032              3939595          180.0      104.250    0.248476
# 1  992133032              4283025          147.0        1.000    0.151302
# 2  992133032  7738855340040790016          387.0       89.375    0.858020
# 3  992133032              4658535          202.0       29.625    0.313258
# 4  992133032              5295335           69.0       86.875   -0.078381
#
#    follow_score                                            content
# 0      0.691486  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话打电话无人应答或客户暂时...
# 1     -0.161284                     无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进
# 2      0.568630  打电话打电话无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进客户最近需要150万...
# 3      0.075138  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进无人应答或客户暂时无法接听 、...
# 4      0.547982  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话无人应答或客户暂时无法接...

# %% [markdown]
# # 提取备注的工资信息

# %%
merge_df['salary_score'] = 0
for i in tqdm(range(len(merge_df))):
    line = merge_df.iloc[i]['content']
    
    line = line.replace('几千','1000').replace('几万','10001').replace('多','')
    line = line.replace('一','1').replace('两','2').replace('二','2').replace('三','3').replace('四','4').replace('五','5').replace('六','6').replace('七','7').replace('八','8').replace('九','9')
    line = line.replace('百','00').replace('千','000').replace('万','0000').replace('员工资源','资源')
        
    ret = re.findall(r"\d+-\d+",line)
    for result in ret:
        line = line.replace(result,result.split('-')[-1])
    ret = re.findall(r"\d+",line)
    if len(ret):
        ret = re.findall(r".{0,10}\d+[万|千|w|W|K|k]?",line) # 税后工资七八千 流水一个月一两百万
        for result in ret:
            sub_ret = re.findall(r"代发|流水|发现金|税后|收入|打卡|工资",result)
            
            if len(sub_ret) > 0:
                sub_ret = re.findall(r"\d{1,3}多?[w|W|K|k]|\d{1,3}-\d{1,3}多?[w|W|K|k]",result)+re.findall(r"\d+-\d+",result)+re.findall(r"\d+",result)
                if len(sub_ret) > 0:
                    salary = sub_ret[0].split('-')[-1].replace('w','0000').replace('k','000').replace('W','0000').replace('K','000')
                    
                    merge_df.at[i,'salary_score'] = salary
                    print(ret)
                    print('工资:',salary)
                    break
# Out:
# HBox(children=(IntProgress(value=0, max=775910), HTML(value='')))
# ['电话打卡工资 每个月5000', '  没有5险1']
# 工资: 5000
# ['打电话需要30000', ' 打卡工资4000', ' 无5险1']
# 工资: 4000
# ['他，说平安普惠，说了1', '.3分到1.7', '分的利息，周1', '他，说平安普惠，说了1', '.3分到1.7', '分的利息，周1', '他，说平安普惠，说了1', '.3分到1.7', '分的利息，周1', '，感觉他在骗人，他说3', '话打电话打电话户办单4', '份，年交3000', '，交了3年。you1', '台按揭车，刚拱了1', '年，有社保8', '年公积金也8年，工资5000', '有按揭房，用房产拿了400000', '打电话打电话约客户周1', '了年手续费。约客户周1']
# 工资: 8
# ['是她老公有扣碎工资，1', '年，他要跟他老沟通1']
# 工资: 1
# ['打电话客户需要1到20000', '但是没得卡   打卡7000', '左右   加微信yx1017074532', '有时间打电话客户也是6']
# 工资: 7000
# ['打电话客户需要20000', ' 近期   打卡工资3000', '  按揭房   月供1000']
# 工资: 3000
# ['打电话打电话客户需要1', '到20000', '近期    打卡工资2000']
# 工资: 2000
# ['时跟进打电话客户需要20000', '社保公积金   个交700', '    打卡8000']
# 工资: 8000
# ['打电话客户需要30000', ' 在永川上班  打卡3500', '  平安保单  交了2']
# 工资: 3500
# ['电话客户现在在忙  1', '法接听打电话客户需要10000', '近期    打卡工资4000']
# 工资: 4000
# ['打电话在桐庐打卡工资9000']
# 工资: 9000
# ['打电话华先生打卡工资1', '个月100002', '年了，保单年缴6000']
# 工资: 1
# ['产，泡滴滴的，每个月8000', '收入，有负债4.5']
# 工资: 4
# ['林旭994647593', '阳全款房，没证，准备50000', '装修，有1', '个太平洋保单，才缴费1', '年7000', '，没拿到社保卡，工资7000']
# 工资: 7000
# ['林旭994647593', '社保公积金，打卡工资4000', '，有信用卡2张1.60000', '，用了1.30000']
# 工资: 4000
# ['陈国华995451576', '上班 观音桥 全款车100000', ' 有社保 打卡3000']
# 工资: 3000
# ['陈国华995451576', '话铜梁的上班  打卡3000', ' 有社保 按揭房月供2000', ' 6']
# 工资: 3000
# ['何凯微997575611', '时无法接听打电话打卡5000', '，社保3', '年。在桐庐，约了下周1', '电话近期没时间，再跟1']
# 工资: 5000
# ['打电话2000', '打卡，社保去年8']
# 工资: 8
# ['何凯微997575611', '抢了商机打电话打卡4000', '，社保1', '，可能下午过来，报了8']
# 工资: 4000
# ['电话打电话打电话打卡6000', '，社保2年，单边240', '，明天联系1', '要的，微信已跟进，过2']
# 工资: 6000
# ['打卡3500，社保3', '金断交，嘉兴按揭房，4000']
# 工资: 3500
# ['需要100000', '，上班，工资转账8000', '代发不知真假，社保8', '建房车按揭，发票价十0000', '。保险人寿，年缴7000', '，2017买的。这2', '我叫晚上过来客户说看1']
# 工资: 8000
# ['拾回自跟进打电话需要2w', ' 急用 上班 打卡8000', ' 微粒贷额度有8000']
# 工资: 8000
# ['暂时没有这个资金需求100000', '，上班，1.20000', '工资，社保8', '，没有房产证的，全款2', '手车，160000', '，信用卡11张。120000', '。3']
# 工资: 8
# ['联系不上......40000', '个短时间，退休工资，6000000', '平安，有几份，有月缴700', '，缴了3']
# 工资: 6000000
# ['上班，打卡工资，社保3', '个月，微粒贷5000']
# 工资: 3
# ['话打电话客户打卡工资6000']
# 工资: 6000
# ['退休户退休工资2500', '用50000', '，牡丹卡有需要300', '逾期1', '年签单亚联财批款20000']
# 工资: 2500
# ['霍成硕998765615', '客户想贷款买车，打卡20000', '有车险，明天下午过来2', '招商银行，让同事联系1', '下吓唬1', '下，再出新产品吸引1']
# 工资: 20000
# ['户开物流公司的，需要100', '，车。房都没有流水4000000']
# 工资: 4000000
# ['电话客户上班打卡工资4000', '到5000', '费最低的 有给小孩买1', '份保单年缴费2000', '不到 买了6到7']
# 工资: 4000
# ['有需要有公积金 打卡6000', '时间周末联系我  周1']
# 工资: 6000
# ['拾回自跟进打电话需要50000', '，上班打卡6000']
# 工资: 6000
# ['打电话需要100000', '生意有执照法人、收入3', '，年纳税20000，67', '了，房子是儿子的，有3', '全款。下午过过来需要100000', '生意有执照法人、收入3', '，年纳税20000，67', '了，房子是儿子的，有3']
# 工资: 3
# ['郑海根999803972', '话提示客户已关机，第1', '电话打电话打电话需要10000', '   就挂了。脑壳有4', '打电话打电话需要10000', '，在武汉上班打卡4000', '、芝麻分592', '.在汉口。约的下周1', '上午10；30', '电话停机没用了，新号18627029571']
# 工资: 4000
# ['郑海根999803972', '时无法接听打电话需要100000', '，做生意有34', '台挖机收入5--60000', '、盘龙城按揭房首付200000', '中国银行月供3100', ',面积135平，2018', '/5月按揭车月供2400', '裸车110000、2015', '年全款车裸车100000', '自己征信查询超了去年12', '剔除商机。原因：客户3']
# 工资: 5
# ['郑海根999803972', '抢了商机打电话需要10000', '徐东做生意收废品收入5000', '，什么都没有。利息4', '--8', '话打电话打电话打电话2', '剔除商机。原因：客户3']
# 工资: 5000
# ['郑海根999803972', '抢了商机打电话需要30000', '新洲做小吃生意，收入6000', '跟进，约的而明天上去10', '跟进，约的而明天上去10', '剔除商机。原因：客户3']
# 工资: 6000
# ['郑海根999803972', '抢了商机打电话需要10000', '，做餐饮生意收入4', '--50000']
# 工资: 4
# ['郑海根999803972', '抢了商机打电话需要30000', '联系打电话打电话需要30000', '，做生意收入20000', '说话就想嘴里含个吉吉1', '。已发短信打电话需要30000', '，做生意收入20000', '，荆州全款房，2017', '/5月全款车裸车17', '.870000', '因：号码打不通、客户3']
# 工资: 20000
# ['郑海根999803972', '抢了商机打电话需要60000', '。上班打卡6000', '下午再联系打电话需要60000', '。上班打卡6000', '时无法接听打电话需要100000', '以内，黄陂人打卡6000', '、黄陂县城按揭房首付14000080', '平工行月供1000', '，问了利息房抵3--5', '厘、信贷5--8']
# 工资: 6000
# ['郑海根999803972', '抢了商机打电话需要50000', '，2018/7', '月会的武汉上班打卡10000', '户暂时无法接听，下午4']
# 工资: 10000
# ['郑海根999803972', '抢了商机打电话需要500000', '硚口住刚办的营业执照1', '个月，收入100000', '，2017/3', '月平安保单年交10000', '。（2015', '年全款车裸车39.80000', '，郑州按揭房建行月供4100']
# 工资: 100000
# ['郑海根999803972', '抢了商机打电话需要5000', '在司门口做小生意收入1', '.50000', '不了，信用卡当前逾期1', '.50000']
# 工资: 1
# ['郑海根999803972', '商机打电话打电话需要20000', '关山本人上班半年打卡6000', '、社保单边300']
# 工资: 6000
# ['郑海根999803972', '商机打电话打电话需要30000', '公务员区政府上班打卡4500', '，社保有，公积金双边3400']
# 工资: 4500
# ['打电话需要30000', '好  上班每个月收入6k', '   有5险1', '金  交了7、8', '是公积金+商贷 月供2000', '先发地址打电话征信有90']
# 工资: 6000
# ['打电话打电话需要4w', '，发现金 有社保9', '个月单边400']
# 工资: 9
# ['常伟100017', '客户暂时无法接听需要5w', '公积金最低缴费，打卡3000', ' 都江堰，近期需要5w', '公积金最低缴费，打卡3000']
# 工资: 3000
# ['常伟100017', '暂时无法接听客户需要2w', '，有公积金 月交最低200', ' 交了5年，打卡 6000']
# 工资: 5
# ['打电话打电话打卡工资10000', '       公积金2800']
# 工资: 10000
# ['时跟进  打卡工资 5000', '户挂断电话，稍后联系1']
# 工资: 5000
# ['打电话客户需要  100000', '以内 打卡工资3', '个月   3500', '后联系打电话告诉客户3', '户挂断电话，稍后联系1', '户挂断电话，稍后联系1']
# 工资: 3
# ['打电话打卡工资 2']
# 工资: 2
# ['梁伟平100098', '，后期及时跟进打电话10000', '。今明2', '要用了，上班，收入是5000', '有社保，微粒贷额度是1', '.80000', '有使用过，邀请客户这2']
# 工资: 5000
# ['梁伟平100098', '抢了商机打电话10000', '，最近，上班，6000', '，转账工资，社保2']
# 工资: 2
# ['，后期及时跟进打电话10000', '，周转1', '个月，上班收入10000', '剔除商机。原因：客户3']
# 工资: 10000
# ['梁伟平100098', '抢了商机打电话40000', '，这2天，上班，收入8k', '，车按揭，1年，月供2800', '，个人供款，660', '打电话客户说现在安排1', '过来，晚上联系客户试1']
# 工资: 8000
# ['梁伟平100098', '及时跟进打电话打电话50000', '在也可以，上班，收入3800', '，现金，社保15', '剔除商机。原因：客户3', '剔除商机。原因：客户3']
# 工资: 3800
# ['梁伟平100098', '抢了商机打电话想要50000', '建房子用，上班，收入4000', '到5000', '，没有买社保，信用卡1', '.80000', '他什么都没有，客户在3', '边，说过来很远，报了8']
# 工资: 4000
# ['打电话10000', '，上班，收入8000', '剔除商机。原因：客户3']
# 工资: 8000
# ['20000，装修用，1', '个月，上班收入4k', '剔除商机。原因：客户3']
# 工资: 4000
# ['梁伟平100098', '抢了商机打电话20000', '，这2天，上班收入5k', '剔除商机。原因：客户3']
# 工资: 5000
# ['梁伟平100098', '抢了商机打电话20000', '，最近用，上班收入6k', '保累计十几年，报了 1', '在老家清远那边，下周3', '微信打电话客户说下周3']
# 工资: 6000
# ['打电话20000', '做生意，有营业执照，200000', '现金流水，保单年交9000', '，1', '年..客户说今天下午2', '户今天上门了，绿融汇0']
# 工资: 9000
# ['打电话100000', '最近要用，上班，工资5000', '扣税工资，社保公积金2', '年，自己交350', '，报了利息是8.5']
# 工资: 5000
# ['梁伟平100098', '抢了商机打电话80000', '，这几天，上班，收入10000', '，代发招商的，社保3', '年，保单，3年，月缴832', '顺德大良那边，客户说2', '经还了，约了明天下午2', '点过来，利息是8厘-1', '分利息打电话客户说过2']
# 工资: 10000
# ['话老乡 加vx 负债100000', '网贷 房贷 退休工资2500', ' 需要50000']
# 工资: 2500
# ['  发现金  车做了20000']
# 工资: 20000
# [' 无执照 流水每个月1000', '保单无信用卡 芝麻分63']
# 工资: 1000
# ['上班 公积金单边350', '  打卡4000']
# 工资: 4000
# ['打电话做生意营业执照4', '企业法人，对公流水有10001', '单有的断缴了，信用卡13W', '用完了，平安半年缴1', '上在回个电话详细了解1']
# 工资: 10001
# ['夏宗祥100289', '打电话客户现在在忙十1', '打电话打电话投资需要5W', '，最近需要，上班代发6000', '好几年了，车子按揭车1', '年月供2000', '+，没房，保单缴了2']
# 工资: 6000
# ['夏宗祥100289', '了商机打电话装修需要10W', '，这1', '就需要用到，上班代发5000', '+，社保公积金1', '车没房没保单，信用卡2000']
# 工资: 5000
# ['夏宗祥100289', '了商机打电话装修需要5W', '，做生意有营业执照，34', '年了，对私流水30W', '每月，车全款14年15W', '，老家按揭房按揭1', '年月3000', '块，平安年缴15W56', '电话提醒客户添加微信11']
# 工资: 300000
# ['夏宗祥100289', '锌接的电话，上班代发4000', '没车有自建房，信用卡1W', '用了10', '他贷款，邀约明天下午2']
# 工资: 4000
# ['微信，了解到客户代发1000']
# 工资: 1000
# ['需要50000', '，上班转账工资5000', '，社保2', '无贷款，暂约明天下午3']
# 工资: 5000
# ['接听在广州上班，需要40000', '，工资5000，社保3', '跟保单，有车，微粒贷6000', '，网贷20000']
# 工资: 5000
# ['时无法接听打电话需要30000', '，上班转账工资6000', '，社保11', '年，无房，车子月供2700', '，供了半年，信用卡20000']
# 工资: 6000
# ['邓汝辉100316', '抢了商机需要30000', '，做生意营业执照3', '个月，流水30000', '子按揭不到半年，月供2000']
# 工资: 30000
# ['打电话客户想需要100000', ' 12', '上门时间。打电话社保2', '年  工资10000', '。。  8000']
# 工资: 10000
# ['打卡工资 8000']
# 工资: 8000
# ['户在从化上班，月收入9k', '保公积金，本单位上班15']
# 工资: 9000
# ['客户暂时无法接听需要5w', '，打卡月收入5000', '，有社保，4', '资产，没保单，微粒贷3500', '，约下午4']
# 工资: 5000
# ['需要3w，上班收入6', '.7k', '，打农行，本单位不到1', '，微粒贷没有，芝麻分587', '，约今天上午11']
# 工资: 30000
# ['打电话需要20w', '，营业执照没有，流水8', '.9w', '，微粒贷没有，芝麻分670', '，约下午2']
# 工资: 8
# ['客户暂时无法接听需要10w', '，花都国企上班收入8k', '有社保公积金，本单位8', '年，公积金基数8300']
# 工资: 8000
# ['打电话公积金498 3', '年 打卡7K 3年 4', '月1']
# 工资: 7000
# ['时跟进打电话工资打卡5K', ' 3年 农行保单2', '年 3K']
# 工资: 5000
# ['打电话工资打卡 7k', ' 5', '  其余无。。。。。1', '打电话工资打卡 7k', ' 5', '年  加微信 下周1']
# 工资: 7000
# [' 工作手机联系 打卡6K', ' 1']
# 工资: 6000
# ['魏刚100406', '了商机打电话公积金交4', '具体少不清楚  打卡5K']
# 工资: 5000
# ['魏刚100406', '机打电话打电话公积金1200', ' 10年 打卡14K', ' 名下保单月缴2年 4001', '月 名下按揭房1K 3', '年  需要100000', '点更好  1', '打电话打电话公积金1200', ' 10年 打卡14K', ' 名下保单月缴2年 4001', '月 名下按揭房1K 3', '年 需要100000']
# 工资: 14000
# ['魏刚100406', '了商机打电话工资打卡3K', '  1年 需要1500', '打工的   工资打卡3K', ' 1年 需要1500', ' 最2000']
# 工资: 3000
# ['魏刚100406', '抢了商机打电话公积金700', ' 4个月   打卡4K', '  4', '话打电话打电话公积金700', ' 4个月 打卡4K 4', '个月  加微信 4.4']
# 工资: 4000
# ['魏刚100406', '抢了商机打电话公积金400', ' 1年 打卡6K 1', '年 康泰3年 年缴3K', '   1', '打电话打电话公积金400', ' 1年 打卡6K 1', '年 康泰3年 年缴3K', '    4.4']
# 工资: 6000
# ['打电话公积金300', ' 不到半年 打卡5K', ' 不到半年 4.10']
# 工资: 5000
# ['打电话公积金10', '交少不清楚 工资打卡5K', ' 名下有3笔小贷 周1', '到周6', '末休息 已加微信 周56']
# 工资: 5000
# ['话客户在开车  过个10', '房子，工资现金 需要30000']
# 工资: 30000
# ['打电话公积金1400', '  4', '个月  信用卡之前有8', '个月逾期  打卡20000', '  1', '年 名下有辆按揭车 16661', '了。。。打电话公积金1400', ' 4', '个月 信用卡之前有8', '个月逾期 打卡20000', ' 1', '年 名下有辆按揭车 16661']
# 工资: 20000
# ['打电话公积金6', '体交少不清楚  打卡4K', ' 6', '月。。。打电话公积金6', '具体交少不清楚 打卡4K', ' 6']
# 工资: 4000
# ['魏刚100406', '电话餐饮店的 公积金1200', '元 不到半年 打卡7K', ' 2年 需要10000']
# 工资: 7000
# ['司，没车没房有个买了5', '年年交600', '的保单，现金工资每月8000']
# 工资: 8000
# ['街，有套按揭房，月供2000', '，买了2年，全款车70000', '。上班现金工资5000']
# 工资: 5000
# ['：号码打不通客户打卡6000', '，需要100000']
# 工资: 6000
# ['听打电话告诉客户能做5', '.60000', '，流水都没有，不bz1']
# 工资: 1
# ['在京东上班，打卡工资10000', '给客户说保底可以贷到100000']
# 工资: 10000
# ['发型师，打卡工资大概8000', '，微粒贷额度1000']
# 工资: 8000
# ['兼职，工资转账，需要50000', '午上门打电话名下只有1', '辆车，16']
# 工资: 50000
# ['打电话需要10000', ' 最近   打卡底薪2200', '，加提成在4000']
# 工资: 2200
# ['王大川100639', '抢了商机打电话150000', ' 流水20000', '  做家装的   在0000', '要确认金额 富登出了100000', ' 征信白户 亚联财 0000']
# 工资: 20000
# ['王大川100639', '商机打电话打电话需要20000', '黄泥磅上班 打卡工资10000', '。有保单年交5000', ' 交了2']
# 工资: 10000
# ['打电话渝北上班 工资7000', '金   有个车子全款100000', ' 8']
# 工资: 7000
# ['打电话客户需要50000', ' 有工资7000', '接听打电话客户说考虑1']
# 工资: 7000
# ['冯芸芸介绍 客户需要400000', ' 不着急  打卡7000']
# 工资: 7000
# ['行卡，工资扣税，工资3000', '，社保13年，信用卡100002', '，无保单，有房全款，800001', '方，420', '方，无微粒贷。1']
# 工资: 3000
# ['浦发银行审批通过250000', '///行审批通过110000', '，利息0.5%，12', '有限广州分公司，上班2', '年，代发10000', '，公积金基数12169', '，花都按揭房，12', '年供的，月供3500', '，中信银行150000', '，月供5000', '，信用卡每月还4000']
# 工资: 10000
# ['客户已签50000', '收 客户上班 在佛山3', '水那边 司机 网站5000', '无社保公积金 信用卡3000', ' 招商的 用了3', '个月 综合利息1.2', '.3% 前置3', '厘 实际还款1.2.0', '% 3年  ，4月16', '排恒昌诺远，但是客户2', '月没有发工资，客户说2', '月1', '尝试进件。审核通过:4', '月19', '审中，还没有出结果。4', '月20', '号，诺远审批通过3.50000', '，利息2.38%，18', '期，约了周1']
# 工资: 2
# ['上班发现金10000', '，信用卡4张 50000', '，微粒贷5000', '，芝麻分614. 说1', '月份来过没办下来。15', '年的车，8.80000', '，需要50000', '车已经在别的地方做了1', '押50000', '在说死押都可以，报了3']
# 工资: 10000
# ['客户需要30000', '，白云上班打卡6000', '、公积金，社保断过，17', '年11', '月续上，信用卡额度5000', '嫌麻烦， 有问利息，1', '我说最低可以操作信贷8']
# 工资: 6000
# ['1、代发工资4k', '左右，有社保2']
# 工资: 4000
# ['上班，代发9000', '社保公积金都有购买，2']
# 工资: 9000
# ['需要100000', '，广州上班，打卡工资8000', '，公积金个缴700', '，缴存比例10', '%，上班10', '清远有个按揭房，按揭6', '年，月供2000', '，没车保单，利息报了5', '厘左右，费用2.6', '个点，4，5', '年前信用卡逾期过，90', '了工商银行的装修贷，4', '.5', '厘的利息，中介前置了6', '，以后有需要再联系。7', '.27', '款:客户建设银行放款9', '.310000']
# 工资: 8000
# ['需要200000', '需要怕办不下来，上班3', '年现金工资8000', '，信用卡有56', '张，支付宝699', '，微粒贷100006', '，报了8']
# 工资: 8000
# ['客户需要200000', '生意 有营业执照 (8', '年）月收入50000', ' 自己在04', '年买的全款车 去年11', '月 给妻子买了1', '辆按揭车300000', ' 自己 月供4000', '+爱人 2000 2012', '年买的平安保险 年缴8000', ' 微粒贷额度610001', '但是都用完了 月还款100000', ' 负债1000000']
# 工资: 50000
# ['客户广州本地人，广州1', '客车装修厂上班，代发5000', '，公积金基数5489', '，微粒贷6500、8', '月5号做了1', '笔建行，建行审批通过5', '.510000，利息0', '.52%，12']
# 工资: 5000
# ['需要100000', '，做生意无执照，流水10001', '家人买也有自己的，有3', '份保单，自己名下1', '份，买了好几年，年缴1000', '块，保单有贷过款，1', '年前贷的，在清远有1', '按揭房，在清远，还有3', '年就供完。房产面积120']
# 工资: 10001
# ['1、客户需要 3~5w', '，近期用钱。2', '、做生意的执照2', '年，月流水300w', '，年开票300w', '从化城中村有自己建房2', '栋价值800w', '来。没有微粒贷信用卡5k', '额度，小花钱包3k', '得麻烦，上门需要考虑1']
# 工资: 3000000
# ['客户韶关的，现金工资7000', '有全款房在韶关，市值200000', '，芝麻分570']
# 工资: 7000
# ['打电话客户再出差，周1', '听打电话客户代发工资6000']
# 工资: 6000
# ['需要300000', '上班，代发的，月收入20000', '，税后的。个人公积金2700', '已经十几年了。名下有2', '套房子，1套全款，1', '套按揭，供了3', '年了，月供7600', '的。在增城的， 报了5', '厘2的利息，3', '贷，近期办理不了，说0', '.55', '息就接受不了了。报了1', '个装修贷，利息0.328', ' 等额本息，2.5', '的手续费，0.3']
# 工资: 20000
# ['需要60000', '，做生意的，执照20', '不是本人。流水账每月300000', '买了平安的保险，买了5', '年，年缴费是6000', '，在平安有贷了1', '卡。在龙洞的 平时是6', '上可以过来办理 先发1']
# 工资: 300000
# ['打电话社保5年，工资5000', '，公积金个人缴100', '，这几天内要10000']
# 工资: 5
# ['班，发现金，微粒贷有2000']
# 工资: 2000
# ['金融，半年执照，流水10001', '，在佛山按揭6000', '，按揭3', '有社保没缴了，信用卡300000', '，微粒贷80000', '房子贷，现在无业，要300000']
# 工资: 10001
# ['跟进暂时无人接听 要150000', '这段时间要，上班2', '年，现金工资，6000', '，有老家按揭房，月供2000', '，供5~6', '己的卡在供的，约客户12', '月28']
# 工资: 6000
# ['做生意，执照10', '年，流水10001', '，无房无车，人寿10', '年年缴1000', '，太平洋几年，年缴1000', '，信用卡200002']
# 工资: 10001
# ['跟进上班，工地，工资50008', '无公积金，平安保单，7', '年了，年缴1800', '的，信用卡6', '月份办的，624']
# 工资: 50008
# ['做生意，执照2', '年，流水十10001', '房无车，平安保单年缴4900', '，买了30', '年的，信用卡6000', '，无微粒贷，520']
# 工资: 10001
# ['客户暂时无法接听需要500000', '，中远海运集团，代发1w', '8', '左右，有社保。公积金3000', '左右。上班30年，57', '不要退休了。平安普惠200000', '，3年等额，浦发250000', '，分5年。邮政的50000', '装修贷，分3', '年 还剩下十10001', '有全款房，越秀区的，121', '方。夫妻共有的，600001', '方，05年建的，17', '没有车子 汕头南澳有1', '套全款商品房，价值1000000', '，1套公寓 价值1000000', '。谈了8.5']
# 工资: 10000
# [' （上班。物业管理，6000', '，银行代发，社保3', '年，公积金200', '业保单公司买，信用卡100000', '，微粒贷无，要30000', '，猎德，加v沟通，周6']
# 工资: 3
# ['，花店，做零售，执照18', '年4', '办的，流水微信较，月10000', '，社保20']
# 工资: 10000
# ['州，搞工程的，收入年200000', '，准备买社保，信用卡30000', '，微粒贷20000']
# 工资: 200000
# ['大都会保单，8', '年了，年缴4000', '，上班，文员，40005', '工资，银行代发，社保08', '年，在公司8']
# 工资: 08
# ['上班，教育行业，工资10000', '左右，银行代发，社保4', '工资，无保单，信用卡30000']
# 工资: 10000
# ['打电话上班工资8000', '社保无公积金，信用卡10000', '就不想要了，微信沟通1']
# 工资: 8000
# ['房产，按揭房，天河，4000000', '，供了9年，月供5000', '，做生意，贸易，执照3', '年，流水私账，流水十10001', '单，有车全款，裸车价500000']
# 工资: 10001
# ['打电话00', '停服务，上班代发工资9000', '左右。上班时间3', '代发，需要资金，上班3', '年了，公积金个人缴纳260']
# 工资: 9000
# ['话上班，街道的，工资5000', '，公积金不记得，社保4', '年，信用卡100006', '无微粒贷，无房无车，573910825']
# 工资: 5000
# ['老家江西按揭房，月供3600', '，供了4', '行，在商场保安，工资4600', '，银行代发，社保11', '不要挂断了，再打确认1', '老家江西按揭房，月供3600', '，供了4', '行，在商场保安，工资4600', '，银行代发，社保11']
# 工资: 4600
# ['餐厅，执照几年，流水80000', '，车全款，裸车价90000', '，13', '信用卡无，微粒贷无，500', '行，以前用执照贷过十0000']
# 工资: 80000
# ['接听打电话上班，工资10000', '，银行代发，社保1', '年，公积金700', '，无保单，信用卡400005', '山，资金不急，wix765051239']
# 工资: 10000
# ['上班，广告行业助理，4000', '行代发，无扣税，社保1', '年，公积金210', '，保单外资的，2017', '年10月买的，年缴4000', '，无房无车，信用卡30000', '历，海珠区家具，超过1', '贷款，通过了微信沟通1']
# 工资: 1
# ['打电话上班，7000', '工资，银行代发，社保10', '年以上，公积金500', '，无保单，老家4', '川房全款，价值300000', '款，东莞牌照，裸车价120000', '，18', '沟通。客户有需求，这2', '时间，客户在南沙，周5', '再打个回访电话确认周5']
# 工资: 10
# ['打电话上班，工资10000', '金，保单断了，信用卡30005', '，有车全款，裸车价70000', '，17']
# 工资: 10000
# ['古倩鑫100682', '答或客户暂时无法接听1', '聘人员），公积金基数5900', '，上班23', '年，建行代发5900', '，实际工资200001', '（除代发剩余发现金）2', '人，非全日制大专学历3', '.有车全款2015', '年买的裸车价460000', '，广州牌照，2018', '年5', '车贷抵押绿本，抵押了300000', '，月供10000 4', '.信用卡总额的40000', '，刷了1半，微粒贷2017', '年7月开始用现额度有600001', '无保单，支付宝少用，590', '芝麻分 5', '拉征信看结果再判断 6', '.建行去年7', '月有点了点贷40000', '银行今天点了没额度 7', '.费用谈了13%,3', '负债高打压谈了总费用13', '用+手续费）负债差不500000', '小贷都能做，可以接受1', '.1.8']
# 工资: 5900
# ['古倩鑫100682', '户暂时无法接听打电话200000', ',自己没房，上班工资8000', '，4', '年，银行代发，社保4', '年，公积金基数5300', '，平安保单，买了3', '年，年缴买断，5', '，客户现在海南，下周2', '回来广州，约下周3', '下午3', '游，回来再跟进客户周2', '话问了手续费少，说了3', '个点要考虑1', '话打不通，微信跟进看1']
# 工资: 8000
# ['古倩鑫100682', '抢了商机打电话30000', '，上班，工资8000', '，16', '年，代发，扣税，社保16', '年，公积金个人缴60000', '不是中介，当前有逾期3000', '未还逾期十几天，只要10000']
# 工资: 8000
# ['接听打电话上班，工资6000', '剔除商机。原因：客户3']
# 工资: 6000
# ['古倩鑫100682', '户暂时无法接听打电话50000', '店，十年执照，月流水100000', '，有太平洋保单，买了16', '年，年缴2500', '车，无微粒贷，信用卡20000', '，番禺，约明天早上十1', '现在在忙，明天早上十1']
# 工资: 100000
# ['古倩鑫100682', '开小工厂，无执照，做1', '年了，流水月10000', '，对私，平安保单，4000000', '，17', '区嘉禾望岗，客户只要20000', '左右，分6']
# 工资: 10000
# ['古倩鑫100682', '客户暂时无法接听要借20000', '子的教育基金，上班，5000', '工资，代发，社保10', '单，信用卡无，微粒贷6500', '无房，、客户在佛山，5']
# 工资: 10
# ['古倩鑫100682', '接听打电话装修，工资6000', '无公积金，无保单，要30000', '贷，无房无车，芝麻分600', '剔除商机。原因：客户3']
# 工资: 6000
# ['古倩鑫100682', '答或客户暂时无法接听50000', '，上班，开车的，1000', '工资，银行4000', '发，剩下发现金，社保2', '公积金无，人寿保单，2', '年，年缴5000', '在东莞的，问利息报了7']
# 工资: 4000
# ['古倩鑫100682', '暂时无法接听打电话要10000', '，珠海上班，4000', '工资，发银行卡，社保2']
# 工资: 2
# ['古倩鑫100682', '照别人的，个人月收入30000', '，有房河南按揭，供了3', '年，月供4000', '揭，河南牌照，裸车价20', '，17年买的，只要30000', '想过来挂断了电话，第1', '再打，无人接打电话这2']
# 工资: 30000
# ['古倩鑫100682', '无法接听打电话上班，5000', '工资，银行代发，社保1', '年，公积金1000', '个人缴1300', '用卡停了，无房无车，10000', '微粒贷无，白云区只要10000', '时间过来，明天再确认1', '下时间，微信号GH520', 'L ，微信跟进1', '出差，今晚回来，平时6', '点下班的，5', '没时间过来，明天早上10', '点再打电话确定1']
# 工资: 1
# ['古倩鑫100682', '商机打电话装修，工资8000', '积金，意外险，信用卡30000', '，微粒贷100005', '，和妹妹共有，现价值1000000', '，荔湾，要30000', '门明天上门过来，只要20000']
# 工资: 8000
# ['打电话打电话20000', '，上班，8000', '银行代发，工商，上班2', '年，社保2', '，全款，车子，全款，110000', '车价，买了4', '年了，河南牌照，609', '分，天河区，庞先生，15137374071', '天看早上还是下午方便1', '飞机的客户，下午下班4', ',5']
# 工资: 2
# ['现单位上班6', '年，基本工资4000', '，银行代发工资3000', '左右，工行代发，5险1', '金扣600', '，有友邦保单，年缴1000', '道放哪里，信用卡额度10000', '，用了几年，微粒贷20000']
# 工资: 4000
# ['话打电话上班，现单位7', '年，工资9000', '社保无公积金，信用卡10001', '，微粒贷2000', '无房无车，在增城，要100000']
# 工资: 9000
# ['无法接听工作手机拨打1', '听打电话上班，现单位1', '年，工资6000', '单，无房无车，信用卡20000', '，微粒贷无，芝麻分620', '，花都区，微信号15999905768', '，考虑1']
# 工资: 6000
# ['暂时无法接听打电话要30000', '，现单位上班3,4', '年，会展保安，8000', '行代发，有扣税，社保10', '个人缴不清楚，好像是210', ',，无保单，信用卡50000', '，微粒贷3000', '始经常用网贷，芝麻分652']
# 工资: 10
# ['打电话打电话要30000', '，上班，工资7000', '考虑要续缴，换了工作2', '个月，无保单，信用卡200006', '无，无房无车，芝麻分656', '，网贷国力花10000', '剔除商机。原因：客户3']
# 工资: 7000
# ['打电话打电话只要要100005', '执照是老公的，月流水10001', '对私，平安保单，买了2', '年，有3份，总年缴100003']
# 工资: 10001
# ['，电话提醒正忙打电话200000', '自己开服装，执照刚办1', '个月，月流水40000', '地，别墅，南沙区，前2', '年，253方，现价值2700000', '，统1', '揭，广西牌照，裸车价200000', '，18年9', '老公名下，平安保单，18', '年7', '份，给子女买的，年缴30006', '，信用卡10000', '，微粒贷2000', '有保单，平安保单，有4', '年，年缴4000', '上班，运输行业，工资8000', '，有社保。费用报了1', '%-3', '%，先回去跟老公商量1']
# 工资: 40000
# ['打电话打电话打电话要50000', '班，现单位好年，工资7000', '建筑，无保单，信用卡20000', '，微粒贷700008', '房有车，按揭，裸车价800008', ',16', '，湖南牌照，白云区，1']
# 工资: 7000
# ['古倩鑫100682', '暂时无法接听打电话要20000', '，上班，现单位6', '，工资6000', '卡工资，没扣税，社保6', '年，公积金个人缴102', '，平安保单，买了快5', '年了，年缴1000', '，微粒贷无。点网贷2', ',3']
# 工资: 6000
# ['打卡工资30005到5000', ' 需要3到50000', '元 资金周转 56', '，稍后联系 打卡工资30005', '到5000 需要3到50000', '元 资金周转 56', '，稍后联系 打卡工资30005', '到5000 需要3到50000', '元 资金周转 56']
# 工资: 30005
# ['信再次上门 打卡工资1000']
# 工资: 1000
# ['宛婷100817', '了商机打电话客户需要3000', '班工资打银行卡，社保1', '个月1200', '块钱，单位上班6', '年了，6', '加班没有时间，说着这2']
# 工资: 1
# ['水     客户说要200000', '有做生意，说税后工资10000', '，设班每个月交600', '伙做生意；保单平安的5', '年，年交3000', '人在江门，说只有星期6']
# 工资: 10000
# ['宛婷100817', '在通话中客户上班工资6K']
# 工资: 6000
# ['宛婷100817', '了商机打电话客户需要100000', '班现金工资，社保个人1', '直在交，年交6000', '，交了10', '经常换工作，房子全款600000']
# 工资: 1
# ['宛婷100817', '暂时无法接听客户需要5000K', '，上班税后5000', '，单位上班1', '，暂时邀约在明天上午9']
# 工资: 5000
# ['客户需要20000', '，上班现金工资，1', '个月8K，社保1个月100', '，单位上班2', '年，全款车，裸车价150000']
# 工资: 1
# ['宛婷100817', '法接听打电话客户需要5K', '上班税后5000', '积金都有交，单位上班2', '看看，暂时邀约在下午3']
# 工资: 5000
# ['需要100000', '近需要用，做生意执照8', '年，流水100000', '借了几笔，信用卡刷了200000', '心办理不下来，说考虑1']
# 工资: 100000
# ['宛婷100817', '法接听打电话客户需要30000', '最近用，上班现金工资5800']
# 工资: 5800
# ['，近期用到，上班代发5000', '左右，社保买了8', '年，按揭房月供1300', '供了5', '年没车，平安保单4', '份年缴年缴20000', '，信用卡总额度1010001', '，最长1张6', '年，有微粒贷，1']
# 工资: 5000
# ['上班代发税后6000', '，社保和公积金买了4', '房车，太平洋保单年缴70002']
# 工资: 6000
# ['打电话上班代发税后5800', '+，社保买了15', '，没保单，信用卡额度3000']
# 工资: 5800
# ['上班代发4000', '+，社保公积金买了1', '邀约周天上门上班代发4000', '+，社保公积金买了1']
# 工资: 4000
# ['理分配商机给【周健锌100847', '打电话上班，代发税后6000', '，社保买了2']
# 工资: 6000
# ['上班代发税后1W5', '，刚来这家公司3', '在茶山，邀约明天下午2']
# 工资: 10000
# ['周健锌100847', '暂时无法接听上班代发5000', '左右，社保买了5']
# 工资: 5000
# ['周健锌100847', '于消费，上班代发税后6000', '于消费，上班代发税后6000']
# 工资: 6000
# ['周健锌100847', '客户暂时无法接听需要20000', '班发现金，全款车买了2', '年5W，邀约明天下午2']
# 工资: 2
# ['周健锌100847', '抢了商机打电话要下周1', '上门，请不了假，代发5000']
# 工资: 5000
# ['周健锌100847', '客户暂时无法接听需要100000', '发现金，人寿保单年缴2000', '+买了2', '在虎门，邀约明天上午10', '点上门打电话需要100000', '发现金，人寿保单年缴2000', '+买了2', '在虎门，邀约明天上午10']
# 工资: 2000
# ['需要20000', '左右，上班代发税后7000', '+，社保公积金买了7', '在沙田，邀约明天下午2']
# 工资: 7000
# ['话客户有烟酒店，流水20000', '，执照下来2', '年了，信用卡2000', '度客户反反复复就那么1']
# 工资: 20000
# ['在外企上班，打卡工资120000', '，工作了35']
# 工资: 120000
# ['李玲100870', '石家庄上班，打卡工资2000', '有社保公积金，上班有1', '年了，信用卡额度15000', '，用1年了。约客户周1']
# 工资: 2000
# ['李玲100870', '电话客户打卡工资每月5000', '，需要10000']
# 工资: 5000
# ['李玲100870', '营业半年了，流水不到50000']
# 工资: 50000
# ['话，工资是现金发放，3', '没有保单，信用卡使用1', '年左右，额度30000', '，有平安普惠的贷款30000']
# 工资: 3
# ['李玲100870', '货，不方便接听电话，1', '，法人是本人，月流水50000', '以上，有商铺，2010', '年买的，有房本，400000']
# 工资: 50000
# ['李玲100870', '上班，，打卡工资每月5000', '左右，没有5险1']
# 工资: 5000
# ['家庄，上班，打卡工资100005', '跟客户介绍公积金贷款56']
# 工资: 100005
# ['有执照，流水每月几十0000', '房车，太平洋保险交了2', '次了，年交2800', '，，信用卡额度20000']
# 工资: 0000
# ['李玲100870', '了商机打电话客户需要5000', '右，自己盖的房，月薪5000', '，打卡，信用卡6000', '自己交的保险，芝麻分600']
# 工资: 6000
# ['李玲100870', '题，打不出去电话客户1', '卡，网贷秒拒，有车，17', '年6月买的，裸车价84800', '，月供1500', '，有信用卡，额度11000', '，有店，去年6', '开的，是法人，月流水67000']
# 工资: 67000
# ['李玲100870', '太平洋保险，交了不到1', '年，年交5000', '吗，打卡工资23000', '，好几年了，没有5险1', '金，信用卡额度10000']
# 工资: 23000
# ['李旭飞100913', '。。。。。。。。。要30000', '块   转账工资1.20000', '，有部车160000', '  开了4', '     报了可以做200000', '，利息3.2', ' ，挂电话，，，，第2']
# 工资: 1
# ['李旭飞100913', '，，，，，，，，，要300000', '   上班2', '年   代发7000', '  有5险1', '金，    1', '   少   我报了2', '.3到3.5', '里     先息5', '     他说要对比1', '今晚回访 不说不用过2', '。。。。。。。。。要300000', ' 上班2年 代发7000', ' 有5险1金， 1', '直问利息 少 我报了2', '.3到3.5里 先息5', '厘 他说要对比1', '今晚回访 不说不用过2']
# 工资: 7000
# ['李旭飞100913', '.........要5', '到10', '业执照  也上班代发10000', '条件都是父母的，考虑1']
# 工资: 10000
# ['李旭飞100913', '意向，后期及时跟进要20000', '，  代发7000', '半年不到   有社保1', '   越来星期天下午3']
# 工资: 7000
# ['电话打电话打电话需要50000', '，有社保，工资6000', '，工作4年，1']
# 工资: 6000
# ['打电话1', '积金代发工资这些，说2', '月份点过很网贷，3']
# 工资: 2
# ['电话客户上班现金工资5000', '，无房无车，平安保单3700', '，去年12', '份买的，其他无，需要50000']
# 工资: 5000
# ['答或客户暂时无法接听1', '客户上班代发5000', '保公积金，公司+个人690', '/月，建行80000', '，其他负债加起来200000']
# 工资: 5000
# ['林志强100935', '电话客户上班打卡工资6000', '，有社保，信用卡8000']
# 工资: 6000
# ['李超100945', '抢了商机打电话客户要60000', '，有车按揭1', '，还有半年还清，裸车240000', '，有打卡工资4000', '分现金，总月收入大概6', ' 7000，有1', '户在沙区，暂时约的周1', '最近要出差，不确定周1', '间过来，先加微信，周1', '微信，还没通过我，周1']
# 工资: 4000
# ['信息打电话打电话夫妻2', '征信负债都很高  有1', '个营业执照 有7', '年的时间了  2019', '.3.20号更新了1', '不稳定 客户每个月有2000', '夫还在事业单位上班 1', '个月的打卡工资10000', ' 征信上有体现有2', '名字是不是本人的 有1', '  在农业银行抵押了500000', ' 才还1个月 有1', '按揭车  按揭金额十10001', '跟她联系过 只收取她3', '用  当天就可以下款1000000']
# 工资: 10000
# ['刘静100953', '抢了商机打电话200000', '重庆鸳鸯  打卡工资3000', ' （受益人）保单年交5000', '  按揭房9', '年 按揭款1500']
# 工资: 3000
# ['刘静100953', '抢了商机打电话微粒贷5000', '.人在沙坪坝芝麻分650', '.做教校兼职收入3000', '左右有流水。客户下周1', '上午十1']
# 工资: 3000
# ['刘静100953', '抢了商机打电话150000', '做生意 月收入大概在30000', ' 全款房500000', ' 买了56', '年  按揭房15001', '个月 按揭5年  有1', '套房子是夫妻共有 有1', '己的名字 已添加微信150000', '做生意 月收入大概在30000', ' 全款房500000', ' 买了56年 按揭房15001', '个月 按揭5年 有1', '套房子是夫妻共有 有1']
# 工资: 30000
# ['刘静100953', '抢了商机陈 50000', ' 打卡工资5000', '  社保买了2', '  先发份征信过来看1']
# 工资: 5000
# ['刘静100953', '抢了商机450000', ' 微信转账50001', '个月工资芝麻信用分600', ' 无微粒贷打电话这2']
# 工资: 600
# ['刘静100953', '客户暂时无法接听需要20000', '在武隆 自己做生意 1', '个月的收入在6000']
# 工资: 6000
# ['刘静100953', '做生意 无营业执照 1', '个月的收入在10000', '沙坪坝 芝麻信用分在600', '户下午过来打电话下午4', '后期及时跟进 今天不1']
# 工资: 10000
# ['刘静100953', '话客户在新牌坊上班 1', '个月的工资6000', ' 保单月交300', ' 交了1年了打电话这2', '信报告可能会往后延迟12']
# 工资: 6000
# ['刘静100953', '抢了商机打电话130000', ' 在广东上班 打卡6000', '合川打电话芝麻信用分600', '先添加微信 这边先问1']
# 工资: 6000
# ['刘静100953', '户暂时无法接听打电话30000', '  现金工资78000', '在还  芝麻信用分有600', '征信之前有逾期  近3', '个月的流水没有超过6000']
# 工资: 78000
# ['刘静100953', '法接听打电话打卡工资6000', '司就只有十天 只需要2000']
# 工资: 6000
# ['刘静100953', '暂时无法接听需求金额100000', '以内  1', '个月打卡工资在10000', '左右  公积金个缴在800']
# 工资: 10000
# ['刘静100953', '户暂时无法接听打电话50000', ' 上班 工资6800', '  全款  渝北区 610000', '证是父母的名字 上班3']
# 工资: 6800
# ['刘静100953', '户暂时无法接听打电话30000', ' 打卡工资30001', '月  社保才买1', '没有久 客户需要考虑1', '暂时无法接听客户觉得5', '这边说是要跟老公商量1']
# 工资: 30001
# ['刘静100953', '户暂时无法接听打电话20000', '  营业执照不满1', '年  纯收入30000', '/月  保单交了2', '次  还未缴纳第3', '次打电话保单年交费2000']
# 工资: 30000
# ['暂时无法接听自己需要20000', '边上班边做生意 流水4000']
# 工资: 4000
# [' 上班   社保交了2', '车没有房没有  代发4000', '   贷款50000', '寮步 上班 社保交了2', ' 车没有房没有 代发4000', ' 贷款50000']
# 工资: 4000
# ['打卡 有社保  需要8', '到100000', '      信用卡4500']
# 工资: 8
# ['电话寮步 上班 代发5000', '几天寮步 上班 代发5000']
# 工资: 5000
# [' 上班打卡工资 社保10', ' 上班打卡工资 社保10']
# 工资: 10
# ['电话打电话公积金买了2', '资      全款车7', '到80000', '    买了2', '信用卡     恒昌30000', '个月打电话公积金买了2', ' ，打卡工资 全款车7', '到80000 买了2', '有信用卡信用卡 恒昌30000', '电话打电话公积金买了2', ' ，打卡工资 全款车7', '到80000 买了2', '有信用卡信用卡 恒昌30000']
# 工资: 7
# ['谢宏金100981', '   打卡   社保1', '到2年    信用卡20000', '城 上班 打卡 社保1', '到2年 信用卡20000', '城 上班 打卡 社保1', '到2年 信用卡20000', '城 上班 打卡 社保1', '到2年 信用卡20000']
# 工资: 1
# ['谢宏金100981', '话东莞 东城客户需求10000', '，现金工资5000', '，本地人，2', '年社保    信用卡1', '话东莞 东城客户需求10000', '，现金工资5000', '，本地人，2', '十年社保 信用卡1', '话东莞 东城客户需求10000', '，现金工资5000', '，本地人，2', '十年社保 信用卡1']
# 工资: 5000
# ['王鑫鑫100989', '电话打电话上班 打卡4000']
# 工资: 4000
# ['王鑫鑫100989', '打电话餐饮行业 打卡5000']
# 工资: 5000
# ['打电话也可以需要  50000', '，按揭房  14', '年买的  月供1280', ' 没营业执照  工资5000', '没社保公积金， 早上8', '点上班  晚上6']
# 工资: 5000
# ['就需要，有营业执照，04', '年的流水十0000']
# 工资: 0000
# ['打电话打电话需要200000', '经营场所，每个月流水10001', '营模式，泰康保单年缴6000', '去年开始交的，今年有1', '个逾期，9', '已还，现在不需要需要200000', '有实体店，流水每个月10001', '，开了1', '营店，泰康保单，年缴6000', '开始交的，今年有逾期9']
# 工资: 10001
# ['，银行卡，流水，下周3']
# 工资: 3
# ['电话在江苏，打卡工资5000']
# 工资: 5000
# ['邹芬101015', '抢了商机打电话需要50000', '现在就需要，营业执照1', '个月，流水30000', '，按揭车 月供2000', '，还了5', '个月，做车抵押，利息8']
# 工资: 30000
# ['上班  发现金4000', '，社保断了，分8期，3', '无  yo8', ',原因：限制区域巫溪3']
# 工资: 4000
# ['邹芬101015', '话全款房，没证，打卡8000', '保公积金，要明天下午3', '电话打电话说明天早上9']
# 工资: 8000
# ['有营业执照半年，流水50000']
# 工资: 50000
# ['话急用，有营业执照，4', '年，流水几十0000']
# 工资: 0000
# ['，发现金，工地上班，5000', '车，在渝北，今天下午3', '个月就需要用钱，需要100000', '前在跟平安的工作人员1', '看了说大概可贷金额在300000', '，利息大概在4', '厘左右，2012', '业银行办了抵押，贷了270000', '，先息后本，还了1', '名下有平安保单，年交100002', '，去年9', '份才开始交的，才交了1']
# 工资: 5000
# ['费十年了，税后工资有6000']
# 工资: 6000
# ['贷款有当前逾期，今年2', '。他的条件是代发工资4K', '，社保公积金3', '面提取钱。现在有逾期20000']
# 工资: 4000
# ['条件已上过门：1', '增城做建筑设计，代发10000', '半年以上，公积金个人1725', '，基数12300', '，社保个人382', '，公司830,、2.3', '无，3.信用卡100000', '左右，网贷80000']
# 工资: 10000
# ['务签单已上门，微粒贷2000', '过款。在这个公司做了2', '年，打卡工资3000']
# 工资: 3000
# ['时无法接听打电话需要10000', '元，上班，打卡工资8K', '无社保公积金，芝麻分597']
# 工资: 8000
# ['打电话打电话社保 2', '日再跟进  打卡工资4000']
# 工资: 4000
# ['打电话打电话每月流水2000', '以上，车子全款100000', '，开了2']
# 工资: 2000
# ['电话拾回自跟进还需要1W', '点忙，先加微信，打卡3500']
# 工资: 3500
# ['话拾回自跟进现金工资4000', '左右还是需要10000']
# 工资: 4000
# ['杨青101025', '电话打电话打电话打卡8000', '以为是网贷，线下考虑1']
# 工资: 8000
# ['杨青101025', '电话打电话打电话打卡3800', '左右，现在过来0', '...0打电话正在1818', '，马上到0.00']
# 工资: 3800
# ['打卡5000', '右，以为是网贷，考虑1']
# 工资: 5000
# ['杨青101025', '商机打电话打电话打卡6000', '左右，公积金单边500', '，只需要2W']
# 工资: 6000
# ['打电话客户在东城，贷10000', '，代发工资6500']
# 工资: 6500
# ['电话拾回自跟进客户近2', '个月点了3', '，大数据很花，想要贷50000', '，打卡工资6500', '，社保买了89']
# 工资: 6500
# ['拾回自跟进客户想贷10000', '，在黄江，打卡工资8K']
# 工资: 8000
# ['跟进客户只有代发工资4K', '到5K，社保只买了1', '个月，45']
# 工资: 4000
# ['话打电话打电话打电话3000000', '  流水 100000']
# 工资: 100000
# ['地 发现金 自存流水1w', ' 信用卡额度5w', ' 全款房 900000', ' 现在还有300000', ' 还了1年了 利息6', '厘 需要100000']
# 工资: 10000
# ['话打电话上班 打卡 5500', ' 社保500', ' 保单 买了10', ' 年缴   微粒贷 2000', '额度 全款车 买了6', '年 280000']
# 工资: 5500
# ['听打电话打电话流水 5w', '  到6w', '    信用卡额度 2w', '右 几张   微粒贷1w', '子按揭 工商 按揭了2', '年 每月还2000']
# 工资: 50000
# ['话打电话做生意 流水200000', '   保单2年 年缴6000']
# 工资: 200000
# ['话做生意 营业执照 3', '到4年 流水40000', '以内 信用卡额度20000', '  车 5到6', ' 年  裸车价80000', '  等2']
# 工资: 4
# ['接听打电话打电话打卡5k', '到6k 公积金单边200', '打电话打电话周6']
# 工资: 5000
# ['打电话打电话10001', ' 上班 打卡 4000', '到5000', ' 信用卡额度 3000']
# 工资: 4000
# ['稍后联系打电话打电话100000', '以内 上班 打卡 7000', '到8000', ' 公积金单边 900', ' 保单 6年 年缴30000', '房子按揭 农商 不到1', '年 还3000']
# 工资: 7000
# ['打电话打电话自存流水10001', '   信用卡额度3000']
# 工资: 10001
# ['话打电话打电话打电话1', '无法接听打电话打电话20000', ' 上班收入7000', '保无公积金，有全款车16', '年，发票价190000', '，全款房老家，微粒贷2000']
# 工资: 7000
# ['打电话上班 打卡工资1', '个月 1w到2w', '   公积金 缴几00', '元   车 按揭 1', '年 0 车每月还300', '裸车价170000', ' 车子还有60000', '按揭在邮政 按揭了 5', '年 每月还2100', ' 需要1到20000', '  信用卡额度 50000', '  微粒贷2到30000']
# 工资: 1
# ['打电话打电话打卡7000', '到8000 社保500', '   需要5w', '接听打电话打电话打卡7000', '到8000 社保500', ' 需要5w  7']
# 工资: 7000
# ['有自存流水 信用卡 10w', ' 2', '大邑县 全款 需要 10w']
# 工资: 100000
# ['进打电话打电话流水 20000', ' 保单买了去年10', '月买的 年缴2600', ' 信用卡额度3张3000']
# 工资: 20000
# ['电话上班 自存流水 4000', ' 信用卡额度 1.4w', '   按揭 10', '个月 裸车价 62900', '  还有300001', '没还 需要3到40000']
# 工资: 4000
# ['打电话打电话1到30000', '  上班  打卡工资2000', ' 现金3000到4000', ' 社保 单边缴费  400', '了   信用卡额度 6000', '话打电话打电话打电话1', '到30000', ' 上班 打卡工资2000', ' 现金3000到4000', ' 社保 单边缴费 400', '很年了 信用卡额度 6000']
# 工资: 2000
# ['打电话打电话流水  2000']
# 工资: 2000
# [' 房 有证 全款车 08', '年买的 裸车90000', ' 打卡工资5000']
# 工资: 5000
# ['打电话打电话客户需要20000', '电话打电话打电话流水4000', '到5000', '保单家里在买 芝麻分594', '左右打电话打电话19', '岁 流水3000到5000']
# 工资: 4000
# ['打电话打电话打卡1.5w', '接听打电话打电话打卡1', '.5w']
# 工资: 50000
# ['打电话打电话客户需要20000', '都 保险自己交了的 5000', ' 不是他的 流水000']
# 工资: 000
# ['话打电话营业执照办了1', '年   流水 30000', '     平安保单1', '    车全款 买了2', '年 裸车价350000']
# 工资: 30000
# ['电话打电话打电话流水1000', ' 全款房 13', ' 邛崃 在农商行贷了300000', '  总价值 60001', '平米 93']
# 工资: 1000
# ['晚点去电联系。打电话10000', '，上班打卡80005', '年缴税。约定今天下午4']
# 工资: 80005
# ['打电话500000', '，上班打卡100005', '，公积金单边12005', '资金主要用于投资，周5']
# 工资: 100005
# ['打电话打卡交税20000']
# 工资: 20000
# ['打电话拾回自跟进打卡7000', '公积金11003', '年保单年缴800089', '年。客户打卡8000', '分公司安徽公积金以前31', '个月。需要十0000']
# 工资: 7000
# ['户上班，外地人，打卡5000', '金，贷款买房。信用卡700000', '。拾回自跟进保单年缴30002', '年。计划加客户微信调1']
# 工资: 5000
# ['户暂时无法接听、下周1', '时无法接听打电话需要600000', '，这2', '天，上海普陀清房6000000', '，跟父母3', '体店，执照半年，流水80000', '在不需要，约定加微信5', '月9']
# 工资: 80000
# ['客户要2十6', '号发工资流水，计划2', '十7']
# 工资: 2
# ['户征信不好·流水只有2', '个月做不了4月十5']
# 工资: 2
# ['曾朝涛101101', '期。工作，打卡交税，4000', '户说不需要了，计划 4', '月2十2', '户说不需要了，计划 4', '月2十2']
# 工资: 4000
# ['曾朝涛101101', '月底需要用。工作打卡3000', '，外地人有1', '张信用卡，51', '约定加微信发位置，周6', '要月底才有时间，计划4', '月1']
# 工资: 3000
# ['曾朝涛101101', '抢了商机打电话打卡6000', '，公积金320，社保800', '。建行20000', '月用，已加微信，计划3', '月2十3', '定今天晚上再去电确定1']
# 工资: 6000
# ['曾朝涛101101', '电话打电话上班，打卡8000', '静安区。约定今天下午3', '来办理贷款业务。客户6']
# 工资: 8000
# ['已签约计划去做普罗十6', '商务签单客户流水只有2000', '剔除商机。原因：客户3']
# 工资: 2000
# ['物业的，招商代发工资5500', '，社保每月扣350', '逾期过，问利息，报了5', '厘5', '较缺人，现在每天要上12']
# 工资: 5500
# ['李龙杰101104', '班的，有代发工资到手6000']
# 工资: 6000
# ['李龙杰101104', '条件都没有，转账工资3000', '，芝麻分500，600', '信用卡都没有，说需要3', '~5000']
# 工资: 3000
# ['了解了下客户的社保有18', ' 农村信社代发工资 6k', ' 社保卡发过来 准入1']
# 工资: 6000
# ['朱嘉敏101116', '打电话跑业务，扣税后5k', '，社保2', '，按揭车，现代，按揭1', '年，月供1500', '，发票价8w', '，平安保单，年交400', '人，不是自己交，交了1', '邀约了客户周日或者周1', '地方有没有分公司 这2', '在广西 这边让客户这2']
# 工资: 5000
# ['话客户做装修的，只要5k', '工资，有个全款车，买2', '年，东风什么580', '，发票价11w']
# 工资: 2
# ['电话打电话上班，打卡8000', '，网贷看过1.2', '家，需要30000']
# 工资: 8000
# ['需要100000', '，只有打卡工资每月5000', '，信用卡1张7000', '进打电话打电话告知到1', '月4', '，加了微信再联系告知5', '号联系他，6', '后邮递银行卡约了下午3', '....已上门网贷批2', '家1共10000', '，普罗还可以批20000', '左右。客户需要100000']
# 工资: 5000
# ['跟进      打卡5000']
# 工资: 5000
# ['打卡社保公积金 黔江00', '世快递客服2']
# 工资: 00
# ['任超101169', '打电话打电话客户需要30000', '单，只有流水，芝麻分500']
# 工资: 500
# ['拾回自跟进还没毕业 23', ' 银行流水够 芝麻分665', '还没毕业 23', ' 银行流水够 芝麻分665']
# 工资: 665
# ['打电话信用卡2.3w', '微粒贷没有 银行流水2w']
# 工资: 20000
# ['拾回自跟进2w 打卡6600', ' 周5', '址打电话暂定明天下午1', '.2', '......打电话周3']
# 工资: 20000
# ['无法接听打电话月收入8', '.9000']
# 工资: 8
# ['打电话5w 63', '岁 武隆楼梯房60w', ' 退休工资5000', '过去 后续联系打电话5w', ' 63岁 武隆楼梯房60w', ' 退休工资5000', '过去 后续联系打电话5w', ' 63岁 武隆楼梯房60w', ' 退休工资5000']
# 工资: 5000
# ['电话社保 打卡 需要50000', ' 周1', '电话已签  客户  5555555']
# 工资: 50000
# ['袁满101173', '打电话微粒贷  流水30000', '要的额  征信需要养1']
# 工资: 30000
# ['现金工资 按揭车  3', '.25']
# 工资: 3
# ['打电话拾回自跟进上班1', '个月有5险，打卡工资4', '到5000']
# 工资: 5
# ['唐成101201', '抢了商机打电话需要10000', '，江北上班30', '年工资打卡  有 5', '险1']
# 工资: 5
# ['打电话打电话需要3000', '，渝中区，饿了么上班4', '个月，工资打卡有5险1']
# 工资: 5
# ['时无法接听打电话需要10000', '，有自存流水，芝麻分652']
# 工资: 652
# ['时无法接听打电话需要2000', '，19', '在渝北上班，打卡工资30001']
# 工资: 30001
# ['打电话需要80000', '卡工资，有按揭房月供2300', '还有2']
# 工资: 2300
# ['打电话需要50000', '大渡口上班，打卡工资10000', '，有按揭车月供1300', '还了7', '确定哪天过来打电话这2']
# 工资: 10000
# ['唐成101201', '了商机打电话客户需要50000', '，有流水，微粒贷额度4', '.50000', '过微粒贷贷款，芝麻分730', '分打电话客户回复这2', '天有事，说周5']
# 工资: 4
# ['进客户黔江的。月工资8000', '，快递员需要4到50000', '按揭车首付150000', '月供22004', '年了裸车230000', '客户快递员，好忙的.1']
# 工资: 8000
# ['话客户在鸡店的，流水1', '个月20000']
# 工资: 1
# ['回自跟进点的网贷只有1000', '贷款吗，月打卡6000', '.信用分500']
# 工资: 6000
# ['客户工资2000']
# 工资: 2000
# ['工资，明天追问现需要100000']
# 工资: 100000
# ['的，可以贷他朋友过来1', '起做。打卡40001', '个月社保300']
# 工资: 40001
# ['无法接听客户每月打卡5000', '，芝麻分500']
# 工资: 5000
# ['打电话客户做生意每月200000', '到300000', '流水有房子每月20003', '年车贷20001']
# 工资: 20003
# ['开服装店的.房产价值700000', '，月工资10000', '现金.4']
# 工资: 10000
# ['李伟101203', '微信，陕西有社保月缴400', '现金工资1.50000']
# 工资: 1
# ['李伟101203', '机打电话客户有公积金1000', '.打卡4000到5000', '就是在忠县，只有周6']
# 工资: 4000
# ['李伟101203', '了商机打电话客户打卡5000', '到6000', '，社保断交，9', '龙坡的，只要10000', '需要打电话客户明天不1', '无法接听打电话客户近2']
# 工资: 5000
# ['李伟101203', '但是，怎么做嘛，需要30000', '做生意的，打卡3000']
# 工资: 3000
# ['谢建兵101206', '抢了商机打电话在9', '和店面，没有营业收入10', '来0000，芝麻分700', '分，需要300000']
# 工资: 10
# ['朝天门上班，打卡3000', '，9龙坡的房子400000', '子，有信用卡，只需要10000', '，急用，明天早上9', '上午有事来不到，下午2', '断电话，稍后联系换了2']
# 工资: 3000
# ['谢建兵101206', '暂时无法接听打电话在0000', '州驾驶员，现金工资7K', '，有社保，工作5', '年了，有平安保单，买2', '年，每年交5000', '，下周1下午2', '手机打的电话，客户这2', '了，改预约到后天下午2', '户重感冒，可能还要输3', '，客户忘记今天是星期3']
# 工资: 7000
# ['谢建兵101206', '在渝北顺丰公司，打卡7K', '，社保个缴400', '，工作6', '年，按揭房渝北，还有2', '年就还清了，100', '平米，按揭车140000', '有几个月还清，只需要150000']
# 工资: 7000
# ['谢建兵101206', '手机打通了，明天下午2', '银行流水，我说只需要10000']
# 工资: 10000
# ['谢建兵101206', '话大足上班，现金工资6K', '，工作10', '房，还没结房，说大概50000', '户暂时无法接听手机打2']
# 工资: 6000
# ['谢建兵101206', '工地上上班，现金工资8K', '，5个月，芝麻分610', '，需要20000']
# 工资: 8000
# ['谢建兵101206', '解放碑上班，打卡工资6K', '今年才到公司，芝麻分610', '，明天上午10']
# 工资: 6000
# ['打电话打卡工资4000', '，社保300，公积金200', '，工作22年半，需要30000', '，周5早上11']
# 工资: 4000
# ['谢建兵101206', '了商机打电话退休了，64', '岁，退休工资3K', ',需要30000']
# 工资: 3000
# ['公交公司上班的，打卡6000', '，公积金个缴400', '，按揭房10', '了，马上还钱了，月供2000', '，需要60000', '装修房子，后天上午10']
# 工资: 6000
# ['电话在嘉州上班，打卡10000', '，公积金个缴2000']
# 工资: 10000
# ['话打电话税后工资缴存7000', ',8', '电话打电话打电话还有6']
# 工资: 7000
# ['话客户人在广州，需要2W', '，上班的，现金工资5000']
# 工资: 5000
# ['打电话打电话打卡工资8K', '，有1000']
# 工资: 8000
# ['，每个月收入不定，有1', '张农行的信用卡，额度4W', '，大概需要5W', '去苏州出差了，大概要2']
# 工资: 1
# ['话打电话客户说他需要2W', '没执照，收入都说有时120000']
# 工资: 120000
# ['打电话打电话需要10W', '右，上班的，现金工资1W', '5', '是重庆的，给同事联系1']
# 工资: 10000
# ['接听打电话打电话需要3W', '，说每个月工资是7000', '，但每个月只给1000', '费，都是现金，卡里没1', '点流水，还有2', '张信用卡逾期1']
# 工资: 7000
# ['打电话打电话需要1W', '子，上班的，现金工资5000', '，有1']
# 工资: 5000
# ['打电话需要10w', '，，收入 6', '意  有执照   满3', '知晓   车子裸车价400000', '  保险20000']
# 工资: 6
# ['打电话逾期20天  1000', '  负债5、6十0000', '做生意破产了  只剩1', '朋友没有逾期  负债67', '十0000', '  收入每月120000']
# 工资: 120000
# ['作  发现金 每个月4000']
# 工资: 4000
# ['打电话常德按揭房  2000', '每月 2', ' 餐饮行业 营业执照3', '.4个月  实际经营1', '了    流水每个月10001']
# 工资: 10001
# ['新增商机需要3到50000', ' 打卡工资2000', '剔除商机。原因：客户3']
# 工资: 2000
# ['增商机长沙西站客服 2', '年了 打卡工资5000', ' 美团 360', ' 马上消费  芝麻分580']
# 工资: 5000
# ['在还是打卡的  微信937696054']
# 工资: 937696054
# ['是退休了    现在56', '岁了  工资3000']
# 工资: 3000
# [' 连锁食材经营 需要200000', ' 2', '加上微信联系 月收入8000']
# 工资: 8000
# [' 现在在重庆 月收入10000']
# 工资: 10000
# ['江鑫101342', '打电话打电话发现金 5000', ' 招商银行 50000', ' 3月2']
# 工资: 5000
# ['唐彬101343', '抢了商机打卡5000', '，社保500']
# 工资: 5000
# ['人，在成都上班。打卡30007', '，社保交了2年。200', '。营业执照刚3']
# 工资: 30007
# ['唐彬101343', '商机打电话打电话工资30004000', '。邀了后天11']
# 工资: 30004000
# ['房 妻子名下 温江 200', '平米 工资10000', ' 需要60000']
# 工资: 10000
# ['打电话打电话需要400000', '买车跑滴滴，，工资6000', '到10000']
# 工资: 6000
# ['办理，是老师打卡工资5000', '，客户之前在建行做了1']
# 工资: 5000
# ['杨林10134867', '打电话打电话资金需求100000', '，近期需要。打卡工资4000', '左右，社保单边扣393', '，买了2', '话打电话客户明天上午10', '电话打电话客户说下午2']
# 工资: 4000
# ['杨林10134867', '打电话打电话资金需求10000', '，近期需要，自存流水5000']
# 工资: 5000
# ['杨林10134867', '，首次联系客户说明天10', '打电话打电话资金需求30000', '，近期需要，打卡工资1', '.20000到1.50000', '，公积金单交162', '，社保单交300']
# 工资: 1
# ['杨林10134867', '打电话打电话资金需求10000', '，近期需要，打卡工资4000', '在北京上班。预约下午2', '.30']
# 工资: 4000
# ['杨林10134867', '打电话打电话资金需求150000', '都，微信流水每个月有10000', '信用卡，预约明天上午10']
# 工资: 10000
# ['杨林10134867', '打电话打电话资金需求30000', '期需要，之前打卡工资3000']
# 工资: 3000
# ['话打电话已上门，需要5000000', '，科技公司法人，2', '个公司，1个占股80', '%, 营业额5000000', '，1年开票1400000', '，对公流水10000001', '年，对私4000000', '，玉林1套房1000000', '，，华阳1套4000000', '，抵了750000', '，都做了抵押。信用卡320000', '，用了290000']
# 工资: 10000001
# ['班现金工资，有信用卡3W', '额度，芝麻分585']
# 工资: 30000
# ['跟进打电话打电话打卡5000']
# 工资: 5000
# ['电话打电话打电话打卡4K', '没社保，有信用卡额度1000', '剔除商机。原因：客户3']
# 工资: 4000
# ['拾回自跟进打电话打卡6000', '，社保公积金2', '年，公积金单边390']
# 工资: 6000
# ['打电话上班的打卡工资10000', ' 公积金交1000']
# 工资: 10000
# ['执照 有实体 流水十0000', '常在使用 无逾期 有1', '话客户做餐饮的 让我2']
# 工资: 0000
# ['拾回自跟进打电话打卡5K', '遂宁全款房，平安保单5K', '，交了2年，16', '年的车子，裸车价80000']
# 工资: 5000
# ['电话崇州上班打卡工资3500', '有社保 公积金单边交120']
# 工资: 3500
# ['跟进打电话打电话打卡3000']
# 工资: 3000
# ['电话打电话公积金交了2', '年 1开始200', ' 去年5.6月涨到600', ' 打卡工资平均8.9k']
# 工资: 9000
# ['在开实体店买蔬菜，有200', '了十年了，每个月流水2', '十0000', '接听 应该可以做泸商5', '.4']
# 工资: 2
# ['跟进打电话打电话打卡4K', '公积金最低缴费，需要3W', '意给手续费，利息接受8', '厘的样子，1']
# 工资: 4000
# ['话成都上班 打卡工资8000', '积金 有信用卡 用了1']
# 工资: 8000
# ['打电话打电话客户需要5K', '现金工资，信用卡额度5K', '，用了1年了，说下午2', '务员，每个月转账工资3500', '，微粒贷额度3K', '是普罗和微粒贷 费用15']
# 工资: 5000
# ['就挂了 客户自己打卡6K']
# 工资: 6000
# ['电话客户只有打卡工资3000']
# 工资: 3000
# ['在成都上班，打卡工资3500', ' 社保200 上班2', '年，目前有很网贷  1']
# 工资: 3500
# ['打电话打电话车子按揭14W', '买了1年 月供3000', ' 保单断缴了 流水1000', '块1']
# 工资: 1000
# ['电话客户现在每个月还10000', '。。。。在攀枝花投资700000', '去，推荐的网贷，客户29', '在成都给儿子全款买了1000000', '子在西昌上班的，收入8000']
# 工资: 8000
# ['贺春燕10135139', '生，工资现金，社保缴1']
# 工资: 1
# ['打电话打电话每个月有34000', '的流水，需要20000']
# 工资: 20000
# ['自己的情况，打卡工资2000', '员很水。不专业，报的10', '个点的费用，利息报的1', '.8；客户现在近期1', '了很网贷。让客户维护1']
# 工资: 2000
# ['王亚宁101356', '话客户江津的有流水月3000']
# 工资: 3000
# ['王亚宁101356', '没有，连芝麻分都只有500', '户名下有个房子，流水10001', '，芝麻分600']
# 工资: 10001
# ['打电话刚换工作，代发5000', '，有社保，没公积金，4', '月份满56']
# 工资: 5000
# ['跟进上班发现金发微信5000', '左右的工资，微粒贷3000', '，芝麻分580，车子2', '的加上保险费和其它的60000', '，约了明天下午3']
# 工资: 5000
# ['断电话，稍后联系客户1', '。找其他人打试试。上1', '代发没够半年，要等到4', '月8', '月的工资还没发下来，10', '工资，跟客户说了星期5']
# 工资: 4
# ['不过感觉很水。打电话100000', '，流水老婆银行卡下。18', '年全款车，140000', '下个星期才回来，星期1', '来不了，下午在看看，2']
# 工资: 18
# ['打电话尽快需要30000', '打卡，有时候微信转账5k', '左右。湖北的社保2', '信用卡，后来取消了。11', ',12年的车，但是90000', '。这2天公司有事，不1', '走得开，暂时约了星期3']
# 工资: 5000
# ['有条件做，但是只需要1000', '续跟进。上班，工资卡5k', '，有社保公积金，工作3']
# 工资: 5000
# ['王军101387', '配合接电话。近期需要30000', '以前发现金，现在打卡34', '个月。无社保，微粒贷55001', '在不方便接电话，下午3']
# 工资: 34
# ['打电话尽快需要20000', '料制品生意，每月流水10000', '，微粒贷有8000', '，老婆名下保单5000', '总是很吵，客户本人带1', '儿1']
# 工资: 10000
# ['需要20000', '自建房装修用，打卡近5000', '无信用卡，无微粒贷。2', '手按揭奥迪A3，18', '年11月买入，160000', '，付50000', '电话没人接，微信说了1']
# 工资: 5000
# ['打电话不接，今天回了1', '微信，客户搬家租房要10000', '入职，没办过信用卡，3', '医院做护士，工资代发8k']
# 工资: 8000
# ['王军101387', '机打电话客户近期需要10000', '迪达斯点做销售，工作3', '个月了，打卡5000', '有社保公积金，微粒贷10000', '，信用卡邮政1.5', '，交通4k']
# 工资: 5000
# ['王军101387', '抢了商机打电话4', '月中需要50000', '资企业上班，打卡工资5K', '左右，社保3', '年，公积金2', '没有报利息费用。预计4', '月1号回广州，约了4', '月2']
# 工资: 5000
# ['王军101387', '电话上班发现金发微信5000', '左右的工资，微粒贷3000', '，芝麻分580，车子2', '的加上保险费和其它的60000']
# 工资: 5000
# ['王军101387', '商机打电话打电话需要20000', '，比较急，上班1年，5', '险1金，打卡工资3K', '，现金3K。信用卡1', '.30000', '了解直接邀约了，下午4', '剔除商机。原因：客户3']
# 工资: 3000
# ['最近需要20000', '，客户在汕头工作3', '年，打卡工资6K']
# 工资: 6000
# ['计明晚回到，约了星期3', '早上10', '点上门。最近需要20000', '开公司的，还没注销，18', '年11', '什么都没有。客户老婆24', '学历，工作半年，打卡5K', '用卡，名下有按揭车，18', '年12月，发票价80000', '，19年1月还第1', '期，借呗有1.10000', '按揭半年可以做，利息1', '.1.5']
# 工资: 5000
# ['话了。打电话尽快需要200000', '，上班6年，税后工资10000', '，5险1金，有2', '在用，无逾期，微粒贷1', '.60000', '，最近在平安贷了1', '笔，买了份保险1年3000', '，19年4', '月初。前几天点了6、7', '现在不方便请假，星期6', '休息，星期5']
# 工资: 6
# ['或客户暂时无法接听，2', '或客户暂时无法接听，3', '跟打电话20000', '，现金工资2000到3000', '，有保单，买了2', '年缴费1700', '家，有电子保单，年缴1000', '明天过来只能做网贷，3']
# 工资: 2000
# ['户暂时无法接听打电话20000', '金工资，商业保单缴费480', '月，已经缴费5', '家，有电子保单打电话15', '过逾期，抽时间过来看1']
# 工资: 480
# ['单做不了，没有完整的3', '个月流水，3']
# 工资: 3
# ['打电话30000', '，商业保险买了1', '年，保费350', '，做生意，最少月收入5000', '，目前在南川，最近2']
# 工资: 5000
# ['伍0000', '话小额贷款，查询次数8', '做搏民，有座机，家里80', '其他地方咨询过，考虑1', '下打电话打电话报价7', '后期再联系维护打电话50000', '，做生意 ，流水67000', '左右，人在0000']
# 工资: 67000
# ['接听，工作手机联系，3', '户暂时无法接听打电话30000', '有半年营业执照，流水10000']
# 工资: 10000
# ['蒲春香101394', '，明天工作手机联系，2', '被挂断，工作手机联系1', '或客户暂时无法接听，3', '跟打电话工作手机联系1', '维护、加了微信打电话100000', '，有店，营业执照12', '年，流水10001', '，在0000盛，周1']
# 工资: 10001
# ['蒲春香101394', '抢了商机打电话40000', ' 在上班，有现金工资30005', '西，妈妈有房子，人在0000', '州，2', '因：其它区域，客户在0000']
# 工资: 30005
# ['新增商机150000', '，转账工资10000', '以上，在9', '流水很大，芝麻信用分730', '商务签单签单搏民放款30000']
# 工资: 10000
# ['新增商机50000', '，打卡工资4000', '，想做房子抵押利息在5', '者让朋友做保单，保费5000', '，缴费1年8', '暂时无法接听打电话伍0000']
# 工资: 4000
# ['打电话20000', '做工程的， 现金工资7000']
# 工资: 7000
# ['10000', '无锡上班，有打卡工资4000', '，才回来重庆上班不到1']
# 工资: 4000
# ['蒲春香101394', '抢了商机打电话50000', '，上班，现金工资4000', '无人应答，工作手机打1']
# 工资: 4000
# ['打电话20000', '，买了保单已经7', '年，有打卡工资最低6000']
# 工资: 6000
# ['打电话10000', '，打卡7000', '， 有按揭车，月供 1800', '   客户是江西的在9']
# 工资: 7000
# ['打电话打电话10000', '，上班 1000', '工资，  有微粒贷 4000', '  年龄在18', '其它区域，客户年龄在18']
# 工资: 4000
# ['的。退休员工。已退休10', '年；现在55', '岁；退休工资3000']
# 工资: 3000
# ['时无法接听打电话需要200000', '，按揭房期房，还了快1', '年，月供3000', '的也是按揭，打卡工资100005', '低的社保不清楚。去年67']
# 工资: 100005
# ['拾回自跟进打电话客户18', '年9', '，在职部队时打卡工资4500', '。20191']
# 工资: 4500
# ['在微信上联系打征信。1', '.社保交了5年  2', '.打卡流水5000', '  3.生意流水7000', '—8000.    4']
# 工资: 5000
# ['打电话1重庆黔江。18', '岁。2.需求急 3K', 'TV上班18', '左右（现金工资）4', '.做不下来5', '1重庆黔江。18岁。2', '.需求急 3K', 'TV上班18', '左右（现金工资）4', '.做不下来5']
# 工资: 4
# ['：无任何资质，流水几00']
# 工资: 00
# ['观音桥上班；现金工资5000', '—6000', '。银行固定存额2000', '。上门联系。半年查了12', '。名下无其他贷款，有4']
# 工资: 5000
# ['区 做生意 营业执照5', '年， 流水20000', '人寿保险，平安保险各3', '份，年缴3000', '）已经邀约客户下午14', ':00']
# 工资: 20000
# ['打电话现在需要1_20000', '换工作。双份工作打卡1', '起共计6000']
# 工资: 1
# ['李亮101423', '的号码丰都现在需要；44', '岁左右；工资10000', '——13000', '客户不愿意上门办理。2']
# 工资: 10000
# ['巫溪；现金3000', '公司现金打卡流水大于2000', '；近2']
# 工资: 2000
# ['程做的，有流水，需要40000', '程做的，有流水，需要40000']
# 工资: 40000
# ['电话拾回自跟进客户在2', '路上班打卡工资3k', '后期跟进打电话客户在2', '路上班打卡工资3k']
# 工资: 3000
# ['进客户房子在广安按揭800', '左右，流水每个月1000128', '，客户房子在广安按揭800', '左右，流水每个月1000128']
# 工资: 1000128
# ['在白市驿打卡工资平均45000', '在白市驿打卡工资平均45000', '没时间，明天晚上确定1']
# 工资: 45000
# ['户来过公司没办下来，5', '险打卡工资2000']
# 工资: 2000
# ['打电话周4过来需要5', '左右，有保单月缴500', '流水打电话周4', '过来需要5', '左右，有保单月缴500']
# 工资: 4
# ['刘军101424', '姓古，在璧山打卡工资5000', '有个车13年的裸车十10001', '需要10000', '打电话客户中午过来十1', '，过来了押车可能要批2', '.50000', '左右，回去考虑1', '，客户不想押车了，过2']
# 工资: 5000
# ['话客户在巴南打卡工资5500', '到路不想来，我说了做3', '号线很近，他说贷100001']
# 工资: 5500
# ['户在綦江有营业执照才2', '外面上班，有打卡工资5000']
# 工资: 5000
# ['打电话客户有个670000', '的车，上班1个月流水3000', '左右，需要150000', '工的没资产，我叫他问1']
# 工资: 1
# ['户在北碚打卡工资需要120000']
# 工资: 120000
# ['拾回自跟进客户在涪陵6', '十9岁有退休工资3000', '挂电话了，微信上先聊1']
# 工资: 9
# ['坪坝做生意有营业执照1', '个月10001', '流水，需要2十0000']
# 工资: 2
# ['打电话客户叫我下午5', '执照，问他流水大他说12000000']
# 工资: 12000000
# ['客户在巫溪有营业执照2', '年了，流水10000', '左右，有1个理财保单50000', '，需要50000']
# 工资: 10000
# ['暂时无法接听客户需要50000', '，有退休证退休工资2000', '，55', '确表示不需要客户需要50000', '，有退休证退休工资2000', '，55']
# 工资: 2000
# ['的朋友的房子，有流水10001']
# 工资: 10001
# ['复请勿骚扰陈老师人在0000', '有平均每个月打卡工资56000']
# 工资: 56000
# ['南岸，有打卡工资不，7']
# 工资: 7
# ['刘军101424', '上班现金工资有信用卡2', '张最高50000', '，需要10000', '听打电话客户下午来，12', '了，而且他说还要先交100', '了，而且他说还要先交100', '没贷，渠道那边说要收2500', '费用高了就走了，落实1']
# 工资: 2
# ['刘军101424', '金工资，有流水，需要30000', '易记录带不了了，沟通1']
# 工资: 30000
# ['刘军101424', '生意没营业执照，流水10000', '，需要10000']
# 工资: 10000
# ['刘军101424', '打电话璧山去打卡工资5000', '，需要10000']
# 工资: 5000
# ['刘军101424', '抢了商机打电话9', '龙坡打卡工资10000', '有社保需要10000', '，周6', '电话客户说在上班，周5']
# 工资: 10000
# ['刘军101424', '在工地上班，打卡工资4000', '需要20000', '，没什么时间，先考虑1']
# 工资: 4000
# ['刘军101424', '户在永川上班打卡工资3000', '.需要20000', '道什么时候有时间，过2', '客户回复明日再跟进过2', '户在永川上班打卡工资3000', '.需要20000', '道什么时候有时间，过2', '户在永川上班打卡工资3000', '.需要20000', '道什么时候有时间，过2']
# 工资: 3000
# ['，客户在渝北现金工资5000', '来客户在渝北现金工资5000', '朋友来贷，他说回去问1']
# 工资: 5000
# ['刘军101424', '渝北公司大坪打卡工资5000', '社保45年需要20000']
# 工资: 5000
# ['刘军101424', '电话渝北现金工资流水5000', '，也需要5000', '接听渝北现金工资流水5000', '，也需要5000', '电话渝北现金工资流水5000', '，也需要5000']
# 工资: 5000
# ['刘军101424', '商机打电话客户在渝北2', '路，现金工资6000', '，需要20000', '今天没时间客户在渝北2', '路，现金工资6000', '，需要20000', '时无法接听客户在渝北2', '路，现金工资6000', '，需要20000']
# 工资: 6000
# ['刘军101424', '足，没有营业执照流水78000', '，有个车600009']
# 工资: 78000
# ['有车贷，美容营业执照1', '年左右，流水10000', '左右，需要20000']
# 工资: 10000
# ['生意没营业执照，流水23000', '，需要20000', '城上班叫他和儿子沟通1']
# 工资: 23000
# ['在巫山上班，打卡工资3000', '左右，需要120000']
# 工资: 3000
# ['跟进打电话打电话需要10W', '-50W', '区开复印店的  流水6W', '  社保1K']
# 工资: 60000
# ['打电话打电话需要5W', '越快越好  上班流水5K']
# 工资: 5000
# ['潘慧101432', '商机打电话打电话需要1W', ' 现金工资  月的周1']
# 工资: 1
# ['在武汉工作，打卡工资8000', '有房，全款江夏，市值1000000', '没有资金周转的需要，1']
# 工资: 8000
# ['打电话打电话4000', '~5000', '打卡工资， 现在还差300000', '左右。 后面又批了1', '个50000']
# 工资: 300000
# ['自建房，每个月流水有1000', '块钱。要20000']
# 工资: 1000
# ['打电话孝感 有按揭 14', '年 2000', '！！！！ 现金流水 7000']
# 工资: 7000
# ['向雪松101482', '在友谊大道那边上班 1', '个月打卡工资8000', '己也不知道  钱大概4', '在友谊大道那边上班 1', '个月打卡工资8000', '自己也不知道 钱大概4', '话打电话每个月还款：2000', ' 18年10', '支付宝 分期乐 负债2000', '  上了3', '年办，暂时差20000']
# 工资: 8000
# ['汉上班 现金工资  48', '武汉上班 现金工资 48']
# 工资: 48
# ['向雪松101482', '汉上班，打卡工资。要1000020000']
# 工资: 1000020000
# ['跟进打电话打电话需要50000', '，跑滴滴的5', '星等级，工资6k', ',微信转账，信用卡10000']
# 工资: 6000
# ['期及时跟进    就1', '个打卡工资5k']
# 工资: 5000
# ['跟进打电话打电话需要350000', '，按揭房无证已经住了2', '年，无车，现金工资3k', '，社保500']
# 工资: 3000
# ['回自跟进打电话打电话3', '份保单，年缴10000', '，缴了3', '年。工资是公对私转账4k', '日再跟进打电话打电话3', '份保单，年缴10000', '，缴了3', '年。工资是公对私转账4k']
# 工资: 4000
# ['打电话打电话保单年缴4000', '，缴了5年，社保1200', '月，打卡工资6k-8k', '，分2']
# 工资: 6000
# ['话有房有车，现金工资7k']
# 工资: 7000
# ['打电话打电话需要50000', '开养生馆，有证，流水20000', '，银行流水少，信用卡1', '.80000']
# 工资: 20000
# ['杨彪101485', '接听打电话打电话首电2', '打电话打电话客户需要20000', '，打卡工资6000', '，公积金年缴8000', '无效,原因：客户需要20000', '，打卡工资6000', '，公积金年缴8000']
# 工资: 6000
# ['话成都上班，现金工资3000', '，平安银行信用卡10000', '示不需要打电话打电话2', '断电话。打电话打电话3']
# 工资: 3000
# ['打电话打电话客户需要30000', '，现金工资7000', '月，信用卡当前逾期10000', '，支付宝逾期20000']
# 工资: 7000
# ['杨彪101485', '电。打电话客户先咨询1', '下，需要50000', '工地做焊工，现金工资9K']
# 工资: 9000
# ['杨彪101485', '打电话打电话客户需要10000', '，做广告生意的，流水10001', '，按揭车月供·3000', '，还了1', '断电话。打电话打电话2']
# 工资: 10001
# ['杨彪101485', '话客户郫县上班，需要10000', '，打卡工资3000', '，社保缴费单边300', '太愿意过来，暂定下午3']
# 工资: 3000
# ['唐振101486', '话按揭房 农行按揭 15', '年按揭的  月供5000', ' 房价约为800000', '  有全款车 裸车价230000', ' 17', '年买的  打卡工资5000', '到10000', '自己买有社保  需要500000']
# 工资: 5000
# ['唐振101486', '打电话打电话客户需要1', '到20000', '期就需要，打卡工资有4000', '到8000']
# 工资: 4000
# ['唐振101486', '话打电话社保单边缴费350', ' 缴费5', '年了，打卡工资4000', '左右，有信用卡10000', '左右，人在眉山，需要30000']
# 工资: 4000
# ['唐振101486', '打电话上班打卡工资有4000', '，需要2000']
# 工资: 4000
# [' 发现金 每个月自存300', '左右  约的明天上午10']
# 工资: 300
# ['王林101518', '话只有打卡工资每个月6000', ' 约的周1上午10']
# 工资: 6000
# ['打电话打电话上班打卡5000', ' ，   社保2000', '元  。   信用卡1000']
# 工资: 5000
# ['是需要的，打卡每个月5000']
# 工资: 5000
# ['话打电话打电话信用卡30000', '。  工资5000', '，公积金，社保分别交500', '。这周5']
# 工资: 5000
# ['打电话蓝先生， 50000', '，。 开店，餐饮。5', '年了，  60000', '流水。  2张20000', '，   40000']
# 工资: 2
# ['打电话王先生，50000', '，。干装修的 1个月10000', '收入。    6000']
# 工资: 6000
# ['混毅101523', '打电话现在在忙，下午4', '话。打电话江苏无锡，62', '岁，退休金将近3000', '元。 棋牌室5000', '女儿上班打卡工资每月4000', '钟在致电。打电话下午4']
# 工资: 4000
# ['打电话打电话打电话11', '电话今天要拿到钱。 1', '.50000打卡， 50000', '。  100000', '微粒贷。   负债：700000', '。300000']
# 工资: 50000
# ['打电话100000', '，  8000', '，   6000', '打卡，  上班15', '年了。  公积金1900', '，  社保1000', '元， 平安300000', '负债。  110000', '微粒贷。  平安50000']
# 工资: 15
# ['打电话150000', '，税后打卡10000', '，  公积金1400', '   社保个人700', '。 上班3', '年。   负债70000', '，信用卡100000', '来时间再定。周先生 150000', '，税后打卡10000', '， 公积金1400', ' 社保个人700', '。 上班3年。 负债70000', '，信用卡100000']
# 工资: 10000
# ['做不了，名下3', '无，工资1']
# 工资: 1
# ['打电话4.7', '，公积金贷没点出来，10', ',0000，上班打卡9000', '，有社保公积金1300', '，4', '这是爱人的情况打电话4', '.7', '，公积金贷没点出来，10', ',0000，上班打卡9000', '，有社保公积金1300', '，4']
# 工资: 0000
# ['电话未接，\t打卡工资3000']
# 工资: 3000
# ['话打电话在忙，\t需要100000', '，\t打卡工资8800', '有，最低的标准，开票2000000', '，税1010001，02', '流行业的打电话打电话3', '.15']
# 工资: 8800
# ['还是在有事忙呢，需要50000', '，现金工资 微粒贷2500']
# 工资: 2500
# ['决了，不需要了，打卡5100', '保公积金，按揭房月供6000', ',14', '年买的，上海人，需要300000', '，5', '决了，不需要了，打卡5100', '保公积金，按揭房月供6000', ',14', '年买的，上海人，需要300000', '，5', '决了，不需要了，打卡5100', '保公积金，按揭房月供6000', ',14', '年买的，上海人，需要300000', '，5', '决了，不需要了，打卡5100', '保公积金，按揭房月供6000', ',14', '年买的，上海人，需要300000', '，5']
# 工资: 5100
# ['打电话查询很，打卡5000', '安保单 本人投保人 6000', ' 买2', '话打电话查询很，打卡5000', '安保单 本人投保人 6000', ' 买2', '不行，要养征信，打卡5000', '安保单 本人投保人 6000', ' 买2']
# 工资: 5000
# ['需要，解决了，公积金1100', '，打卡工资10000', '上海房全款但被抵押了1600000', '，2', '体现的，查询次数，看3', '需要，解决了，公积金1100', '，打卡工资10000', '上海房全款但被抵押了1600000', '，2', '体现的，查询次数，看3', '需要，解决了，公积金1100', '，打卡工资10000', '上海房全款但被抵押了1600000', '，2', '体现的，查询次数，看3']
# 工资: 10000
# ['查征信打电话明天下午3', '先拉网查的，拆迁房满5', '，无保单微粒贷，打卡2500', '，现金6000', '积金打电话打电话下午3', '先拉网查的，拆迁房满5', '，无保单微粒贷，打卡2500', '，现金6000', '保无公积金打电话下午3', '先拉网查的，拆迁房满5', '，无保单微粒贷，打卡2500', '，现金6000', '要，解决了，拆迁房满5', '，无保单微粒贷，打卡2500', '，现金6000']
# 工资: 2500
# ['电话打电话未接，需要50000', '，税后5000', '，公积金1', '的办打电话未接，需要50000', '，税后5000', '，公积金1', '电话打电话关机，需要50000', '，税后5000', '，公积金1']
# 工资: 5000
# ['库点不是店面。月收入4w', '-5w，流水账300w', '年。平安信用卡35000', '，微粒贷2.5k', '。网贷点了1', '蚂蚁保险，全款车落地10w', '，5', '下机构，刚申请了网贷3', '.50000', '库点不是店面。月收入4w', '-5w，流水账300w', '年。平安信用卡35000', '，微粒贷2.5k', '。网贷点了1', '蚂蚁保险，全款车落地10w', '，5']
# 工资: 40000
# ['话打电话打电话未接，1', '年150000', '左右流水，按揭车，9', '个月，月供3000', '，裸车价90000']
# 工资: 9
# ['打电话未接，打卡工资5000', '打电话拒接，打卡工资5000', '打电话拒接，打卡工资5000']
# 工资: 5000
# ['打电话4', '点半下班后去电，打卡6000']
# 工资: 6000
# ['打电话可能要到5', '是特殊情况要用，打卡8000', '社保公积金，保单年交4000', '，交了3', '年了打电话可能要到5', '是特殊情况要用，打卡8000', '社保公积金，保单年交4000', '，交了3']
# 工资: 8000
# ['打电话不需要了，打卡5000', '，公积金上300', '，上海全款房1', '个人名字，保单交2000', '，交了17']
# 工资: 5000
# ['未接，不需要了，打卡7000', '，公积金600', '，按揭房月供3100', '，还了4', '打电话宜信办过，打卡7000', '，公积金600', '，按揭房月供3100', '，还了4', '接，\t宜信办过，打卡7000', '，公积金600', '，按揭房月供3100', '，还了4', '接，\t宜信办过，打卡7000', '，公积金600', '，按揭房月供3100', '，还了4']
# 工资: 7000
# ['需要了，解决了，打卡6000', '以上，月供2600', '，还了2年，保单年交6000', '，交了2']
# 工资: 6000
# ['资金还是需要的，打卡4000', '，公积金上海最低，车120000', '，开了1', '资金还是需要的，打卡4000', '，公积金上海最低，车120000', '，开了1']
# 工资: 4000
# ['地，项目没谈好，打卡5000', '，半年，保单太平洋3', '年，1000，房贷10001']
# 工资: 5000
# ['话说正在弄逾期，打卡10000', ' 打卡4', '金有 车子全款 裸车19', '.80000 09', '年买的 微粒贷6.80000', '是资金不需要了，打卡10000', ' 打卡4', '金有 车子全款 裸车19', '.80000 09', '年买的 微粒贷6.80000', '是资金不需要了，打卡10000', ' 打卡4', '金有 车子全款 裸车19', '.80000 09', '年买的 微粒贷6.80000']
# 工资: 10000
# ['打电话打电话1970', '的，\t10', '，法人，营业执照，1', '，服务性行业，月流水10', '来0000', '，保单，张女士打电话10', '，法人，营业执照，1', '，服务性行业，月流水10', '来0000']
# 工资: 10
# ['打电话负债十10001', '了，打卡5500.3', '年。保单5800.2']
# 工资: 5500
# ['打电话工作 打卡6500', ' 3', '金有的 房子在浦东 3', '，做不了，工作 打卡6500', ' 3', '金有的 房子在浦东 3']
# 工资: 6500
# ['过来，用他姐姐的贷，63', '岁，打卡3000', '，退休工资4000', '子是他姐姐和姐姐老公2', '过来，用他姐姐的贷，63', '岁，打卡3000', '，退休工资4000', '子是他姐姐和姐姐老公2', '个人的名字打电话放款20000', '，用他姐姐的贷，63', '岁，打卡3000', '，退休工资4000', '子是他姐姐和姐姐老公2']
# 工资: 3000
# ['需要，这月不急，需要100000', '，上班，工资打卡，5000', '。有社保400', '左右，本单位上了1', '需要，这月不急，需要100000', '，上班，工资打卡，5000', '。有社保400', '左右，本单位上了1']
# 工资: 5000
# ['太忙，需要先息后本，23', '年的，打卡8000', '保公积金有 车子裸车180000', ' 14', ' 房子有在上海 产证2', ' 全款的 保单 年交50000', ' 泰康人寿 实际需要500000', '金了，需要先息后本，23', '年的，打卡8000', '保公积金有 车子裸车180000', ' 14', ' 房子有在上海 产证2', ' 全款的 保单 年交50000', ' 泰康人寿 实际需要500000']
# 工资: 8000
# ['需要，解决了，公积金500', ' 社保有的 打卡4000', ' 微粒贷7.40000', ' 车子有的 2014', '年12月底买的 裸车80000']
# 工资: 4000
# ...
# 工资: 2
# ['梁佛聪977398337', '暂时无法接听打电话贷10000', '上班打卡，社保公积金5', '个月，车子老家110000', '按揭车（今年6']
# 工资: 5
# ['梁佛聪977398337', '暂时无法接听打电话贷30000', '用，上班打卡，按揭车2', '年130000', '粒贷社保公积金，去年6', '月份逾期2']
# 工资: 2
# [' 有平安保单还没交满1', '年，社保单边300', '，工资打卡5000']
# 工资: 5000
# ['打电话拾回自跟进需要50000', '有打卡工资，明天早上10']
# 工资: 10
# ['黄国英978062838', '电话，稍后联系打电话5000', '班，无社保，发工资发5000', '剔除商机。原因：客户3']
# 工资: 5000
# ['黄国英978062838', '电话，稍后联系打电话20000', '上班，无社保，发现金9000', '系打电话回老家了，过23']
# 工资: 9000
# ['100000', '上班，无社保，发现金8000', '险，无房，有按揭车，70000', '右，无微粒贷，先考虑1']
# 工资: 8000
# ['答或客户暂时无法接听50000', '。做餐饮生意，执照快1', '年了，1个月收入30000', '！先加微信再约！客户1', '，加了微信，提供了别1']
# 工资: 1
# ['需要10w', ' 有打卡工资7000']
# 工资: 7000
# ['话打卡社保公积金单边500']
# 工资: 500
# ['信用卡，有打卡，需要10000']
# 工资: 10000
# ['十月份以后做了700000', '，有平安的保单，年缴30000', '，买了4', '开工厂的，有营业执照5', '年，月流水500000']
# 工资: 500000
# ['上班18年，打卡工资4000', '花都按揭了几年，月供2700', '元，自己名下，106', '方，市价1.600001', '方，现在还差银行400000', '，信用贷款几十0000']
# 工资: 18
# ['打电话贷2~30000', '，上班族在现单位上班2', '年了，转账工资6000', '右，有社保公积金，买2', '年了，公积金基数7000', '有车子，房子，保单，16']
# 工资: 6000
# ['花都做生意，执照4', '年，月流水100000', '。2，平安保单年缴20000', '，5年了，在平安贷了150000', '买房，老家全款房。3', '，有信用卡额度100005', '，使用1年。4']
# 工资: 100000
# ['要1000000', '家上班的 工资现金 30000', '越秀区的按揭房 今年3', '月份购买 月供3.20000', ' 7个月 房子价值9000000', ' 好说话 但是可能是1', '个老司机 上个月贷了1', '个微粒贷 60000', ' 2']
# 工资: 30000
# ['张晓婷979442633', '时无法接听负债：平安3', '年还2年了 500000', ' 渣打剩30000', '，网贷近期下了60000', '，20000', '行业上班十几年，代发20000', '，公积金个人交1000', '，要50000']
# 工资: 20000
# ['自己做生意，营业执照2', '年了，月银行流水100000', '右，有个按揭房，按揭3', '个月了，月供5000', '左右，信用卡刷了480000', '小额贷款，信用贷月供1', '.10000，最近2', '个月查询5', '，诺远，点融需要处理1', '条件，信和：审批通过60000', '，利息2.5%，24', '期，点融已经进件，4', '月19']
# 工资: 100000
# ['开工厂的，每个月流水5000000', '，需要100000']
# 工资: 5000000
# ['打电话打电话华夏 25', ' 信用卡额度 230000', ' 农业 月供5000', '州的增城的月供房子 3', '较大 然后等额本息 6', '厘觉得高 需要1000000', '好房子，上班工资打卡4000', '他老公外企员工 打卡10000', '，公积金个人交1000', '州增城有月供房，月供2000', '，供了5', '的贷款。想贷款全款买1', '无法接听 短信已发 1']
# 工资: 4000
# ['拾回自跟进需要10001', '，装修，番禺按揭20005', '，农业银行400000', '，组合贷，2', '十年，按揭1', '年，楼梯房70', '房。车子130000', '。15', '上班，社保有，月收入10001', '，打工工作5000', '，信用4张100000', '。用完，商贷67', '笔，贷款每月月供20000']
# 工资: 10001
# ['户暂时无法接听，需要5', '到十0000', '有执照几年了，流水十00001', '个月，有平安保险100001', '年，还有1个月满1']
# 工资: 00001
# ['单位，公积金个人月交2000', '，工资有10000', '广州全款房，做了抵押1000000', '，名下信贷500000', '，现在要1000000']
# 工资: 10000
# ['拾回自跟进1', '房地产销售主管，上班6', '年，平均税后工资7~8000', '积金，按最低的来缴；2', '.房：黄埔按揭房2', '年，月供4000', '还没办下来，现在均价20000', '； 报了3~5']
# 工资: 7
# ['拾回自跟进需要100000', '上班转账的，每月工资3000', '是有扣税的，现在升到5000', '没有扣税。上班6', '年了，个人公积金每月600', '网银 在花都区的 加1']
# 工资: 3000
# ['户暂时无法接听 无v10', '月9', '号，客户林立雄，工资4130', '只发了4', '道处上班，公积金个缴466', '，基数3300']
# 工资: 4130
# ['10/20客户社保5', '，客户联系不上，拖了2', '信已发打电话农行代发3000', '，13']
# 工资: 3000
# ['要330000', '上班的，在现单位上班6', '年，现金工资5~60000', '，自己有公司，有执照1', '年了，月流水300000', '，有保单，年缴8000', '，缴5', '婆名下有按揭房，首付300000', '，月供7000，供4', '卡在供，报信贷可以做5', '厘2~7厘2', '的利息，报抵押可以做2', '厘2~3厘2', '公务员才可以做得到，2']
# 工资: 5
# ['照无实体店，流水几十0000', '，香港买的保单年缴50000', '，当前无逾期，芝麻分700', '，需要50000']
# 工资: 0000
# ['客户做生意营业执照1', '体户，有打税，月流水56', '十0000，按揭车1', '年，分3年，发票价150000', '，信用卡额度总额140000', '左右，最高额度300005', '，芝麻分600', '，近期中国银行逾期9000', '，前2天还了，说这2']
# 工资: 56
# ['10年友邦 年缴7000', ' 经营场地在东莞 1', '年了营业执照医疗流水1', '个季度60w', ' 全款房房子280', '知道 平安做了保单批21w', '今天3月 交通银行12w', '快还玩了1', '年期 信用卡25w', ' 车子13', '后在看，其他机构去了6']
# 工资: 1
# ['报了 6', '个点渠道成本+1.6', '来签，客户有意向 做2', '押40w 之前利息报8', '厘~1.5', '分 客户说利息超1.1', '就不要 报1.6', '费 先上门在说，想贷10w', '执照半年 流水方面不1', '定 中山按揭房 月供2500', ' 3', ' 都没有申请下来 报5', '~8厘 超1']
# 工资: 1
# ['答或客户暂时无法接听200000', '，最近1', '周，白云区，占明股，49', '%，流水，有房贷，2', '年，5600']
# 工资: 2
# ['有）按揭（交行）月供5k', '。供2', '。白云区上班打卡工资3k', '左右（6k）（单位9', '年）报了1.2%-2', '.2%。5年（60', '要上班（加微信，明天18', '.00左右回访邀约周5']
# 工资: 3000
# ['拾回自跟进需要1500000', '这周，做生意，执照20', '太太是法人，对公流水30000000']
# 工资: 30000000
# ['拾回自跟进需要30000', '，上班，税后税后8000', '，有社保，2', '码不是本人实名的 过2', '天过来试1', '用卡不着急要钱 需要30000', '，上班，税后税后8000', '，有社保，2']
# 工资: 8000
# ['自跟进客户想做抵押，16', '证发给他，客户现在在4', '川明天晚上回来250000', '，广州的，上班1', '年打卡3700', '数，按揭房半年 月供3300', '，市值100，欠银行570000']
# 工资: 3700
# ['，有执照，非法人，这2', '准备变更法人，月流水4', '.50w', '开增值税发票，年缴税200000', '揭房在个人名下，月供5400', '，供了1年，市值200w', '，还没有证，友邦保单3k', '，2年2缴，近期需要10w']
# 工资: 4
# ['拾回自跟进客户需要150000', '，尽快用到；1', '、做生意，执照1', '年，个人月流水20000', '左右；2', '、名下没有固定资产；3', '、微粒贷150000', '； 报了6~8', '可以接受；手续费报了1', '~2', '，帮他安排了明天下午16']
# 工资: 20000
# ['拾回自跟进需要25w', '，包工程，月收入2.3w', '名下没任何资产，平安3', '份，投保人，年缴2w', '，交了5']
# 工资: 30000
# ['时无法接听上班，打卡30000', '，社保10', '年，建设。平安2', '年，年交6000', '。车按揭1年半。报了8', '自己可以办理平安的，5']
# 工资: 30000
# ['张晓婷979442633', '示号码为空号v联系 6', '年代发1.20000', ' 想要200000']
# 工资: 1
# ['张晓婷979442633', '电话手机打核实 代发5000', ' 公积金个交490', '户挂断电话，稍后联系6']
# 工资: 5000
# ['打电话打电话需要50000', '，3', '现金和打卡，不扣税，5', '险1金扣1000', '剔除商机。原因：客户3']
# 工资: 5
# ['在惠州，广州代发工资6600', '，公积金个人252', '，湖南常德全款900000', '无其他，负债建行快贷6', '.60000', ' 去年做， 7', '月到期，工商欠5000', '，微粒贷2000，1']
# 工资: 6600
# ['明天再联系1', '打电话打电话客户下周2', '险保单华夏的，年缴费4000', '度，缴费了快满2', '间了，流水每个月只有2000', '，负债只有1', '街道办事处上班，社保1', '起1000', '与房屋主人协商评估价430000', '左右，走锦城最高8', '接听打电话打电话代哥2', '有房子，按揭款大概差120000', '方便知晓贷款，走锦城2', '抵最高400000']
# 工资: 2000
# ['豫豫要又不要的样子。1', '.资金需求：2W，2', '使用时间：越快越好，3', '.资质条件：现金工资1W', '左右，征信查询，4', '.预计上门时间：周1', '有事，只有周2或周3', '过来，约的周1']
# 工资: 10000
# ['康睿轩980124176', '打电话打电话只有流水5000']
# 工资: 5000
# ['康睿轩980124176', '机打电话客户只有流水1000']
# 工资: 1000
# ['接听打电话打电话需要30000', ' 每月自存流水20000', '左右 社保2', '打电话再次发短信 这2']
# 工资: 20000
# ['接听打电话打电话打卡6000', ' 需要50000', ' 之前收10']
# 工资: 6000
# ['加微信 广东潮州打卡4000', '连续3']
# 工资: 4000
# ['话打电话打电话年流水3000000', '电话打电话健身俱乐部1', '年  装饰公司2', '年   现在永川  2', '年车10']
# 工资: 3000000
# ['电话打电话说其他平台4', '.5', '公司看看 问了信贷 55', '岁退休工资3000', '其他地方咨询 都咨询2', '家了 还有1', '家  说的160000', '手续费9000利息4', '.5', '电话我去 到处咨询 160000', ' 想要月供1500', ' 压力小的 3', '年本金都要4444', '婆知道 邀约明天上午11', '在春熙路看店面 还有3', '无法接听打电话打电话13']
# 工资: 3000
# ['打电话打电话流水20000', ' 查询还没3个月 5000', '额度信用卡1']
# 工资: 20000
# ['打电话客户用100000', ' 上班打卡6000']
# 工资: 6000
# ['打电话客户想用250000', '上班 打卡5000', '左右 现金1', '积金 小贷使用中的有4', '笔 信用卡最大额度30000', '下来 告诉现在新推出1', '也能做 加微信预计这2']
# 工资: 5000
# ['打电话客户上班 打卡6000', ' 社保现单位5']
# 工资: 6000
# ['不看征信的产品 打卡2000', '现金2000', '来  信用卡最大额度1', '.10000', ' 告诉批不了100000', ' 50000']
# 工资: 2000
# ['话打电话客户转账工资1', '.1.20000', '贷没批 现在网贷剩余1', '笔还有1']
# 工资: 1
# ['明天公司有活动 下周1', '日才回来 说只有下周1', '接听打电话打电话打卡5000', '去年在公司做过网贷批80000', ' 去年8', '月份到现在没有预期 8', '月之前有逾期连3']
# 工资: 5000
# ['再跟进客户上班工资分2', '张卡1.2~3000', '客户说扣税是按照1.4', ' 现在使用中的网贷有3', '笔 信用卡使用超过80']
# 工资: 2
# ['增商机做生意  执照6', '年左右  流水60000', '房无车无保单 微粒贷6500']
# 工资: 60000
# ['宋兰981696577', '打电话在上城区，需要120000', '，有打卡工资10000']
# 工资: 10000
# ['宋兰981696577', '打电话上班，工资打卡6']
# 工资: 6
# ['宋兰981696577', '杭州上班，工资现金，3', '无，有1', '份人寿保险不到1', '但是资金有需要，想要400000']
# 工资: 3
# ['意，有营业执照，流水1', '个月78十0000']
# 工资: 1
# ['宋兰981696577', '，工资现金，临安，有1', '张信用卡，芝麻分500']
# 工资: 1
# ['下个月去了，打卡平均5000', '左右，公积金单边500']
# 工资: 5000
# ['打电话客户需求100000', '做生意的有营业执照 10', '来年了 个人流水10000']
# 工资: 10000
# ['客户需求100000', '生意周转用，上班打卡4k', '-5k，社保交300', '有半年了，芝麻信用分583']
# 工资: 4000
# ['现金工资，月收入大概6k']
# 工资: 6000
# ['陈庆霞983049276', '了商机打电话客户需求10000', '潼南上班 ，打卡工资7000', '左右，芝麻信用分500']
# 工资: 7000
# ['打电话客户需求20000', '，打卡工资1300', ' 其他的收入3000', '，社保400', '有点网贷不  芝麻分679']
# 工资: 1300
# ['客户需求10000', '做生意的 有限公司 2', '年了 个人流水1', '个月大概是200000']
# 工资: 1
# ['上门，达州按揭房月供2400', '母亲共有 的上班工资8000', ' 车子裸车价100000', ' 今年年底结清 月供1400', ' 芝麻分661 网贷2', '个 有钱花 360 30000', '左右 人品分63', ' 费用8.8', '个点 觉得高 要100000']
# 工资: 8000
# ['店用品公司 工资发现6000', '县的按揭房交行 月供2400', ' 6年了 做过1', '笔平安普惠氧气贷900009', '  去年10', '源客户唐先生是亲戚，4', '个人连体婴儿。签约1']
# 工资: 6000
# ['资料给客户了已签单，10000', ' 网贷 8', ' 崇州厂里上班，打卡5000', ' 社保1']
# 工资: 5000
# ['再联系！打电话打电话100000', '，上班打卡工资5000', '，社保十1年，公积金1', '年，信用卡1张10000', '，芝麻分580', '是北京自建房，有贷款40000', '，下周4打电话打电话100000', '，上班打卡工资5000', '，社保十1年，公积金1', '年，信用卡1张10000', '，芝麻分580', '是北京自建房，有贷款40000', '，周4100000', '，上班打卡工资5000', '，社保十1年，公积金1', '年，信用卡1张10000', '，芝麻分580', '是北京自建房，有贷款40000', '，周4']
# 工资: 5000
# ['需要200000', '，每月咨询流水70000', '跟进打电话打电话需要200000', '，每月咨询流水70000', '接听打电话打电话需要200000', '，每月咨询流水70000', '电话在忙......111111111', '电话打电话打电话需要200000', '，每月咨询流水70000']
# 工资: 70000
# ['客户暂时无法接听需要5w', '，上班工资5000', '贷过还了永川 ，保单1', '张3000', '，平安的，信用卡8000', '爆，无芝麻分，微粒贷20000', '，周5', '剔除商机。原因：客户3']
# 工资: 5000
# ['联系打电话打电话需要8000', '，上班，打卡工资4000', '，社保公积金3.4', '年，信用卡2张100004', '，芝麻分558', '，清明节后需要8000', '，上班，打卡工资4000', '，社保公积金3.4', '年，信用卡2张100004', '，芝麻分558', '，清明节后，上午11']
# 工资: 4000
# ['话打电话下个月需要，200000', '，做生意，流水300000', '，社保8年，信用卡1', '张8000，芝麻分712', '，蚂蚁借呗800001', '，有钱花10000', '话打电话下个月需要，200000', '，做生意，流水300000', '，社保8年，信用卡1', '张8000，芝麻分712', '，蚂蚁借呗800001', '，有钱花10000']
# 工资: 300000
# ['需要300000', '，做生意，执照10', '年，流水100000', '+，按揭房，首付200000', '，09年买的，月还4200', '户暂时无法接听\t需要300000', '，做生意，执照10', '年，流水100000', '+，按揭房，首付200000', '，09年买的，月还4200']
# 工资: 100000
# ['接听打电话打电话需要20w', '，社保公积金缴纳8', '年，自己交公积金300', '，打卡4000', '，信用卡10000', '做服装，保险平安年交1900', '，交了17', '电话打电话打电话需要20w', '，社保公积金缴纳8', '年，自己交公积金300', '，打卡4000', '，信用卡10000', '做服装，保险平安年交1900', '，交了17']
# 工资: 4000
# ['无法接听打电话打电话120000', '，打卡工资12000', '，社保3', '年，信用卡有，芝麻分601', '.29', '剔除商机。原因：客户3']
# 工资: 12000
# ['只有打卡工资，芝麻分610']
# 工资: 610
# ['联系打电话打电话需要10000', '，芝麻分534', '，打卡工资5000', '，打卡工资1', '过来打电话打电话需要10000', '，芝麻分534', '，打卡工资5000', '，打卡工资1', '，下个星期再联系需要10000', '，芝麻分534', '，打卡工资5000', '，打卡工资1']
# 工资: 5000
# ['打电话上班，打卡工资5000', '+，社保1年，芝麻分710', '，自己也在做生意,14', ':20']
# 工资: 5000
# ['话电话联系客户，需要200000', '社保公积金，打卡工资8000', '，2张卡，公积金单边1400', '      给他说了6', '.2', '负债 不看征信 授信300000', '的信贷    下周1']
# 工资: 8000
# ['裸车价130000', '   开了3', '   成都  流水 4K', '       就下午4']
# 工资: 4000
# ['郑恒98419826', '客户在成都   需要20000', '   成都上班 工资5K']
# 工资: 5000
# ['郑恒98419826', ' 现金   流水有 2000', '清楚   资金也就这2']
# 工资: 2000
# ['郑恒98419826', '打电话  稍后联系 1', '行流水     月供4K', '  还了几年  贷了250000', '  平安  10', '中     今天早上5']
# 工资: 4000
# ['郑恒98419826', '  现金   流水有7K', '子 车    车买了8', '年了   周4']
# 工资: 7000
# ['郑恒98419826', '  打卡   每个月5K', ' -6', '话明天过来   下午2', ' 过来   明天联系1']
# 工资: 5000
# ['郑恒98419826', '  没有执照  流水2000', '以上 有信用卡 额度3500', '    保单6K', '   泰康保险2']
# 工资: 2000
# ['打电话打电话5k-1W', '   就这2', '卡工资   单位没有1']
# 工资: 1
# ['班的   现金工资 10000', '  才1年时间  7K']
# 工资: 10000
# ['不方便 接电话   1', '      打卡工资5K', '    有信用卡  3K', '打电话今天来不到  1']
# 工资: 5000
# ['郑恒98419826', '都上班   银行流水2K', '     说今明2']
# 工资: 2000
# ['拾回自跟进客户需要30W', ' 上班税后工资1W']
# 工资: 10000
# ['刘志强984405934', '打电话打电话客户需要10W', ' 上班打卡工资6000', '款 说自己没房没车 1', '就过来办理打电话客户1', '会发工资把逾期还上 1', '定回过来办理微信沟通1']
# 工资: 6000
# ['打电话上班打卡8000', ',4']
# 工资: 8000
# ['电话打电话上班，打卡5000']
# 工资: 5000
# ['租车经营个体，月流水200000', '在停掉了，信用卡额度5000', '，农商银行贷款50000']
# 工资: 200000
# ['打电话需要资金1.50000', '，做生意，公司开业于18', '年10月，流水30000', '公积金社保，信用卡有1', '张，额度最高6000', '元，无微粒贷，近1', '年有3']
# 工资: 10
# ['梁志磊985324065', '抢了商机11', '..打电话打电话需要5000', ' 现金工资  信用卡1', '.20000']
# 工资: 1
# ['打电话需要50000', ' 个体户 流水30000']
# 工资: 30000
# ['梁志磊985324065', '抢了商机11', '.打电话姜先生 上班2', '年  打卡8000', ' 公积金无 信用卡50000', ' 今天来不了  星期1']
# 工资: 8000
# ['梁志磊985324065', '抢了商机11', '友咨询的 上班 打卡5000', '有 正式员工 按揭供10000']
# 工资: 5000
# ['梁志磊985324065', '抢了商机11', '电话打电话打电话需要10000', ' 上班1', '月  公积金无 打卡6000', ' 信用卡8000']
# 工资: 6000
# ['话拾回自跟进退休工资2100', '，打卡2700', '，约的明天打电话客户1', '直忙，没有加微信，1', '直说加，1']
# 工资: 2100
# ['班，银行卡流水每个月10001', '，芝麻分650']
# 工资: 10001
# ['回武汉，大概今天下午1', '有资质可以办，流水差1']
# 工资: 1
# ['杨梦辉986463895', '时无法接听打电话打卡3500', '  社保公积金2', '明天上午十点过来打卡3500', ' 社保公积金2', '上午十点过来  需要10000']
# 工资: 3500
# [' 白户，只有现金工资6000', ' 其他没有，想要10000']
# 工资: 6000
# ['买房子 全款买   5', '十0000   还差2', '十0000', '海底捞工作   打卡10000', '右   公积金以前是600', '   现在200', '暂时无法接听打电话要6']
# 工资: 10000
# ['时无法接听打电话打卡8000', '以上 3', '我 告诉他最低的利息4']
# 工资: 8000
# ['做的 没有执照，收入10000', '。芝麻分500']
# 工资: 10000
# ['打电话刚刚上班35', '个月 工资3.5K', '  微粒贷无 芝麻分587']
# 工资: 5000
# ['杭州这边上班得 打卡8000', ' 公积金600 有23', '有申请过网贷，信用卡1', '张 无逾期记录。 4', '先添加微信再后期维护1']
# 工资: 8000
# ['在又回来了。  工资7000', '盖的。其余无 芝麻分600']
# 工资: 7000
# ['在杭州这边上班 打卡3000', '  才上班1', '无。微粒贷无 芝麻分560', '分左右。去年有1']
# 工资: 3000
# ['戴艮银987898826', '机打电话打电话打电话10000', '  上班  工资打卡5000']
# 工资: 5000
# ['戴艮银987898826', '抢了商机打电话打电话30000', '   上班工资现金 10000']
# 工资: 10000
# ['戴艮银987898826', '抢了商机打电话客户要100000', ' 有门面  每月流水10000']
# 工资: 10000
# ['戴艮银987898826', '抢了商机打电话要20000', '别人的   每月流水10000']
# 工资: 10000
# ['戴艮银987898826', '话打电话打电话客户要30000', '武汉上班  工资打卡3000', ' 客户现在信用卡逾期20000', '没还   有1']
# 工资: 3000
# ['打电话打电话需要20000', ' 这12', ' 做生意 有营业执照6', '年 做餐饮的 流水10001', ' 有房有车 报利息6']
# 工资: 10001
# ['跟进打电话打电话需要100000', '按揭房 全款车裸车价110000', '开了4', '年，上班打卡税后收入10000']
# 工资: 10000
# ['李明霞988155923', '抢了商机打电话打电话03', '-25 10:01:51', '，03-25 10:01', ':51，客户需要90000', '得贷款，保单年缴费才400', '保已经买满了，打卡才1000', '，接近2000', '我心好痛，加客户微信18030851297', '手机打的，客户在忙等1']
# 工资: 1000
# ['李明霞988155923', '抢了商机打电话打电话04', '-09 10:01:05', '，04-09 10:01', ':05', '客户现在比较忙，喊我12', '打电话客户有打卡工资30005', '，有当前逾期10000']
# 工资: 30005
# ['李明霞988155923', '话打电话客户打卡工资4000', '，有社保，需要2000']
# 工资: 4000
# ['李明霞988155923', '再跟进打电话客户需要100000', '，在金堂上班，这个月20', '以前用，有公积金单边100', '，打卡2000', '，有按揭车裸车130000', '，去年8', '月买的，利息报的1']
# 工资: 2000
# ['李明霞988155923', '复明日再跟进客户需要10000', '利息高点没关系，只用3', '个月，有社保，打卡4000', '，利息算的1']
# 工资: 4000
# ['李明霞988155923', '打电话客户姓张，需要30000', '，14', '号以前用钱，有打卡4000', '但是花呗逾期3', '天签合同，手续费报的10']
# 工资: 4000
# ['拾回自跟进需要1000000', '有套全款房，天河区，50', '平方，1平方70000', '自己在事业单位工作了30', '年，每个月20000', '的工资，月缴公积金2000', '栋，负债200000']
# 工资: 2000
# ['客户上班20', '年了的；十8', '公积金；公积金个人缴1000', '；代发10000', '的；说要100000']
# 工资: 10000
# ['打电话30000', '，上班代发4000', ' 公积金每个月分别350']
# 工资: 4000
# ['拾回自跟进打电话2450000', '，客户想做20', '期的，广汽上班，税后100007', '，年新税后300000', '，上班1', '年，公积金基数20000', '龙岗区有全款房，价值3500000']
# 工资: 100007
# ['回自跟进打电话今天第2', '次上门，需要的金额在20', '~300000', '的，要给合作方那边结1', '个合作服务费；1', '、在横琴上班11', '个月来了，扣税工资有9', '个月，平均工资在7~8000', '左右，公积金基数6400', '元；2、保：华夏2', '份，年缴6.5000', '，3年4缴；横琴3', '份，年缴2.10000', '，缴了1次；农银3', '份，总缴4000（1', '份2年2缴，2分3年3', '缴）；车：10.40000', '，2013年买的；3', '、微粒贷：3.20000', '小贷、网贷做的有点，7', '~8', '逾期，详版征信上有“2', '”，9月份还的，11', '月24', '老婆征信很干净，代发3000', '，微粒贷1.50000']
# 工资: 9
# ['门办理了，有代发工资7000', '元，上班5年了.3.22']
# 工资: 7000
# ['贺贵祥988319110', '资是发现金的，微粒贷4', '.70000', '，按揭房子是清远1700', '元，按揭1', '年半了，拍拍贷有1000', '加微信，放款时间说了2']
# 工资: 4
# ['贺贵祥988319110', '做制造业的，工作时间9', '年了，每个月收入税后20000', '，每个月公积金交1500']
# 工资: 20000
# ['贺贵祥988319110', '电话客户在越秀区上班3', '年，代发工资7000', '左右，需要分期3']
# 工资: 7000
# ['贺贵祥988319110', '发现金的，只有微粒贷90000', '件没有，微信当前逾期1', '.10000']
# 工资: 90000
# ['历史备注：企业月流水20', '来0000，保单2', '年年缴7k，全款车14w', '发票价4年，按揭房3', '年月供4k，报5厘，10000100']
# 工资: 20
# ['打电话表示授信10w', '客户暂时无法接听：需50000', '，家具，执照3', '年，流水300000', '商意外险缴半年，年缴1900']
# 工资: 300000
# ['听，微信也不回复。需100000', '，家具，执照3', '年，流水1000000', '有时才缴税，平安保险2018', '年5月份缴，月缴591']
# 工资: 1000000
# ['户暂时无法接听打电话2w', '，上班7K，工资卡2', '年，1张，600', '芝麻分，报8', '厘，约明天下午2', '点后上门2w，上班7K', '，工资卡2年，1张，600', '芝麻分，报8', '厘，约明天下午2']
# 工资: 7000
# ['无法接听打电话打电话5k', '，上班，4k', '，工资卡，2', '年，有信用卡，708', '芝麻分，微粒贷2500', '，顺德，咱安排1']
# 工资: 2
# ['打电话4w，1w', '现金工资，芝麻分550']
# 工资: 550
# ['2w，装修越快越好，8k', '农行代发，15', '年入职有社保，报3.6']
# 工资: 15
# ['店，客户说流水比较，1', '个月有10', '没微粒贷，有按揭房在3', '水，夫妻共有，首付20w', '，月供3000，供了7', '.8年，1共是20', '有个按揭车，雅阁，供3k', '，供了差不1年，要供2', '有房子有车，利息大概5']
# 工资: 1
# ['陈瑛素990304134', '机打电话打电话打电话1', '了解到现金工资芝麻分555']
# 工资: 555
# ['打电话1w，10', '天内，上班，税后8k', '，社保1年，13726398304']
# 工资: 8000
# ['打电话1w', '，这个月。上班6K', '现金工资。招商信诺2', '份月700', '/月，南海上班，报的8']
# 工资: 2
# ['1000，上班1w', '金工资，私人厂，平安3', '年年缴4000，报5', '知道在禅城要上门觉得3']
# 工资: 3
# ['陈瑛素990304134', '抢了商机打电话5w', '，这2天要。上班税后6', '.6K', '信用社，有信用卡，报5', '厘。在3']
# 工资: 2
# ['陈瑛素990304134', '户暂时无法接听打电话10w', '，这个星期。上班6K', '税后工资，10年2', '年，有信用卡，平安2', '年年缴7钱，报5', '厘，约明天下午2点到2', '点半10年社保2', '年公积金约明天下午2', '点打电话10w', '，这个星期。上班6K', '税后工资，10年社保2', '积金，有信用卡，平安2', '年年缴7钱，报5', '厘，约明天下午2点到2']
# 工资: 10
# ['陈瑛素990304134', '户暂时无法接听打电话1w', '，不急用。上班税后0', '.1w工资,8', '月社保 ，人寿几年了2', '份2000+5000', '，采购和做1', '些杂事，高明。报5厘20w']
# 工资: 0
# ['陈瑛素990304134', '抢了商机打电话5w', '没有工资流水。月收入2w', '卡，无微粒贷，跟配偶1', '起的情况1']
# 工资: 20000
# ['陈瑛素990304134', '时无法接听打电话表示6', '，稍后联系打电话转账7k', '-1w，按揭车1', '年月供2800，裸车90000', '。意外险，有1', '配偶转账工资，有社保3', '年。报8', '请是大数据不怎么好，40', '几分，2.3.8']
# 工资: 3
# ['上班，只有流水。需要30000']
# 工资: 30000
# ['签单。签的世联，月息0', '.8，报的5', '个点的出门，我们5', '个点的服务费。杂费3500', '的，现金工资。月收入6000', '到10000']
# 工资: 6000
# ['胡海波990823818', '客户暂时无法接听需要150000', '公司名下做生意，流水200000']
# 工资: 200000
# ['胡海波990823818', '机打电话王先生。需要100000', '需要。个体餐饮，流水100000', '理贷款信用卡，名下有1', '年买的新华保险，年交5000', '过来办理，说自己考虑1']
# 工资: 100000
# ['胡海波990823818', '抢了商机打电话需要1', '到20000', '候需要不说。上班打卡6000', '剔除商机。原因：客户3']
# 工资: 6000
# ['打电话需要40000', '，近期要。65', '，有退休证，退休工资3700']
# 工资: 3700
# ['打电话需要5到100000', '，在沌口那边上班打卡5', '到6000', '保公积金，本单位上班2', '年，微粒贷5000']
# 工资: 5
# ['时无法接听打电话下午4', '电话打电话打电话需要200000', '期需要。上班打卡部分2000', '保公积金，按揭房还了5', '年，月还款2000', '求先加微信。报了利息5', '到8厘，费用3']
# 工资: 2000
# ['打电话需要10000', '间不定。上班在东西湖5000', '工资，孝感按揭房月还1600', '，还了8']
# 工资: 1600
# ['何定刚991660497', '金牛区上班，现金工资5K', '他什么都没，利息报的8', '厘，手续费1K-2K']
# 工资: 5000
# ['刘华992133032', '式客户本人咨询的 这2', '现金工资  保单年缴7200', '  缴纳1年零3', '个月  周6']
# 工资: 7200

# %%
# 匹配小数
ret = re.findall(r"\d+\.\d+",'打电话打电话需要1.2万，现金/打卡工资4-5千，自己缴的社保，征信有点问题')
print(ret)

merge_df.head()
# Out:
# ['1.2']
#    business_id place_order_time  customer_id login_name  product_amount  \
# 0          NaN              NaN      2792115  992133032             NaN
# 1          NaN              NaN      3052625  992133032             NaN
# 2          NaN              NaN      3117825  992133032             NaN
# 3          NaN              NaN      3347755  992133032             NaN
# 4          NaN              NaN      3839065  992133032             NaN
#
#    call_duration  call_score  \
# 0          180.0    0.248476
# 1          147.0    0.151302
# 2          387.0    0.858020
# 3          202.0    0.313258
# 4           69.0   -0.078381
#
#                                              content  follow_days  \
# 0  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话打电话无人应答或客户暂时...      104.250
# 1                     无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进        1.000
# 2  打电话打电话无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进客户最近需要150万...       89.375
# 3  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进无人应答或客户暂时无法接听 、...       29.625
# 4  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话无人应答或客户暂时无法接...       86.875
#
#    follow_hour  follow_score  salary_score
# 0           18      0.691486             0
# 1            0     -0.161284             0
# 2          115      0.568630             0
# 3           69      0.075138             0
# 4           15      0.547982             0

# %% [markdown]
# # 读取历史成单记录

# %%
order_df = pd.read_csv('order2018-20190409.csv',encoding='utf-8')
order_df['login_name'] = order_df['user_no']
order_df = order_df[['business_id','place_order_time','customer_id','login_name','product_amount']]
print(order_df.shape)
print(order_df.info())
order_df.head()
# Out:
# (117899, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117899 entries, 0 to 117898
# Data columns (total 5 columns):
# business_id         117899 non-null int64
# place_order_time    117899 non-null object
# customer_id         117899 non-null int64
# login_name          117748 non-null float64
# product_amount      117899 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 4.5+ MB
# None
#            business_id     place_order_time          customer_id  login_name  \
# 0  7636348060347805696  2018-01-02 14:07:34  7636348060372971520  76245836.0
# 1             18270402  2018-01-02 17:16:25             16294154  12034683.0
# 2             18273827  2018-01-02 16:18:53             16296839  56802695.0
# 3             17966745  2018-01-02 16:18:53             16048951  56783251.0
# 4             17918754  2018-01-02 15:41:26             16010715  97511357.0
#
#    product_amount
# 0         12000.0
# 1         50000.0
# 2         70000.0
# 3        600000.0
# 4         50000.0

# %%
order_df['login_name']=order_df['login_name'].astype('object')
order_df['customer_id']=order_df['customer_id'].astype('int')
print(order_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117899 entries, 0 to 117898
# Data columns (total 5 columns):
# business_id         117899 non-null int64
# place_order_time    117899 non-null object
# customer_id         117899 non-null int32
# login_name          117748 non-null object
# product_amount      117899 non-null float64
# dtypes: float64(1), int32(1), int64(1), object(2)
# memory usage: 4.0+ MB
# None

# %% [markdown]
# # 合并历史成单记录

# %%
merge_df = pd.merge(order_df, merge_df, on=['customer_id','login_name'], how = 'right')
print(merge_df.shape)
print(merge_df.info())
merge_df.head()
# Out:
# (775910, 12)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775910 entries, 0 to 775909
# Data columns (total 12 columns):
# business_id         0 non-null float64
# place_order_time    0 non-null object
# customer_id         775910 non-null int64
# login_name          775910 non-null object
# product_amount      0 non-null float64
# call_duration       4807 non-null float64
# call_score          4807 non-null float64
# content             775910 non-null object
# follow_days         775910 non-null float64
# follow_hour         775910 non-null int64
# follow_score        775910 non-null float64
# salary_score        775910 non-null int64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 77.0+ MB
# None
#    business_id place_order_time  customer_id login_name  product_amount  \
# 0          NaN              NaN      2792115  992133032             NaN
# 1          NaN              NaN      3052625  992133032             NaN
# 2          NaN              NaN      3117825  992133032             NaN
# 3          NaN              NaN      3347755  992133032             NaN
# 4          NaN              NaN      3839065  992133032             NaN
#
#    call_duration  call_score  \
# 0          180.0    0.248476
# 1          147.0    0.151302
# 2          387.0    0.858020
# 3          202.0    0.313258
# 4           69.0   -0.078381
#
#                                              content  follow_days  \
# 0  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话打电话无人应答或客户暂时...      104.250
# 1                     无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进        1.000
# 2  打电话打电话无人应答或客户暂时无法接听 、今天已跟进，客户回复明日再跟进客户最近需要150万...       89.375
# 3  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进无人应答或客户暂时无法接听 、...       29.625
# 4  打电话客户已经明确表示不需要 、今天已跟进，客户回复明日再跟进打电话无人应答或客户暂时无法接...       86.875
#
#    follow_hour  follow_score  salary_score
# 0           18      0.691486             0
# 1            0     -0.161284             0
# 2          115      0.568630             0
# 3           69      0.075138             0
# 4           15      0.547982             0

# %%
writer = pd.ExcelWriter('score0424.xlsx')
merge_df.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# # 解析跟进记录中的备注字段

# %%
contents = list(set(allocation_group['content'].values.tolist()))
print(len(contents))
contents
# Out:
# 99643
# ['打电话打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听今天已跟进，客户回复明日再跟进',
#  '客户已经明确表示不需要打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话客户已经明确表示不需要打电话无人应答或客户暂时无法接听打电话剔除商机。原因：客户征信黑名单',
#  '客户不需要，有一点小傲娇打电话无人应答或客户暂时无法接听',
#  '03/21   、客户挂断电话，稍后联系03/26   通话中 、无人应答或客户暂时无法接听03/28  、无人应答或客户暂时无法接听',
#  '打电话拾回自跟进客户有需要 晚上做回访',
#  '拾回自跟进打电话客户已经停机了 继续跟进',
#  '打电话打电话客户挂断电话，稍后联系打电话打电话打电话打电话客户挂断电话，稍后联系打电话打电话剔除商机。原因：号码打不通打电话打电话',
#  '拾回自跟进客户挂断电话，稍后联系打电话打电话真服了，打通不说话，再打还是不说话',
#  '打电话打电话客户说的等哈过来，应该无资质 后期持续联系打电话打电话客户说的快到了 ......打电话打电话',
#  '打电话打电话打电话打电话客户不满意，因为服务费太贵，客户反馈给了6千元，无疑问，结项。',
#  '拾回自跟进客户想做个车抵，车本已发给我，评值评了6.5万，客户绿本没在手里，在老家，等从老家拿回来再押',
#  '打电话一说银行贷款这边的，直接挂断电话，周四继续跟进.打电话无人应答或客户暂时无法接听  下午继续跟进打电话一说到贷款就直接挂断电话 后期跟进',
#  '打电话打电话剔除商机。原因：号码打不通打电话打电话打电话剔除商机。原因：号码打不通',
#  '打电话客户说在煮面现在忙，后期再跟',
#  '打电话有点事 说看明天还是后天上来办理打电话客户挂断电话，稍后联系打电话打电话不晓得老师是什么情况 电话不接 微信也不回',
#  '打电话拾回自跟进客户需要两万左右 每个月有几千的打卡工资没有接触过网袋 约3.22来门店免签打电话客户今天有事没有过来 重新跟客户约了周一打电话打电话无人应答或客户暂时无法接听 十一点继续拨打邀约打电话无人应答或客户暂时无法接听打电话',
#  '剔除商机。原因：213',
#  '拾回自跟进打电话打电话无人应答或客户暂时无法接听打电话打电话电话给我挂断了，电话给我挂断了，',
#  '最近两个月都不会办贷款，房子没有贷无人应答或客户暂时无法接听拾回自跟进无人应答或客户暂时无法接听',
#  '打电话客户已经明确表示不需要打电话剔除商机。原因：客户征信黑名单',
#  '打电话说自己还在外面办事，弄完了就过来商务签单签单',
#  '打电话打电话有点装怪我感觉现在每次打过去就直接挂了。',
#  '打电话打电话膜拜普惠。、客户挂断电话，剔除商机。原因：无需求',
#  '拾回自跟进打电话打电话剔除商机。原因：说咱们公司太小了  给他办不下来   我呸！！',
#  '移交商机给【伍彩虹46214950】，原因：移交移交商机给【孙晋10235178】，原因：移交移交商机给【孙晋10235178】，原因：移交',
#  '打电话在高速上，晚点联系。，，，，，，，，，，，，，，，',
#  '打电话有需要的   晚些再联系、、拾回自跟进客户有需要  晚些再联系',
#  '打电话拾回自跟进客户说自己征信差.做了几笔都没做下来.只有代发工资',
#  '客户挂断电话，稍后联系打电话客户挂断电话，稍后联系打电话打电话打电话打电话打电话客户挂断电话，稍后联系  不需要了客户已经明确表示不需要',
#  '打电话客户已经明确表示不需要剔除商机。原因：客户征信黑名单、客户三无、客户年龄不满足要求、号码打不通',
#  '打电话打电话打电话打电话客户说之前没有在我们这里办理过，现在没有这方面的需要了',
#  '打电话打电话打不停。。。。。。。。。。。。。',
#  '打电话打电话客户比较忙叫明天去电话 说有额度了',
#  '打电话打电话客户已经明确表示不需要  下次再说',
#  '打电话不需要 就挂了 也不加微信',
#  '打电话未接，\t手机打的接了，说是不需要了，解决了，打卡3000左右，现金8000到一万，社保公积金都有，需要15到20，微粒贷5000',
#  '打电话拾回自跟进要10w，之前宜信做了20w，退休返聘1w5，现在忙，下午联系打电话客户挂断电话，稍后联系打电话现在在开会，不方便，下午打电话微信加上了，现在在开会，晚点聊',
#  '打电话打电话电话未接。。。。。。。。。。打电话打电话推了生意贷，资金暂时不需要。。。。。。。。。。',
#  '打电话打电话客户已经明确表示不需要 膜拜 信贷先息后本微信有客户 半个月一跟 微信周末跟进',
#  '客户已经明确表示不需要换同事打过去客户不需要 已经周转解决了',
#  '打电话打电话客户说不需要、客户已经明确表示不需要',
#  '打电话打电话客户近期没有资金需求 。。。。',
#  '拾回自跟进崔先生  没有社保 公积金  已发短信',
#  '打电话打电话现在可以打通了 明天手机联系一下拨打电话提示客户已关机打电话打电话打电话打电话无人应答或客户暂时无法接听打电话打电话在外地的 后面有需要联系',
#  '打电话打电话剔除商机。原因：没时间太远了  不给沟通',
#  '打电话客户已经明确表示不需要打电话客户说资金回笼了不需要啦，后期再联系',
#  '魏刚100406抢了商机打电话工资打卡3K  一年 需要1500出去旅游。。。打电话工厂打工的   工资打卡3K 一年 需要1500 最2000出去旅游。。。',
#  '打电话打电话今天已跟进，客户回复明日再跟进打电话打电话',
#  '拾回自跟进打电话客户有点意向，上班的打卡4000多，微粒贷7000多，客户说是这段时间忙，给发短信告诉客户有10万额度打电话客户说是现在接个电话打电话客户说是前两天过来办过，没办理下来',
#  '拾回自跟进打电话无人应答或客户暂时无法接听打电话打电话拨打电话提示客户已关机打电话无人应答或客户暂时无法接听打电话打电话打电话无人应答或客户暂时无法接听',
#  '打电话打电话客户已经明确表示不需要打电话打电话客户已经明确表示不需要打电话打电话剔除商机。原因：号码打不通',
#  '打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听',
#  '移交商机给【梁伟平100098】，原因：移交移交商机给【谭义昌103890】，原因：资源流转',
#  '打电话无人应答或客户暂时无法接听打电话客户挂断电话，稍后联系剔除商机。原因：客户征信黑名单',
#  '赵嘉豪971601744抢了商机正在回电话.0.0.0.打电话打电话首电中客户体现人是在内江，工作生活都在内江返无效,原因：其它区域  客户説他生活工作都在内江',
#  '打电话客户现金工资5500，无社保公积金，保单断交了，信用卡额度2k，芝麻分560，、客户挂断电话，稍后联系',
#  '打电话打电话手机联系的，说不需要就挂了，试试加微信',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话打电话打电话今天已跟进，客户回复明日再跟进打电话打电话打电话剔除商机。原因：号码打不通',
#  '打电话打电话客户说去年在其他公司做了2抵20万，5年期月还5000目前不需要。++',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听打电话打电话今天已跟进，客户回复明日再跟进打电话打电话无人应答或客户暂时无法接听',
#  '返无效商机审核通过。原因：返无效成功，客户表示未咨询。',
#  '拾回自跟进打电话无人应答或客户暂时无法接听打电话打通没人接听。。。。。。。。',
#  '部门经理分配商机给【赵鹏901162846】',
#  '拾回自跟进打电话打电话电话设置了 一直提示用户忙..........打电话打电话工作手机和外呼一直都是在通话中.............',
#  '拾回自跟进打电话客户对自己很没信心，说不需要打电话客户已经明确表示不需要',
#  '隐藏到期事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐�
电话无人应答或客户暂时无法接听打电话客户挂断电话，稍后联系打电话现在客户在外地呢，继续跟进，打电话客户挂断电话，稍后联系打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '打电话打电话已告知商务离职，无疑问。',
#  '打电话客户挂断电话，稍后联系打电话客户不需要，使用时间待定，预约时间待定',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话客户接通了，挂断电话，比较水',
#  '打电话拾回自跟进暂时不需要，加个微信！打电话微信已通过，后期持续跟进',
#  '打电话打电话打电话打电话通话中或客户暂时无法接听',
#  '微信维护  不太急、、、、、商务签单',
#  '打电话无人应答或客户暂时无法接听修改商机信息打电话打电话无人应答或客户暂时无法接听',
#  '打电话打电话保单先息后本，依旧不需要，下次缓跟，直接备注',
#  '打电话打电话报身份手不需要，挂机',
#  '拾回自跟进打电话打电话未接挂，，，，，，，，，，未接挂。。。。。。。。。',
#  '打电话打电话法人梁总，当前逾期还没还，做不到生意贷',
#  '拾回自跟进打电话打电话认为上班和做生意是隐私，不透露，之后有需要可以找我们， 发了个短信给客户',
#  '方案已经基本确定哈行了 就等客户上门了打电话方案已经基本确定哈行了 就等客户上门了打电话方案已经基本确定哈行了 就等客户上门了客户有意向，后期及时跟进方案已经基本确定哈行了 就等客户上门了打电话方案已经基本确定哈行了 就等客户上门了打电话方案已经基本确定哈行了客户钱不是太着急 就等客户上门了打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听',
#  '打电话打电话打电话打电话无人应答或客户暂时无法接听打电话打电话膜拜的  还没说完就挂了 看来是真的不需要了   前两天让他们回访也不考虑',
#  '拾回自跟进打电话打电话打电话打电话剔除商机。原因：111',
#  '打电话打电话打电话打电话打电话打电话说不了两句话他就给我挂了，',
#  '古倩鑫100682抢了商机无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听通话中，无人接听，晚点再打打电话打电话无人应答或客户暂时无法接听打电话一直无人接听，工作手机打不通打电话打电话打电话一直无人接听，工作手机打不通说了身份挂断了电话，情况未知，再打无人接听打电话打电话工作手机打不通，无人接听工作手机打不通，无人接听打电话',
#  '打电话打电话客户地铁上 让10分钟后联系打电话打电话南充自建房，才在公司注册公司，无其他资产，需要10W，没信用卡，客户还是在忙，说等会儿联系我打电话打电话无人应答或客户暂时无法接听打电话打电话剔除商机。原因：客户三无',
#  '打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听手机联系客户暂时无人接听无人应答或客户暂时无法接听无人应答或客户暂时无法接听剔除商机。原因：号码打不通',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听打电话打电话客户有意向，后期及时跟进打电话打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听',
#  '打电话打电话客户有用款需求。担心下不了款。打电话',
#  '没法办了...........',
#  '打电话打电话打电话在打 看看 嘛 跟进 、客户有意向，后期及时跟进',
#  '打电话打不通 捡回来再说，，，，，，，，拾回自跟进',
#  '移交超时跟进离职移交超时',
#  '打电话客户已经明确表示不需要。有需要，客户在白沙洲，拾回自跟进',
#  '打电话无人应答或客户暂时无法接听打电话正在通话中 稍后在拨打',
#  '拾回自跟进女士接的电话说有需要让爱人回来回复打电话剔除商机。原因：号码打不通',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话推了20先息后本 说的一般都不需要',
#  '打电话无人应答或客户暂时无法接听打电话客户已经明确表示不需要无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听',
#  '拾回自跟进打电话打电话拨打电话提示号码为空号',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听打电话客户挂断电话，稍后联系打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接

#  '打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听客户暂时不需要资金。微信跟进',
#  '新增商机打电话打电话打电话、客户不接电话打电话客户挂断电话，稍后联系打电话客户挂断电话，稍后联系',
#  '打电话打电话工作手机打的，没接电话',
#  '拾回自跟进打电话打电话剔除商机。原因：121',
#  '马金凤103832抢了商机无人应答或客户暂时无法接听返无效,原因：首次联系表示未咨询',
#  '打电话打电话不考虑贷款哈不要打。。。。打电话打电话客户挂断电话，稍后联系',
#  '打电话打电话还是有资金需要，客户名下有一套全款房子在武侯区，推的随借随还，加了微信今天已跟进，客户回复明日再跟进打电话打电话拾回自跟进今天已跟进，客户回复明日再跟进今天已跟进，客户回复明日再跟进已经在微信沟通了，明天打个电话已经在微信沟通了，明天打个电话打电话打电话客户挂断电话，稍后联系客户挂断电话，稍后联系',
#  '打电话说60岁了，暂时不需要；',
#  '打电话打电话客户说没有咨询贷款，不要打，也不叫阿布。、客户已经明确表示不需要',
#  '打电话客户的房子还处于划拨状态，暂时做不了，以后有了合适的再跟客户介绍。',
#  '打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听修改商机信息',
#  '17704008890 客户不打算买房了，后面再跟进吧，觉得压力太大。',
#  '拾回自跟进打电话打电话客户已经明确表示不需要，至少已经说了50次不要了！！！这边再打就要骂人了！！！！剔除商机。原因：客户三无剔除商机。原因：客户三无',
#  '打电话拾回自跟进加微信，预约上门洽谈',
#  '打电话拾回自跟进加微信，之前使用过捷信分期，因为手机跟银行卡丢失，导致逾期黑名单，长期跟进微信：13431678811',
#  '打电话打电话听顶挂.......................',
#  '无人应答或客户暂时无法接听客户有意向，后期及时跟进打电话客户有意向，后期及时跟进',
#  '移交商机给【刘琨元89377852】，原因：防止掉库移交商机给【钱文军60548769】，原因：防止掉库今天已跟进，客户回复明日再跟进打电话打电话客户已经明确表示不需要 真的没有需要 谢谢',
#  '打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话打电话剔除商机。原因：号码打不通',
#  '打电话客户还是没有回来过几天回来联系 跟着吧先打电话明天下午三点回来看一下 后天可以过来不打电话打电话打电话打电话打电话打电话打电话无人应答或客户暂时无法接听打电话打电话打电话无人应答或客户暂时无法接听',
#  '打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听打电话客户挂断电话，稍后联系打电话无人应答或客户暂时无法接听',
#  '客户有意向，后期及时跟进打电话客户已经办了，不过客户朋友需要办，继续跟进',
#  '打电话打电话打电话打电话何先生 之前上过门客户非要说我们是骗子公司......扯了半天  添加微信 看后续剔除商机。原因：客户三无',
#  '04/02  用户正忙   、无人应答或客户暂时无法接听',
#  '打电话电话显示我拨打的电话不正确打电话剔除商机。原因：号码打不通剔除商机。原因：号码打不通',
#  '打电话打电话打电话客户来过公司  说是费用太高  做不了 。。。。。。。。。。。。。',
#  '拾回自跟进打电话打电话不需要  也不接微信 、、、、、、、、、、、',
#  '人工分配商机给【陈汝平940514808】',
#  '打电话打电话拾回自跟进打电话拨打电话提示号码为停机无人应答或客户暂时无法接听',
#  '打电话打电话客户挂断电话，稍后联系陌电做生意随借随还，现在有点忙也不需要，手 机已发授信短信，下次缓跟，直接备注',
#  '事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏事业部库拨打后隐藏',
#  '打电话无人应答或客户暂时无法接听打电话一直说打错了，，、客户已经明确表示不需要打电话客户已经明确表示不需要',
#  '打电话打电话推的随借随还  确实不需要 最近缓跟了',
#  '无人应答或客户暂时无法接听打电话剔除商机。原因：号码打不通剔除商机。原因：号码打不通',
#  '打电话剔除商机。原因：非说我是骗子客户不需要说我们是骗子去骗别人吧剔除商机。原因：号码打不通',
#  '打电话打电话客户已经明确表示不需要，不耐烦了。。。。。。。。。。。。',
人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听',
#  '邓霖101860抢了商机打电话客户挂断电话，稍后联系',
#  '打电话打电话跟进\t\r\n呼叫的用户正忙 打不通 啊\t跟进\t\r\n呼叫的用户正忙 打不通 啊\t跟进\t\r\n呼叫的用户正忙 打不通 啊\t跟进\t\r\n呼叫的用户正忙 打不通 啊\t跟进\t\r\n呼叫的用户正忙 打不通 啊\t跟进\t\r\n呼叫的用户正忙 打不通 啊',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话打电话打电话打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话',
#  '打电话芝麻分590，客户啥都没有、今天已跟进，客户回复明日再跟进打电话剔除商机。原因：客户征信黑名单',
#  '打电话打电话客户听到贷款不需要了就挂了',
#  '打电话打电话拾回自跟进说需要七八万，打卡8000 多  后就挂电话了',
#  '打电话打电话无人应答或客户暂时无法接听打电话打电话打电话打电话无人应答或客户暂时无法接听打电话打电话客户已经明确表示不需要打电话打电话打电话打电话客户已经明确表示不需要',
#  '打电话客户挂断电话，稍后联系、联系客户，回复请勿骚扰打电话客户挂断电话，稍后联系、联系客户，回复请勿骚扰剔除商机。原因：不需要了剔除商机。原因：号码打不通',
#  '打电话现在在忙   等会联系、客户挂断电话，稍后联系打电话无人应答或客户暂时无法接听',
#  '客户暂时无法接听电话。。打电话无人应答或客户暂时无法接听工作手机去电未接，工作手机去电未接',
#  '打电话打电话打电话打电话剔除商机。原因：空号',
#  '微信联系  客户现在不急着装修了  跟家里商量了一下  后期再说',
#  '打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话打电话无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听',
#  '打电话客户感觉利息太高了  只是了解一下',
#  '客户公司无法办理 、联系客户，',
#  '打电话客户挂断电话，应该是不需要了，还有点不方便接听拾回自跟进',
#  '移交商机给【关世维20204606】，原因：商机，给新人吧，',
#  '杜妍934792434抢了商机无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话5万，上班打卡5千，4年多了，老家自建房，车18年10月份，裸车价7年，5万，不是杭州，添加微信了，后期跟进下',
#  '打电话打电话报完家门就直接挂电话',
#  '打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听客户已经找兄弟借钱借到了，目前已经不需要，后期有需要的话会联系我。',
#  '打电话打电话打电话拾回自跟进客户现在还是需要资金的，最近在其他的地方有贷过一笔资金，估计现在客户还是需要一点资金的，现在客户有点忙，先加客户微信，微信跟客户沟通。打电话打电话客户还是需要资金，只是最近还用不到，等一段时间了需要了就跟我联系。修改商机信息',
#  '拾回自跟进无人应答或客户暂时无法接听打电话打电话做生意  对私20-30万    经营范围古建    没时间   周三打电话约时间打电话打电话今天已跟进，客户回复明日再跟进打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '打电话客户不在武汉，在恩施，没有回来打算剔除商机。原因：客户征信黑名单',
#  '打电话客户挂断电话，稍后联系打电话客户已经明确表示不需要、客户挂断电话，',
#  '打电话客户说现在在筹钱呢，打算打官司，但是客户这边之前从中信做了一笔30万先息后本的贷款，现在可能是没有办法办理的，再跟进的吧打电话打电话客户说了当时徐猛联系客户了，然后说了大概情况说他是助理，我说的律师是同一个现在就是换一下，助理，客户说了中旬15-16号 让我联系下说可能有钱办理，让余凡联系',
#  '打电话打电话打电话打电话还是个女的接的电话，没办法了哟',
#  '商务签单签单打电话',
#  '打电话17年征信有逾期 说在别的地方都做不了的  加微信给我看征信。。。。。',
#  '客户已经明确表示不需要打电话客户有意向，后期及时跟进',
#  '打电话打电话客户已经明确表示不需要 介绍了3.3的产品客户已经明确表示不需要',
#  '打电话打电话客户暂时不需要，微信发给客户了打电话无人应答或客户暂时无法接听',
#  '打电话客户已经明确表示不需要打电话打电话联系客户，回复请勿骚扰、客户挂断电话，稍后联系',
# %%
num_content = []
for line in contents:
    ret = re.match(r"\d+",line)
    if ret:
        # 去除无用的数据 如zhy180726'
        ret = re.findall(r"[a-zA-Z]{1,9}\d+",line) 
        if len(ret) > 0:
            for result in ret:
                line = line.replace(result,'')
                
        # 提取时间
#         re.fi
        
        num_content.append(line)
print(len(num_content))
num_content
# Out:
# 349
# ['03/21   、客户挂断电话，稍后联系03/26   通话中 、无人应答或客户暂时无法接听03/28  、无人应答或客户暂时无法接听',
#  '17704008890 客户不打算买房了，后面再跟进吧，觉得压力太大。',
#  '04/02  用户正忙   、无人应答或客户暂时无法接听',
#  '1898232594明天继续打打电话打电话打电话打电话客户已经明确表示不需要',
#  '1、今天已跟进，客户回复明日再跟进让同事联系 需要贷款吗挂了打电话平安兴业华夏都没批、今天已跟进，客户回复明日再跟进今天已跟进，客户回复明日再跟进剔除商机。原因：号码打不通',
#  '1111111111111111111111',
#  '03/25  已关机  、无人应答或客户暂时无法接听03/26  已关机 、无人应答或客户暂时无法接听03/28 资金需要 但是近期没时间 要出差  过一个月才回来  资金方面今年才需要   加微信说不方便03/28 资金需要 但是近期没时间 要出差 过一个月才回来 资金方面今年才需要 加微信说不方便',
#  '14点过手机打的客户不需要',
#  '3.15 可还款农行 今日处理农行资料3.26  农行出注销资料3.27  3.28 建行办理抵押  农行已经注销  预计四月初放款4.4 建行放款4.4 建行放款',
#  '15311601656 网贷',
#  '10月份在蜀信贷的 20万 月供 1000多',
#  '5w ， 做生意，有营业执照，银行卡坏了。信用卡无逾期， 最高4K。在老家。过清明回来。',
#  '03/27  、无人应答或客户暂时无法接听03/28  、无人应答或客户暂时无法接听客户已经明确表示不需要  加了微信今天已跟进，客户回复明日再跟进',
#  '4月初了解是否有资金需求  安车贷办理打电话',
#  '3.21号上门  18年信用卡连续逾期三个月网贷没批，给客户出方案提前把月供车还完拿证做抵押，持续跟进',
#  '59岁，公积金就自己交的1千，法人是老婆，房子在下城区，要退休了怕的不愿意加微信，现在就是咨询修改商机信息今天来了，公积金只有480，下城区房子是夫妻共有，浙商跟民生的行长是朋友，不想欠人情以为我们这边一个电话就下30万的，59岁也不想让老婆跑来跑去。长期维护',
#  '5千，做工程的，有银行卡流水、、、、、、、、',
#  '30万，上班7千现金，社保3年，保单3年2份年缴3千的，房刚刚按揭，还没有供，12月贷款十笔，已上门客户',
#  '1w，下个月需要，个人消费，上班代发，社保公积金，4-5k，在东莞，下个月回广州拾回自跟进',
#  '10多年友邦 年缴7000 经营场地在东莞 1年多了营业执照医疗流水一个季度50-60w 全款房房子280海珠，独有但是房产证这些在老婆那里也不能让老婆知道 平安做了保单批21w今天3月 交通银行12w快还玩了1年期 信用卡25w 车子13年了。 年后在看，其他机构去了5-6家没有做下来加微信发征信报告确定能不能过',
#  '21岁，需要2千，在綦江。加微信跟进中。跟客户微信沟通，一直不明确是否能办理下来，说了可以办理，觉得是骗子。后期表示不需要了。剔除商机。原因：客户表示不需要。',
#  '1、客户挂断电话，稍后联系',
#  '1客户暂时还不需要资金周转',
#  '03/28   、客户挂断电话，稍后联系 2次今天已跟进，客户回复明日再跟进',
#  '70，法人1000,40%房，车按揭车拾回自跟进客户说姓路跟进客户想要70法人打电话打电话w、无人应答或客户暂时无法接听打电话客户说现在不考虑资金秒挂了、无人应答或客户暂时无法接听',
#  '2万日常消费，尽快，桥头上班，打卡工资4800-5500左右，社保1年多，支付宝人寿保险，征信黑户，',
#  '04/03  、客户已经明确表示不需要',
#  '03/21  、无人应答或客户暂时无法接听',
#  '04/01   素质比较差的客户',
#  '4号已上门签约，进件友信客户不配合录单，删微信',
#  '3.26号瞿富洲才跟进了，过于紧密',
#  '13918221749客户再上班，加微信联系，搜不到打电话',
#  '2017-12  客户本人做生意的，后面要开店周转，广州越秀区房子104平方，在民生做了抵押，批了480万，客户当时只需要70万，做的先息后本，明年3月份还款，、2017/12/19  客户上门：客户本人做生意的，开快餐店，营业执照2年多，缴纳税4千多，流水大部分现金，流水差不多20多万，客户负债：信用卡30万左右，微粒贷3万，但是没有怎么使用，负债不怎么高，客户资产：越秀区房，价值7-8百万，可以贷款4-5百万，客户本人再民生银行贷了130万，60万拿出来用了，70万留着还60万的款，操作的6.4厘利息，知道保险费用，我们推的随借随还，利息4-5厘，100万以下不需要保险费，100万以上没加一百万1个点保险费，4-5%，杂费等5千左右，服务费2.6%，垫资40万，包月2分息，拾回自跟进今天已跟进，客户回复明日再跟进',
#  '5千用于急用，今天要用，晚上摆地摊，通讯行业，工资4-5千，底薪打银行卡。社保一年多，还没社保卡，350，人寿年缴2000有一年，顺德，加微信，',
#  '04/08  下午3点到无人应答或客户暂时无法接听签单',
#  '03/28、客户已经明确表示不需要今天已跟进，客户回复明日再跟进',
#  '20万 易捷   8.4%  已签  流程中黄刚 补资料过程中  、客户有意向，后期及时跟进今天已跟进，客户回复明日再跟进  在补资料中今天已跟进，客户回复明日再跟进  客户在流程中今天已跟进，客户回复明日再跟进   做不到 后台回复  负债太高了',
#  '03/28  、客户已经明确表示不需要今天已跟进，客户回复明日再跟进',
#  '3-4万 上班的 固转8k 社保300 单位工作两个月无资产 平安的保单一千多 两个月 微粒贷额度5k拾回自跟进',
#  '1万，永川做生意，有执照，有流水，加微信 。修改商机信息',
#  '10万，越快越好，在火车站那边上班 ，代发一万，有社保公积金，没什么贷款，说本月要用，一说上门就挂机了，再打不接打电话无人应答或客户暂时无法接听 拒接无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '23号回访了解情况 25号办理打电话无人应答或客户暂时无法接听打电话620芝麻分   2个网贷  拍拍贷 去分期     征信有点花  很多网贷没下款  担心没有资金办不下来  约定周五再回访打电话中午回访 上午不方便。打电话打电话打电话无人应答或客户暂时无法接听  短信微信跟进了解状况打电话找爸妈解决了 今后再开发',
#  '11、客户有意向，后期及时跟进打电话打电话是张军旗本人，一提到贷款就说打错了。',
#  '03/27  、客户已经明确表示不需要今天已跟进，客户回复明日再跟进',
#  '04/02 现在在忙，晚点在联系吧04/03   、无人应答或客户暂时无法接听',
#  '2019年4月8日10:46:31：你拨打的用户正忙',
#  '3-4万，上班打卡5-6000，有社保600公积金900多，2年，保单2000,3年，太平洋保险，无微粒贷打电话不需要了，解决了，3-4万，上班打卡5-6000，有社保600公积金900多，2年，保单2000,3年，太平洋保险，无微粒贷',
#  '2018-6 客户有3栋房子收租，但是都不是自己名下的，30号作呕收租，一个月3万左右，客户想贷50万，不想去办理私人的，之前去银行了解过，但是时间太久了，要一个月，跟客户说我们只需要2-3个工作日，客户想考虑一下拾回自跟进今天已跟进，客户回复明日再跟进',
#  '3.22日跟进........打电话打电话客户已经明确表示不需要明确不需要，下周跟进。。',
#  '2013年月供3000元，不动产证，什么怡都世家87平米，客户在医药公司上班待遇客户，贷款用途：给姐姐买房子，不要姐姐还钱。需要60万，和老婆商量一下，下周直接做决定，再联系，在确定上班时间。',
#  '18981993887\u202c  客户在开车客户挂断电话，稍后联系打电话打电话给客户联系秒断。。。。',
#  '11、客户有意向，后期及时跟进打电话以助贷网打电话，客户说自己是三非，咨询了很多平台都做不下来。',
#  '5千  要借建设银行  一个还25利息  还一个月就可以可以了   说银行五万起贷  说找朋友借一下剔除商机。原因：不需要',
#  '04/01   、拨打电话提示客户已关机',
#  '2万，近期，上班，打卡每个月1万，没有社保，公积金，很久，陈哥，客户在成华区，先发短信，明天确定上门时间，客户说也确定不到上门时间。客户估计不想办理线下打电话打电话打电话打电话打电话打电话无人应答或客户暂时无法接听打电话打电话客户说现在不需要贷款不是不是，客户现在很忙，晚点和客户联系，不晓得咋个大了个不需要贷款。打电话打电话客户拒接。客户拒接。客户拒接。打电话打电话客户拒接本次 通话。客户拒接本次 通话。打电话打电话客户拒接本次通话中。内部移交。',
#  '1234567974 不打电销分配',
#  '1万生活消费，尽快，做生意十多年执照，下午3点左右再打，客户现在不方便1万生活消费，尽快，做生意十多年执照，流水一万一个左右，厚街上班打卡工资6800，社保8年，客户不觉得远不方便过来，要考虑一下，陈辉',
#  '2018.9.30神灯放款59万，3年期先息后本',
#  '5万，上班，现金工资4-5千，信用卡8千，没有微粒贷，芝麻分不记得，但说人在珠海不在北京。已经添加微信。无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听',
#  '2万，装修用，一个月，上班收入3-4k，没房车保单，社保.....也不方便别人知道剔除商机。原因：客户三无',
#  '03/26   客户挂断电话，稍后联系03/28   、客户挂断电话，稍后联系03/29  、客户已经明确表示不需要今天已跟进，客户回复明日再跟进',
#  '20W   有保单   年缴三年',
#  '1万，不确定，消费。上班10个月工资4500，无条件。剔除商机。原因：客户三无',
#  '111111111111',
#  '5万尽快，投资。刚从老家出来上班10多天，无条件。剔除商机。原因：客户三无',
#  '04/01  、无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '03/22  税前8千  税后5千社保公积金都有 工作6年  有车贷  近期在厂里面忙，过几天才有空03/25  微信上说 近期店里比较忙 抽不身03/26  客户挂电话  、无人应答或客户暂时无法接听03/28   客户公积金基数11419   说这个星期没有时间  要到下个星期03/28 客户公积金基数11419 说这个星期没有时间 要到下个星期',
#  '2200保单不符合保单进件要求做不了',
#  '20号才能确定 现在还在打官司',
#  '4月29号之后可以办平安了 持证满3个月',
#  '61周岁 上班有社保公积金 打卡4500 年级大了做不了返无效,原因：客户年龄不够 61周岁 年级偏大 无房子 做不了打电话客户已经明确表示不需要不听不给说话机会',
#  '04/01   、客户已经明确表示不需要 说房子还没有搬迁今天已跟进，客户回复明日再跟进',
#  '04/02  一个男的接的   不需要',
#  '70了，想做退休贷，退休金4千，明天上门打电话打电话用10,万，下周一看时间吧.....打电话',
#  '2百万，  准备做生意， 下城区公寓，市值200万 ，按揭每个月还5000左右，尾款30万，车子全款110万左右 路虎揽胜 一年左右 浙A',
#  '4万 上班收入7千，打卡上，本单位社保公积金7年，房子是夫妻共有，老婆不方便知道，车是全款的，国庆刚买的，发票价9万，报了5厘利息，客户说自己办理的支付宝微信里的产品3.4厘，好像有当前逾期。。。。。。。。。。。',
#  '03/22 说自己征信不好  我说做车贷不看征信的   客户说  他的是按揭车  月供3~4千  3个月   近期忙 没时间03/27  以上门 想贷20w  按揭车 月供3千 安徽牌  发票价11w   6个月  车子在老家    全款车10w  10年 粤a牌   物流司机   大地被拒过   只能押车   刚刚开始报小贷利息就不接受了无条件办理了  大地被拒绝了',
#  '0万，比较急，上班的，国企，公积金自己交300多，代发工资三千多，有信用卡，有车贷，花都那边上班，拾回自跟进',
#  '65周岁，有个小公司，退休3k，越快越好，约周一67岁...年龄太大做不了商务签单剔除商机。原因：客户年龄不满足要求签单',
#  '19号手机联系了，暂不需要',
#  '77777，黑名单。9月回家 还款信用社。 77777，黑名单。9月回家 还款信用社。',
#  '4000微粒贷 社保有半年 03年信用卡逾期到现在都没有还剔除商机。原因：客户征信黑名单',
#  '5万，上班现金7千，QQ微粒贷7千，已上门不接受利息费用，告诉以后降费用，让不要申请贷款先',
#  '18117845611曾植， 这个 是曾值介绍的啊699啊，你怎么回事呢。',
#  '03/27  打不进  、无人应答或客户暂时无法接听04/01  、无人应答或客户暂时无法接听',
#  '2年前逾期2个多月，把房子垫资出来 刚押在机构放了80万，房 估值120万，微粒贷 8万。中银15万。自己5月前点了很多网贷，给他报了方案1.5利息他完全不接受聊不下去，说我们这边还要收手续费 不如自己做中邮了。不如用他老婆借了',
#  '24号再联系........又去外地了，目前项目刚启动资金还不是很急，保持联系吧，说是清明前两天左右会回来',
#  '1万。在跑滴滴车在公司名下。上班现金6000多。支付宝590，有信用卡8000+5000，征信条件很好。已加微信。打电话打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '2019-01-09 14:44:36\t商机\t跟进\t\r\n客户需要4万，这几用到，自己做装修，没有营业执照，因为是在公司接单的。自己做。名下无房子车子保单，微粒贷。信用卡，1万。去年逾期了1万，一个月，，芝麻分600多 客户是深圳的做不了。\r\n\r\n-打电话拾回自跟进打电话打电话打电话打电话打电话打电话呼叫受限制，请稍后回复',
#  '3.22日跟进........打电话打电话之前说进半个月需要，添加了微信没同意。打了电话再次添加',
#  '5-10万 做生意 执照7.8年 月流水1.2万 保单年缴5-6千 买了2年 客户在潮州     客户目前回老家了 等清明节后再办理 8号再确认时间',
#  '3万 上班打卡月工资3000-5000 无社保公积金 缴满了 无固定资产 无信用卡  有捷信网贷3万 嘉定区  暂时不要,要考虑吗打电话打电话微信对接 客户有微粒贷7000正在使用 5-6万 下个星期过来办商务签单签单',
#  '3.19备注 有贷款意向 做生意 有 5年了 收入保密 有交税 做家装市场的       房子 按揭 建行 贷款金额60万 月还款12000  没拿到房产证   车子个人的 17年买的  28万   加微信详聊打电话打电话客户已经明确表示不需要',
#  '2018年客户需要10万，不着急，贷款给妈老汉儿用，父母要给自己买套房子，自己准备和女朋友结婚了，夫妻名下有个全款合同商铺，现在每月打卡2300，提成发的现金，有个按揭车明年才还完，信用卡有2万多的额度，支付宝700多分，加微信',
#  '8、无人应答或客户暂时无法接听打电话约明天上午十一点钟来办理，客户不确定能不能来，明天一早打电话跟他确认。',
#  '04/03   、无人应答或客户暂时无法接听',
#  '101111111111111',
#  '2019年3月27日12:54:02：回访未接电话移交商机给【冯贵森103460】，原因：2019年3月27日13:06:59：部门流转资源，今日内必须跟进完毕',
#  '11、客户有意向，后期及时跟进打电话',
#  '04/01  、客户已经明确表示不需要    工作代发工资10000多，工作8年，有全款车，做生意的，占股份4层。中国银行流水几百万今天已跟进，客户回复明日再跟进',
#  '1.潼南需求10万.  2.招投标公司（法人自己的）  3.按揭房电梯房一年（月供1500左右）  4.按揭车。  名下无其他负债。打电话客户已经明确表示不需要',
#  '1客户挂断电话，稍后联系',
#  '10万，尽快用，上班，无社保，发现金8000，无保险，无房，有按揭车，7万左右，无微粒贷，先考虑一下，先加微信再约打电话停机了、今天已跟进，客户回复明日再跟进打电话剔除商机。原因：号码打不通',
#  '3.21号活动上门的，做不到的，查询很多剔除商机。原因：客户征信黑名单',
#  '18    02   08需要1-2万，上班发现金。20多年的社保。 58年的，640分，荔湾区。        18   02   9签单',
#  '2万日常消费，尽快，开货车的上班，打卡工资25000，没有各税，农村社保，客户在开车，',
#  '1、 3万  2、现在要  3、自己打卡10000多 公积金833工作七年 邀约客户上门办理 ，客户不接受立马挂电话  4、挂断电话  发送短信打电话打电话客戶直接就把電話給我掛掉了，哦豁勒打电话打电话客户挂断电话，稍后联系  恼火求得很',
#  '2018-12-18 19:08:38\t商机\t跟进\t\r\n上班现金7-8千，老家自建房，按揭车6万，还有七八个月还请，问了利息报了3-8厘，说八里高了，说很多3-5厘，他朋友就是5厘，只有星期六天才有空，平时比较忙\r\n\r\n-拾回自跟进打电话打电话打电话呼叫受限制，请稍后回复',
#  '60岁老人了，离异，想要十万块，手机不是微信，已发送到短信，明天打电话，让来了解一下，下周一来，清明节老人不方便来，。啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊打电话打打打。干爹60，今年九月份过生日，想做信贷了现在，。打电话来过了，抵押最低20，想要十，没办法，在考虑一下，',
#  '11、客户有意向，后期及时跟进打电话拨打电话提示客户已停机',
#  '3.15上门签单 博民 客户不愿意跑不办了打电话打电话',
#  '2018-7-12  本单位上班6年，税后8000，4年社保月缴300，黄埔按揭房一年多，首付40多万，月供4100，信用卡没逾期，近一个月网贷多，征信花拾回自跟进今天已跟进，客户回复明日再跟进',
#  '1,记得抓到可贷点就及时进行邀约，客户只要5万，了解到有转账工资和社保就不需要问太多其他的了，问的太多了2.电话里除非客户自己跟你说点了网贷，否则不要主动去问，会降低客户的信心。3，在了解到可贷点就给客户出一个初步方案然后再进行邀约   优点：服务态度很诚恳',
#  '03/25 就说不需要了  就挂了打电话04/09    、、无人应答或客户暂时无法接听',
#  '140多平，怕审批通过了，放不了款微信邀约 、客户有意向，后期及时跟进打电话打电话现在不方便说，换时间微信说 垫资成本包 、客户有意向，后期及时跟进房子自己没收房，没有办房产证，要等一年拿1月份的征信，近半年信用卡5次逾期，平安1次。  建行按揭房16年10月，月供4200，平安19万月供6903上午联系 、客户有意向，后期及时跟进',
#  '03/21  之前的情况 需要30万的， 这几天都可以的，占股51，营业执照几年的，流水不知道多少的 ，全款房来的， 在阳江的， 全款车来的，139万的， 奔驰450，买了2年的， 明天早上10点半过来的，没有问其它的今天已跟进，客户回复明日再跟进',
#  '5月份左右再过来.........在微信跟客户报了车贷利息8-1.5分 客户五月份再过来办理',
#  '03/28  有意向  加微信 约下周无人应答或客户暂时无法接听',
#  '2019年3月29日15:51:48：客户每个月发工资时15号，8-9千，客户自己申请的信用卡的没有办下来，网贷客户自己有几十个平台，有几个正常还款的，加起来有1-2万。就是想贷款买车，我有报零首付购车的方案。2019年3月29日15:51:48：客户每个月发工资时15号，8-9千，客户自己申请的信用卡的没有办下来，网贷客户自己有几十个平台，有几个正常还款的，加起来有1-2万。就是想贷款买车，我有报零首付购车的方案。移交商机给【谭义昌103890】，原因：资源流转',
#  '04/10  说回老家  ，朋友借了他50w   ，现在不需要啦    但是问利息  我报8厘~1.2分   客户利息高',
#  '0手续费活动短信...',
#  '11、客户有意向，后期及时跟进打电话征信垮掉了，近三个月点了四五十笔贷款都没有下来。',
#  '1无人应答或客户暂时无法接听修改商机信息',
#  '137号码说贷款秒挂，。。。',
#  '2019-01-14 10:37:41\t商机\t跟进\t\r\n客户是只有微粒贷1千，支付宝500多，友信系统准入不了的，无条件\r\n\r\n-拾回自跟进打电话打电话打电话打电话呼叫受限制，请稍后回复',
#  '1稍后跟进、联系客户，回复请勿骚扰',
#  '1，需要100万，近一周需要，想换房子，看重的房子马上要开盘了，小朋友上学开学前落实好!2,科学城外企上班9年，税后2万多，社保公积金缴费高，公积金一共7000每月。3，番禺亚运城按揭房6年（想明年3.4月份卖掉），月供3千多，有证，也有按揭车。4，在建行了解有随借随还的30万额度，6.3年化利率。我报利息5厘左右（客户听到觉得比较低），主要看评分。想办理不影响后面房贷的贷款，说了有不上征信的。5，费用没聊到，看看明天下班过来了解下，不想带资料拾回自跟进今天已跟进，客户回复明日再跟进',
#  '4月份几号回成都 说的跟我联系无人应答或客户暂时无法接听',
#  '03/26  有意向  报5~8厘  约明天 说看看03/27 用户正忙  、无人应答或客户暂时无法接听',
#  '5万，打卡8000-12000，保单一份一年半，另一份不到一年，两份一起一万多，打电话打电话未接，5万，打卡8000-12000，保单一份一年半，另一份不到一年，两份一起一万多打电话打电话打电话打电话未接，5万，打卡8000-12000，保单一份一年半，另一份不到一年，两份一起一万多',
#  '5万左右 没用过信用卡 外地按揭房刚还了第一期 开装修公司 占股百分之2 单位社保半年 有座机 全款车 河北牌照 裸车价10万 16年买的 利息报了1.5 服务费没报',
#  '03/26  报3.3  有意向   加微信  过二天过来办理03/26  微信搜不到  打电话不接03/27 打二次 、客户挂断电话，稍后联系',
#  '6点 在联系、客户有意向，后期及时跟进',
#  '2018.6.13 上班工资有时现金有时转账，有社保，7-8年。安盛保险，7-8年，1.9万年交。车子粤B ,28万车价，开了8-9年，有信用卡，、无人应答或客户暂时无法接听打电话现在在忙，晚上6点半给他电话',
#  '04/08   、客户挂断电话，稍后联系打电话04/08   、无人应答或客户暂时无法接听  午打电话04/08  、想贷1我 近期需要 开理发店的  三无 约上门说看看时间打电话打电话剔除商机。原因：客户三无',
#  '3.18号的跟进打错了！！！外呼显示的是另一个客户的名字、客户已经明确表示不需要剔除商机。原因：客户三无',
#  '1111111111111111111111111111',
#  '2019年3月25日14:33:04、客户挂断电话，稍后联系移交商机给【谭义昌103890】，原因：资源流转移交商机给【田闰香103930】，原因：2019年4月8日16:37:38资源移交，24小时内必须跟进完毕',
#  '3万，上班，送外卖的，6000转账，无社保公积金，无保单微粒贷，无房无车，剔除商机。原因：客户三无',
#  '3.20自己私人拆借  不需要了',
#  '3万签了3000 客户无法办理 查询过多 社保公积金不够时间',
#  '3.22日跟进........无人应答或客户暂时无法接听打电话打电话打电话剔除商机。原因：征信有问题，办理不下来',
#  '4月初再跟客户联系 直接约时间打电话客户还在深圳 还没回佛山乐从  贷款也不着急  等他回来再说',
#  '315已经上来操作不了商务签单',
#  '2018年4月8号，客户8个月的保单，上班现金，平安普惠无额度，大地恒昌做不了，',
#  '1.24重庆小新城按揭房， 还了3个月， 月供1900，全款车13万，开了3年多，自己是做工程的做外墙的，开年需要资金，因为有新的项目要投资，资金2.3月份用，发了短信，姐姐多好说话的。、客户已经明确表示不需要拾回自跟进打电话打电话',
#  '3.22日跟进........打电话打电话70多岁的老爷子了，但是懂得确实还是比较多，这边办理过没有办理下来',
#  '03/25   一直说在开会忙    说先停一下03/28  约明天的时间  没办法确定  晚点在联系',
#  '3.22日跟进........打电话打电话老大跟进，预计周三上门',
#  '1111111111111111',
#  '18502802139打电话打电话无人应答或客户暂时无法接听',
#  '04/01  、无人应答或客户暂时无法接听04/02   、无人应答或客户暂时无法接听04/02   、无人应答或客户暂时无法接听剔除商机。原因：客户三无',
#  '2017-09-21胡浩备注：推荐了4厘的建行分期通和小顶贷，但是客户没有需要 10-10：推荐了随借随还，但是还是不需要……之后一直没联系上打电话打电话手 机打了，依旧关机关机',
#  '1拨打电话提示客户已关机',
#  '11、客户有意向，后期及时跟进打电话以助贷网小刘打 客户说现在很忙，资金需要还不确定，晚一点再和客户联系。打电话客户在吃饭，可能要喝多了，明天早上电话。',
#  '0手续费活动短信......',
#  '1、客户需要 3~5w，近期用钱。2、做生意的执照2年，月流水300w，年开票300w+。 在从化城中村有自己建房2栋价值800w左右，不动产权证没下来。没有微粒贷信用卡5k额度，小花钱包3k。客户想申请的是网贷，开场白就问是不是下线放款，不想跑过来了觉得麻烦，上门需要考虑一下',
#  '11、客户有意向，后期及时跟进打电话客户里面很杂乱，等会儿再打。打电话客户还没有回上海，要20号的时候才回来。',
#  '04/01   、无人应答或客户暂时无法接听',
#  '711    ',
#  '3/28已经周转过来了，不需要无人应答或客户暂时无法接听',
#  '2-5万，这两天，自己开工作室没有营业执照，保单，给别人买的，三年五千多，客户在大良那边，先加客户微信',
#  '04/03  明天去打征信和流水   星期一过来办理客户增城人  后台评估223万   按揭工商 还欠86万  征信流水都打好了  现在在广西玩明后天才回来   明天致电',
#  '63岁，亚联财拒了，做不了商务签单剔除商机。原因：客户三无签单',
#  '10个点已经下款3万，再重新发了还款明细',
#  '1拨打电话提示客户已关机修改商机信息',
#  '10/20客户社保5年了，但社保账号密码忘记，客户联系不上，拖了两星期，无法操作，待前台联系上重新进件，先退单。客户要去银行吧社保账号密码改回来，明天去电催进度拾回自跟进账号搜索异常，短信已发打电话农行代发3千多，13年社保 无资产物业公司上班，社保还没有改，不需要资金打电话打电话',
#  '10万，万州个体户，无营业执照，月收入8千-1万，有个按揭房在建行按揭起，还了5年了，月供1500左右，打算拿这笔钱来资金周转一下，十天以内要这笔钱，继续跟进。打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听打电话客户说这几天都在忙起，等忙完了再安排时间过来办理。打电话客户还在忙起，约下周一过来办理。打电话无人应答或客户暂时无法接听',
#  '1万，今天过来，打卡工资5000签单',
#  '0手续费活动短信.....',
#  '03/28  有意向  加微信',
#  '1万，之前在无锡上班，有打卡工资4千，才回来重庆上班不到一个月，才买了社保，明天下班后过来打电话客户微信回复不确定上门时间打电话无人应答或客户暂时无法接听',
#  '3.22日跟进........打电话打电话后期有一定的需要，想深入了解，直接加了微信没同意，再次添加。后期跟进怀疑同行，这边加了微信也没说话，朋友圈也没有动态。',
#  '2019年4月8日10:48:08：罗先生，准备贷5万左右，佛山三水区上班，给客户说初始额度通过，直接邀约客户上门。',
#  '3.22日跟进........剔除商机。原因：已经办理过了，没办理下来，留有微信',
#  '2019/3/252工作手机打2次没接，2018/12/07车房无，做生意，流水10多w。平安保单4000，5年。现在名下有小贷。快结清了。这两天没空。星期天邀约报了2.8服务费',
#  '3.22日跟进........剔除商机。原因：之前办理了，没有办理下来，条件那些都不行。做不了',
#  '04/01  、无人应答或客户暂时无法接听',
#  '2019年3月25日14:32:13：、客户挂断电话，稍后联系',
#  '3.15上门，征信差的不行',
#  '3.21：客户做许可证，现在在落实自己的渠道。3.22：下周开始逼单。3.25：客户自己的渠道还在等回复，看那边情况。我们的成本太高，看下个月会不会调整。',
#  '18502802139',
#  '58了已经退休了，、客户已经明确表示不需要打电话打电话打电话打电话',
#  '03/26 说小顶金融的  就直接说不需要',
#  '04/08  现在在忙  晚点在联系打电话打电话打电话打电话打电话04/09   、拨打电话提示客户已关机打电话打电话04/09   客户说自己很难整的  办理不下来剔除商机。原因：客户三无',
#  '03/21   客户挂我电话剔除商机。原因：客户三无',
#  '11、客户有意向，后期及时跟进打电话打电话跟客户说合作的银行新出的产品 给我们公司独家渠道，利息还是按照银行的利息，对于客户的条件放宽了很多，客户要晚上跟老公商量一下，看后天有没有时间安排，明天上午给她电话确认一下后天来办理的时间。',
#  '0手续费活动短信....',
#  '03/27  通话中 、无人应答或客户暂时无法接听03/28  客户挂我电话今天已跟进，客户回复明日再跟进',
#  '3.22日跟进........打电话打电话客户已经明确表示不需要',
#  '98年的小孩，近3个月查询50多次，做不了的，没有别的资产，就打卡4000，有社保，公积金334，一起600多98年的小孩，近3个月查询50多次，做不了的，没有别的资产，就打卡4000，有社保，公积金334，一起600多打电话打电话98年的小孩，近3个月查询50多次，做不了的，没有别的资产，就打卡4000，有社保，公积金334，一起600多打电话打电话98年的小孩，近3个月查询50多次，做不了的，没有别的资产，就打卡4000，有社保，公积金334，一起600多',
#  '1客户暂时还不需要资金周转修改商机信息',
#  '2018-01-10转介绍：需要一百万 这个月可以要 自己在出差 自己是做建筑的 知道不好办 限制行业 自己朋友有一个全款房 一个全款合同房 房子七八成一百万没问题 利息说的五六 费用说的二 可以少 别的公司说的一个点全包 利息五厘多 让他去对比 到处都在问 下午在联系 如果可以让他朋友下午来 1-11：他朋友给我打了电话，说如果情况好 那就1.5到5 他给他朋友沟通 1-15：莫总朋友 黄姐明天来 房产证再别的公司押着的 业务员以总监不再的名义 今天拿不到 1-24：米贷申请了 评估了 因为费用2个点 所以客户不做了 签的1.8个点 执照0.5年 有场地 卖红酒好多年 流水一个月一两百万 只要随借随还 不要先息后本 3-15放款：李佳潞抵押放款先息后本信贷，不需要，手 机已发授信短信，下次缓跟，直接备注',
#  '3-5w  尽快  上班现金6-7k  没有资产  没有贷款，没有微粒贷，之前来过公司，加微信  保持跟进   约了周一上午来公司。打电话客户已经在来的路上了。保持跟进约见打电话已经到公司楼下   马上上楼了。没有任何资质  网贷点了很多  家人不能知晓贷款  去年12月份 来过公司 没有办成 目前这个客户联博明都办不了打电话打电话回访客户  目前确实没有什么资质可以做   只能等一段时间在试试网贷吧。无人应答或客户暂时无法接听',
#  '1、拨打电话提示客户已关机打电话无人应答或客户暂时无法接听修改商机信息',
#  '1、代发工资4k左右，有社保2年。无其他。加了微信后期跟进。打电话无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '0手续费活动产品短信.....',
#  '11111111111111',
#  '111111111111111111',
#  '1.客户湖北人，给老板开车，现金6千，无社保公积金，2.湖北按揭房供6年，月还几百块，市价20多万，没回去拿证，3无车，人寿保险年缴1400，2年缴2次，3.无微粒贷，4.需要5万，消费越快越好，微信号13986608138. 没空间做。保险缴费和房贷月供金额达不到要求',
#  '1万，还没问完就挂了，用手机打过去，说不方便通电话。。。。。加微信加了微信了，公积金个缴一百多，说要过来办理就算了，不在主城，，，，，打电话',
#  '2018-12-18 16:49:51\t商机\t跟进\t\r\n需要3万尽快，上班，公积金185，代发4K多，信用卡当前逾期两三个月\r\n\r\n-拾回自跟进打电话打电话呼叫受限制，请稍后回复',
#  '03/27  客户还是有意向  加微信  近期做生意比较忙   报5~6厘04/10  说忙，没时间  、今天已跟进，客户回复明日再跟进',
#  '15天.............。。。。。。。。。。。。。。。',
#  '04/02   、无人应答或客户暂时无法接听',
#  '11点左右到公司..商务签单打电话打电话无人应答或客户暂时无法接听',
#  '2017-10-14首电：需要2万，名下有套按揭房，已还款几年了，月供1500，利息费用未报，上班发现金，周一上午来办 10-16：今天临时办事，明天过来，第二天又来不到 10-30：贷款用来装修房子，暂时不需要了 换人跟，截止4.11号都不需要陌电手 机打了，当天拿钱，不需要，下次缓跟，直接备注',
#  '04/02    、客户挂断电话，稍后联系无人应答或客户暂时无法接听',
#  '5900 工资 社保最低300多，11个月了  北京九合正中建筑设计事务所 （普通合伙）',
#  '3.22日跟进........打电话打电话客户暂时不需要，后期持续跟进，已添加微信',
#  '4月一号再联系。、客户有意向，后期及时跟进无人应答或客户暂时无法接听',
#  '3千，现金1500保安，最近需要，人在都江堰的小镇，母亲住院，说没时间白天工作又要照顾母亲，不办理了没时间打电话打电话客户已经解决，不需要咯客户有意向，后期及时跟进无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '03/28  安排了东莞的同事对接啦   过几天上门',
#  '15183679770',
#  '04/02  近期不差钱，不需要谢谢无人应答或客户暂时无法接听',
#  '4月中旬在联系一次 目前不需要4月中旬在联系一次 目前不需要',
#  '9越快越好，没工作，保单无，微粒贷，车9万多，韶关的车，3年15.8，目前在天河区，说不想出门，不想去繁华的地方',
#  '1、无人应答或客户暂时无法接听修改商机信息',
#  '3.28 中信放款 3.28 中信放款商务签单商务签单3.28 中信放款 3.28 中信放款  4.1号 建行扣款3.28 中信放款 3.28 中信放款 4.1号中信扣款',
#  '1万尽快，投资。做生意执照10多年，客户说执照过期了没年审，其他条件没有。',
#  '11、客户有意向，后期及时跟进打电话客户已经明确表示不需要',
#  '2019-04-01 \r\n借两三万。目前是在员村上班，去年年底刚刚入职的，餐饮工资上午不上班，下午上班， 税后工资七八千，公积金没交，没资产，信用卡额度一万，光大的，没有微粒贷，邀约两次一是今日下午五点，要上班来不了。二是明日上午十点，已确定，邀约已发出，报了一到三个点的手续费，银行放款，手续费放款的同时银行代扣，以上客户都接受\r\n\r\n-2019    4    2  号预约在今日上午10点面谈 ，客户没有赴约，发微信问候且试探客户情况，客户没回复，打电话没接，表示在通话中。。。。。。在跟进',
#  '4月3号联系.....',
#  '03/25  有意向  保单只有半年   说一个星期后才有时间   发地址先',
#  '04/08  说远不想过来了   、、今天已跟进，客户回复明日再跟进',
#  '5万，在永川开店，有营业执照2-3年了，流水2-3万，在老婆名下的流水。想要拿5万去装修和开多一家店，越快拿到这笔钱越好，今天没得时间，最近在忙开店的事，有空抽时间过来再跟我说。打电话无人应答或客户暂时无法接听打电话无人应答或客户暂时无法接听',
#  '3.21上门谈没谈好，只给2个点手续费，又说利息高，不是先息后本的，自己做生意的，有营业执照，以女儿名义注册的，做服装的，退休，55岁，去年开了200万的票，交了4万多的税，微信13585946435打电话3.21上门谈没谈好，只给2个点手续费，又说利息高，不是先息后本的，自己做生意的，有营业执照，以女儿名义注册的，做服装的，退休，55岁，去年开了200万的票，交了4万多的税，微信13585946435打电话3.21上门谈没谈好，只给2个点手续费，又说利息高，不是先息后本的，自己做生意的，有营业执照，以女儿名义注册的，做服装的，退休，55岁，去年开了200万的票，交了4万多的税，微信13585946435打电话打电话打电话未接，3.21上门谈没谈好，只给2个点手续费，又说利息高，不是先息后本的，自己做生意的，有营业执照，以女儿名义注册的，做服装的，退休，55岁，去年开了200万的票，交了4万多的税，微信13585946435',
#  '18  02   07需要1万，上班发现金。每月4000,577分，在番禺区。信用卡有逾期，介绍了一个朋友过来做车贷。明天过来办理    18  05  21客户不需要      19   03  26呼叫受限，稍后再拨打电话',
#  '04/01  、客户已经明确表示不需要今天已跟进，客户回复明日再跟进',
#  '15-10万元 买车用的商务签单等着结果...........今天说发征信给我看看等着发征信来给我看看签单同客户商机成单掉库打电话客户有意向，后期及时跟进无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '3月25号用工作手机号拨打了，无人接听打电话所有线路在忙，请稍后再拨',
#  '2019年3月25日14:31:16：来电提醒功能',
#  '5万生意周转  尽快，有执照十多年了，流水一个月2-3万左右，客户说了自己没房没车没保险，下午再联系5万生意周转 尽快，东城石井有执照十多年了，流水一个月2-3万左右，客户说了自己没房没车没保险，客户已经去过很多公司做过没有办理下来，而且也点做很多网贷',
#  '10万 现金6k 微粒贷 保单 公积金都没有同行 加微信是同行、今天已跟进，客户回复明日再跟进剔除商机。原因：同行 有截图为证、客户三无',
#  '16年买的MKX 买成60多万，目前川A拍照，爸爸户下，要过户到表哥名下，因为要卖牌照，拍照有点好，可以卖10多万。需要40万，评估价26万，过户后只能做1分15的5成和押车才能满足30多万额度。押车一个月1分，2个月2分。有客户微信的，随时问到进度。无人应答或客户暂时无法接听 下次打电弧问他过户了没有，关心一下无人应答或客户暂时无法接听 手机拨打挂断了 给我发了条短信 说这几天在忙，问他车子过户没有，没回复微信在联系此客户的，，，，无人应答或客户暂时无法接听打电话打电话无人应答或客户暂时无法接听打电话打电话打电话打电话说他最近忙的很，到时候给我打电话。。。无人应答或客户暂时无法接听',
#  '60多岁了，，三无.....',
#  '8无人应答或客户暂时无法接听返无效,原因：首次联系表示未咨询',
#  '5000尽快，租房。上班2个月工资2800-3000，无其他条件。剔除商机。原因：客户三无',
#  '20万 在中山 桂林有全款房 。。。。。。。。。。月底回来',
#  '3万，做生意，有营业执照，在彭水，抵押房，做的先息后本，近期要都可以，蔡老师，，，，加微信，，，邀约打电话说最近没得空，有需要的时候再过来。。。。。',
#  '04/02  、、客户已经明确表示不需要  加微信',
#  '111111111111111',
#  '2~3w，打卡四五千，有社保无公积金  征信很差  去年社保贷拒了 友邦保单1年多，大良商品房，按揭快供完，客户不愿意到公司面签   15天。。。。。。。。。。。。。。',
#  '8万尽快，客户说信号不好，下午再联系4.9   需要8万投资，尽快，何先生，做生意没有执照，实地三年了，流水10万，湖北老家全款房，客户现在出差在珠海，大概是后天回来，约了后天下午3点',
#  '3.15来过公司，自己有一块不确定。。。。。。想了解一下。。',
#  '12月亚联财。。。正常使用',
#  '2月份又放款了一笔  、客户有意向，后期及时跟进',
#  '11、客户有意向，后期及时跟进打电话7点半给客户电话，客户现在不方便打电话打电话无人应答或客户暂时无法接听，发了短消息给客户，明天上午联系。',
#  '4里多先息后本现在不太需要挂了打电话打电话客户已经明确表示不需要',
#  '2018-12-19 09:50:29\t商机\t跟进\t\r\n客户需要10万。最快用到。广州做生意。有执照。法人。餐饮。无流水。名下无房子车子。有保单，招商信诺月缴94元，现在停了，客户是之前来过我司办理。客户有微粒贷2000，有信用卡\r\n\r\n-拾回自跟进打电话呼叫受限制，请稍后回复',
#  '4月8号联系....',
#  '2013年包商银行按揭 月供2300元有证，万科金色城市。需要10万，说的下午过来。还有一个2018.03按揭车月供5000，农行信用卡按揭的。还有达州信用社3万，招商信用10万，信用卡6.3万招商（招商信用10万），交通3万多。周转用途。无人应答或客户暂时无法接听',
#  '111111111111111111111111',
#  '04/03  有意向  加微信',
#  '18502802139今天已跟进，客户回复明日再跟进',
#  '3.22日跟进........',
#  '5万尽快，个人周转。做生意。刚说完客户就挂电话了。无人应答或客户暂时无法接听无人应答或客户暂时无法接听无人应答或客户暂时无法接听无人应答或客户暂时无法接听',
#  '7.5客户做拼多多的，执照7月份即满一年，都是网上做，只有一个三百多方的仓库，有辆车17万，按揭3千多，一直联系不上客户，操作不了',
#  '3点半来 什么都没有用两三万块钱信用分不到600打电话三无 网贷下款5000跟8000的都没用，70年的，约了两次都没来',
#  '04/03  想贷1w   近期需要  上班开货车的司机  代发6千左右 社保 工作6~7年   全款车11w  2~3年  粤g江门牌   保单4年  年缴8千左右   有的7~8年了  有的忘记了   邀约上门说不想跑，额度也只要1万无人应答或客户暂时无法接听',
#  '1111111111111',
#  '51周岁  需要50万 行唐有个宅基地720平米 有证，  做养殖 服装的 营业执照 ， 信用卡给降额度了  几千就  保单交了四年  年缴1万。明天再联系 想先做宅基地',
#  '7号已经手机沟通了，客户不愿意上门，只想做点点能下款的',
#  '20万，尽快，上班打卡工资有社保，有五险没有一金，微粒贷有2500  点过很多网贷  信用卡25000用了3年   做过阳光杯拒绝了    想养一下征信  再做   可加微信沟通客户有意向，后期及时跟进打电话客户挂断电话，稍后联系无人应答或客户暂时无法接听客户征信不好  暂时先不打电话   杨断时间约来',
#  '5-10w 做工地。、客户有意向，后期及时跟进',
#  '20万，月底，还贷， 上班打卡1.8万 公积金2748           刚来过了，虹口的房子没有备用房，142平米，1200市价，回去和老婆商量再说，负债60万左右老婆都不知道，微信再联系打电话不需要了，以后都不要贷款了',
#  '2万，这个月用，上班，没社保，月交保险500，交了两次费，五年前黑名单，借钱还信用卡，无车无房，老公不可以知道，直接说做不到了剔除商机。原因：客户三无',
#  '4.2号回访客户，工作手机拨打，客户回老家了，还不确定什么时候回来东莞，说回来东莞再联系',
#  '18  02  08在佛山顺德，需要1万，上班转账，每月3500，551分，现在还是一个白户 先发下短信，客户这边想年后在办理    18  02   24客户上门已签单，在佛山顺德，需要1万，上班转账，每月3500，551分，现在还是一个白户，在发廊工作的，本来以为是通过网上转账的，结果是微信转账，97年的，暂时还没办法操作。没有条件       18  02  27办理不了 客户这边自己去申请的平安银行信用卡 已经审批下来 。3月10号 才用到资金    18  11  12拾回跟进一次',
#  '20万个人周转，尽快，五百强单位上班，社保半年左右没有拿卡，打卡工资4-5000，也有交个税，平安保险，但是现在没有交，信用卡当前逾期80多天四张信用卡，约了明天上午十点   白先生，',
#  '04/08   、无人应答或客户暂时无法接听  早打电话04/08   、无人应答或客户暂时无法接听  午打电话04/08   、无人应答或客户暂时无法接听  晚打电话打电话04/09   、无人应答或客户暂时无法接听  早打电话04/09   、无人应答或客户暂时无法接听  午打电话04/09  、无人应答或客户暂时无法接听  晚返无效,原因：联系三个工作日联系不上',
#  '4-5万投资，尽快。 上班1年工资8000-1万打卡，社保1年。邀约客户明天上门，客户说没时间要上班。客户都没有时间过来办理。',
#  '3.22日跟进........剔除商机。原因：信用卡逾期了4500.房子在仁寿，做不了。',
#  '03/22   、客户已经明确表示不需要03/28  说通过啦 过来办理放款手续   有意向   说发地址给他   明天没有时间',
#  '11客户有意向，后期及时跟进',
#  '11、客户有意向，后期及时跟进打电话打电话客户已经明确表示不需要',
#  '5万 上班工资6千，社保4年社保卡没有办理，车老婆名下，高明全款房有证，房贷20万，还了3年，利息3厘多，',
#  '00后 刚满18周岁 自己和哥哥在成都做生意 广东人 维护下吧 有信用卡',
#  '2万，左右，  上班打卡3000不到  公积300多金社保，信用卡有逾期没有，点的网点比较多，周六  微信征信45岁，看看渠道能不能做，再说网贷都是被拒了，做不了打电话只有周末有时间，浦江镇，闵行区，周四确认时间',
#  '3-5w，社保公积金，打卡六千多，明天邀约打电话无人应答或客户暂时无法接听打电话资料问题已经解决  暂时不需要了',
#  '03/27  有意向 在佛山  一会过去今天已跟进，客户回复明日再跟进',
#  '03/21  之前的情况 需要十五万，比较急，自己做生意的，但不是法人，占股80%，13年的执照，顺德的全款房，当时全款价100w，全款车，全款价50w，16年买的，近期没时间，在南沙那边，南沙佛山来回跑，已发广州地址过去。今天已跟进，客户回复明日再跟进',
#  '03/26  报名字就挂    、客户已经明确表示不需要03/26 报名字就挂 、客户已经明确表示不需要',
#  '03/21  之前的情况 需要15万，没有营业执照， 开服装厂， 裸车价18万多， 全款老家牌照， 广西， 年交2万左右， 3分， 交了3，,4年， 下周过来。无人应答或客户暂时无法接听今天已跟进，客户回复明日再跟进',
#  '5k 人在深圳上班的过来广州玩 工资现金 无社保保单微粒贷信用卡 手续费报了2.8-3.6 资金找朋友解决了返无效,原因：其它区域 在深圳上班的',
#  '04/02   客户不需要了',
#  '1111111111111111111111111',
#  '03/28   、无人应答或客户暂时无法接听',
#  '111111111111111111商务签单签单无人应答或客户暂时无法接听',
#  '6月再联系，，，，，，，']

# %%
# re.findall(r"1[0-2]{1}月",'12月8号联系.....')
# re.findall(r"[1-9]{1}月",'004月8号联系.....')
# 将[万|千|w]替换为0000|000|0000
re.findall(r"\d{1,3}多?[万|千|w]|\d{1,3}-\d{1,3}多?[万|千|w]",'保单年缴5-6千')
# Out:
# ['5-6千']

# %%
# 匹配工资
# re.findall(r"发现金[0-9][万|千]|税后收入打卡工资[0-9][万|千]",'打卡工资发现金2万')
# re.findall(r"发现金[0-9][万|千]|收入打卡工资[一|二|三|四|五|六|七|八|九][万|千]",'打卡工资发现金2万')
ret = re.findall(r".{0,10}\d+多?[万|千|w|K].{0,10}|.{0,10}\d+-\d+多?[万|千|w|K].{0,10}",'客户每个月发现金时15号，8-9千') # 税后工资七八千 流水一个月一两百万
print(ret)
if len(ret) > 0:
    sub_ret = re.findall(r"代发|流水|发现金|税后|收入|打卡|工资",ret[0])
    print(sub_ret)
# Out:
# ['个月发现金时15号，8-9千']
# ['发现金']

# %%
# 匹配负债
re.findall(r"[月供|还]{2}\d+000",'月供4100')

# %%
剔除原因 | 剔除商机   扣分
营业执照10多年
要1万
查征信
手续费报的3-5个点
线上产品1分内客户都接受
4号早上11-12点  3-4点左右
【徐治琴72343078】 替换为 其他商务，其他商务作为外部词库
马灿森102473抢了商机
秦云飞915359587抢了商机
{"保单":"有","商品房":"有","实体店":"有","社保":"有","营业执照":"有","车":"有"}{贷款金额:30万}

# %% [markdown]
# ## 备注分词

# %%
import jieba.analyse
from wordcloud import WordCloud
import jieba

from gensim import corpora, models,similarities
import gensim

import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl



def cut_record_content(content):
    content_S = []
    for i in range(len(content)):
        line = content[i]
        #print(line)
        if isinstance(line,float):
            print('(============)')
            print([])
            print('(============)')
            content_S.append([])
            continue
        current_segment = jieba.lcut(line)

    
        if current_segment != '\r\n':
            content_S.append(current_segment)
    return content_S

contents = cut_record_content(contents)
contents
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow_gpu\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.610 seconds.
# Prefix dict has been built succesfully.
# [['打电话',
#   '打电话',
#   '简阳',
#   '做生意',
#   '，',
#   '需要',
#   '5',
#   '-',
#   '10',
#   '万',
#   '，',
#   '加微信',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '在',
#   '忙',
#   '，',
#   '后续',
#   '跟进',
#   '。',
#   '。',
#   '。'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '（',
#   '暂时',
#   '）',
#   '打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '不要'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打',
#   '不通',
#   '，',
#   '打',
#   '不通',
#   '，',
#   '打',
#   '不通',
#   '。'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '在',
#   '上班'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '微信加',
#   '了',
#   ' ',
#   '客户',
#   '最近',
#   '补办',
#   '了',
#   '银行卡',
#   ' ',
#   '之前',
#   '的',
#   '流水',
#   '都',
#   '没有',
#   '了',
#   ' ',
#   '这个',
#   '月',
#   '开始',
#   '存',
#   ' ',
#   '三个',
#   '月',
#   '之后',
#   '再',
#   '过来',
#   '贷',
#   ' ',
#   '一直',
#   '跟进',
#   '微信加',
#   '了',
#   ' ',
#   '客户',
#   '最近',
#   '补办',
#   '了',
#   '银行卡',
#   ' ',
#   '之前',
#   '的',
#   '流水',
#   '都',
#   '没有',
#   '了',
#   ' ',
#   '这个',
#   '月',
#   '开始',
#   '存',
#   ' ',
#   '三个',
#   '月',
#   '之后',
#   '再',
#   '过来',
#   '贷',
#   ' ',
#   '一直',
#   '跟进',
#   '微信加',
#   '了',
#   ' ',
#   '客户',
#   '最近',
#   '补办',
#   '了',
#   '银行卡',
#   ' ',
#   '之前',
#   '的',
#   '流水',
#   '都',
#   '没有',
#   '了',
#   ' ',
#   '这个',
#   '月',
#   '开始',
#   '存',
#   ' ',
#   '三个',
#   '月',
#   '之后',
#   '再',
#   '过来',
#   '贷',
#   ' ',
#   '一直',
#   '跟进'],
#  ['打电话', '打电话', '打电话', '打电话', '无人', '应答', '或', '客户', '暂时', '无法', '接听', '3.27'],
#  ['打电话', '拾回', '自', '跟进', '目前', '不', '在', '武汉', '，', '回', '武汉', '了', '联系'],
#  ['中午', '过来', '。', '。', '。', '。', '。', '已经', '邀请', '。'],
#  ['打电话', '打电话', '修改', '商机', '信息'],
#  ['打电话',
#   '打电话',
#   '关机',
#   '了',
#   '啊',
#   '...........................',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '忙',
#   '，',
#   '没有',
#   '时间',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['李辉霞',
#   '930225359',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['打电话',
#   '打电话',
#   '公机',
#   '打通',
#   '了',
#   '，',
#   '客服',
#   '名义',
#   '，',
#   '3.19',
#   '号',
#   '就',
#   '已经',
#   '在',
#   '公司',
#   '办',
#   '下来',
#   '了',
#   '（',
#   '融资',
#   '）'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '是',
#   '甘孜',
#   '的',
#   '...................',
#   '返',
#   '无效',
#   ',',
#   '原因',
#   '：',
#   '客户',
#   '是',
#   '甘孜',
#   '的',
#   '...................',
#   '、',
#   '其它',
#   '区域'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '联系',
#   '客户',
#   '，',
#   '回复',
#   '请勿',
#   '骚扰'],
#  ['打电话', '打电话', '现在', '不', '需要', '了', '。', '。', '。', '。', '。'],
#  ['没接', '................................'],
#  ['修改',
#   '商机',
#   '信息',
#   '打电话',
#   '打电话',
#   '客户',
#   '说',
#   ' ',
#   '国企',
#   ' ',
#   '有房',
#   '有车',
#   ' ',
#   '想贷',
#   '10',
#   '几万',
#   ' ',
#   '只是',
#   '暂时',
#   '没有',
#   '想',
#   '好',
#   '打电话',
#   '打电话',
#   '客户',
#   '说',
#   ' ',
#   '国企',
#   ' ',
#   '有房',
#   '有车',
#   ' ',
#   '想贷',
#   '10',
#   '几万',
#   ' ',
#   '直接',
#   '说',
#   '暂时',
#   '不',
#   '需要',
#   '的',
#   '打电话',
#   '打电话',
#   '修改',
#   '商机',
#   '信息',
#   '国企',
#   ' ',
#   '有房',
#   '有车',
#   ' ',
#   ' ',
#   ' ',
#   '不',
#   '知道',
#   '什么',
#   '情况',
#   '就',
#   '直接',
#   '说',
#   '不',
#   '需要',
#   '了'],
#  ['打电话', '打电话', '客户', '已经', '明确', '表示', '不', '需要', '二抵', '短信', '..........'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '无人',
#   '接听'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打卡',
#   '2000',
#   '左右',
#   '，',
#   '社保',
#   '好几年',
#   '了',
#   '，',
#   '爱人',
#   '名下',
#   '有车',
#   '。',
#   '想用',
#   '35',
#   '万',
#   '打电话'],
#  ['拾回', '自', '跟进', '姓雷', ' ', '车贷', ' ', '呆账', '一年', '多', ' ', '.....'],
#  ['唐振',
#   '101486',
#   '抢',
#   '了',
#   '商机',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '打电话',
#   '打电话',
#   '上班',
#   '打卡',
#   '工资',
#   '有',
#   '4000',
#   '多',
#   '，',
#   '需要',
#   '2000',
#   '左右'],
#  ['打电话',
#   '打电话',
#   '暂时',
#   '不',
#   '需要',
#   '贷款',
#   '了',
#   '，',
#   '后期',
#   '在',
#   '说',
#   '吧',
#   '。',
#   '打电话',
#   '打电话'],
#  ['拾回',
#   '自',
#   '跟进',
#   '今日',
#   '已',
#   '跟进',
#   '，',
#   '下次',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话', '打电话', '剔除', '商机', '。', '原因', '：', '通了', '就', '挂', '了'],
#  ['客户',
#   '想',
#   '贷款',
#   '，',
#   '不想',
#   '加微信',
#   '，',
#   '后期',
#   '跟踪',
#   '，',
#   '晚点',
#   '打',
#   '手机',
#   '给',
#   '客户',
#   '打',
#   '的',
#   '，',
#   '没人接',
#   '打电话',
#   '客户',
#   '资质',
#   '不错',
#   '，',
#   '但是',
#   '不',
#   '需要',
#   '，',
#   '说',
#   '以后',
#   '也',
#   '不',
#   '需要',
#   '，',
#   '不用',
#   '联系',
#   '他',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['来',
#   '了',
#   '公司',
#   '，',
#   '三无',
#   '，',
#   '坐',
#   '不了',
#   '，',
#   '让',
#   '他',
#   '走',
#   '了',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '征信',
#   '黑名单',
#   '、',
#   '客户',
#   '三无'],
#  ['711', ' ', ' ', ' ', ' ', 'zhy180726'],
#  ['打电话', '客户', '暂时', '没有', '贷款', '意向', '。'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '沟通',
#   '不了',
#   ' ',
#   '挂',
#   '了',
#   '无数次'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '加上',
#   '了',
#   '微信',
#   '，',
#   '可能',
#   '有点',
#   '机会',
#   '，',
#   '跟进',
#   '下',
#   '看',
#   '微信',
#   '上',
#   '又',
#   '跟',
#   '我',
#   '说',
#   '不用',
#   '了',
#   '的'],
#  ['打电话',
#   '返',
#   '无效',
#   ',',
#   '原因',
#   '：',
#   '其它',
#   '区域',
#   ' ',
#   ' ',
#   '客户',
#   '是',
#   '荆州',
#   '的',
#   ' ',
#   ' ',
#   '没',
#   '在',
#   '武汉',
#   '生活',
#   '过',
#   ' ',
#   ' ',
#   ' ',
#   '在',
#   '湖南',
#   '长沙',
#   '做生意',
#   ' ',
#   ' ',
#   ' ',
#   '有',
#   '荆州',
#   '的',
#   '房子',
#   ' ',
#   ' ',
#   '做不了'],
#  ['空号', '了', '、', '无人', '应答', '或', '客户', '暂时', '无法', '接听'],
#  ['打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '号码',
#   '为',
#   '空号',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '暂时',
#   '无人',
#   '接通',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['打电话', '打电话', '设计', '公司', '.......', '培养'],
#  ['打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '打电话',
#   '客户',
#   '中行',
#   '按揭',
#   '房',
#   ' ',
#   '不要',
#   '资金',
#   '的',
#   '嘛'],
#  ['新增',
#   '商机',
#   '上班',
#   '打卡',
#   '3000',
#   '多点',
#   '，',
#   '有',
#   '社保',
#   '公积金',
#   '，',
#   '扣',
#   '几百块',
#   '钱',
#   '。',
#   '但是',
#   '上班',
#   '在',
#   '蒲江',
#   '，',
#   '要个',
#   '一两万',
#   '，',
#   '一',
#   '听到',
#   '要',
#   '来',
#   '公司',
#   '就',
#   '说',
#   '算了',
#   '。',
#   '360',
#   '上面',
#   '的',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '说',
#   '要',
#   '一千万',
#   '，',
#   '说',
#   '蒲江',
#   '那边',
#   '好几套',
#   '房子'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '客户',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '了',
#   ' ',
#   '也',
#   '没有',
#   '贷过',
#   '款',
#   ' ',
#   ' ',
#   '也',
#   '没有',
#   '过',
#   '网贷',
#   ' ',
#   ' ',
#   ' ',
#   '现在',
#   '在',
#   '忙',
#   ' ',
#   ' ',
#   '不',
#   '方便',
#   '接听电话',
#   ' ',
#   '可以',
#   '加微信',
#   '打电话',
#   '客户',
#   '再次',
#   '明确',
#   '的',
#   '表示',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   '用',
#   '随借',
#   '随',
#   '还',
#   '的',
#   '诱惑',
#   '还是',
#   '成功',
#   '吸引',
#   '了',
#   '一波',
#   '注意力',
#   '隐藏',
#   '客户',
#   '公共',
#   '库',
#   '商机',
#   '0',
#   '条'],
#  ['客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '打电话',
#   '生意',
#   '贷',
#   '不',
#   '考虑',
#   '，',
#   '之前',
#   '备注',
#   '：',
#   '按揭',
#   '房有证',
#   '市值',
#   '300',
#   '万',
#   '，',
#   '欠',
#   '银行',
#   '70',
#   '万',
#   '，',
#   '单价',
#   '34000',
#   '，',
#   '全款',
#   '车',
#   '3',
#   '年',
#   '10',
#   '万公里',
#   '裸车',
#   '37',
#   '万',
#   '奔驰',
#   'C200',
#   '，',
#   '还有',
#   '一个',
#   '按揭',
#   '车',
#   '，',
#   '有',
#   '营业执照',
#   '2',
#   '年',
#   '农业',
#   '免税',
#   '，',
#   '咨询',
#   '先息',
#   '后本',
#   '，'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '停机',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '停机',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '停机',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '停机',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['打电话',
#   '打电话',
#   '听到',
#   '贷款',
#   '就',
#   '挂',
#   '了',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '打电话',
#   '打电话',
#   '接通',
#   '后',
#   '就',
#   '挂断',
#   '了',
#   '~',
#   '~',
#   '~',
#   '~',
#   '~',
#   '~',
#   '~',
#   '~',
#   '~',
#   '~',
#   '~'],
#  ['今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '下次',
#   '用',
#   '手机',
#   '打',
#   '，',
#   '客户',
#   '没',
#   '接电话',
#   '客户',
#   '说',
#   '近期',
#   '不怎么',
#   '考虑',
#   '贷款',
#   '了',
#   '，',
#   '发了',
#   '微信'],
#  ['移交', '商机', '给', '【', '肖如燕', '103159', '】', '，', '原因', '：', '你', '跟'],
#  ['钱家伟',
#   '973547908',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '、',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '再',
#   '打',
#   '不接',
#   ' ',
#   ' ',
#   '加微信',
#   ' ',
#   ' ',
#   '显示',
#   '是',
#   '荆州',
#   ' ',
#   ' ',
#   '也',
#   '没有',
#   '通过',
#   ' ',
#   ' ',
#   '再',
#   '跟进',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '餐饮',
#   '想',
#   '咨询',
#   '小',
#   '程序',
#   '，',
#   '已加',
#   '微信',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话'],
#  ['打电话',
#   '、',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['客户',
#   '不',
#   '确定',
#   '时间',
#   '，',
#   '说',
#   '到时候',
#   '忙',
#   '完',
#   '了',
#   '再',
#   '确定',
#   '，',
#   '车子',
#   '已押证',
#   '了'],
#  ['舒波',
#   '15849234',
#   '抢',
#   '了',
#   '商机',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '返',
#   '无效',
#   ',',
#   '原因',
#   '：',
#   '首次',
#   '联系',
#   '表示',
#   '未',
#   '咨询'],
#  ['打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '，',
#   '还',
#   '未',
#   '介绍',
#   '完',
#   '直接',
#   '挂断',
#   '。'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '说',
#   '现在',
#   '在',
#   '忙',
#   '有',
#   '时间',
#   '在',
#   '给',
#   '客户',
#   '联系',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '年龄',
#   '不',
#   '满足要求',
#   '、',
#   '客户',
#   '三无'],
#  ['打电话', '打电话', '也', '是', '接', '起来', '就', '把', '电话', '挂断', '了', '。'],
#  ['打电话', '打电话', '客户', '现在', '不', '需要', '资金', '了', '！', '！', '！', '！', '！'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '之前',
#   '有',
#   '一笔',
#   '贷款',
#   '一直',
#   '没',
#   '还',
#   ' ',
#   ' ',
#   '应该',
#   '是',
#   '征信',
#   '黑名单',
#   '了',
#   ' ',
#   ' ',
#   ' ',
#   '加微信'],
#  ['李玲',
#   '100870',
#   '抢',
#   '了',
#   '商机',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '不',
#   '听',
#   '介绍',
#   '，',
#   '挂断',
#   '电话',
#   '打电话',
#   '客户',
#   '不',
#   '考虑',
#   '做',
#   '线下',
#   '，',
#   '不',
#   '考虑',
#   '做',
#   '贷款',
#   '。'],
#  ['贺腾芳',
#   '915830772',
#   '抢',
#   '了',
#   '商机',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '做生意',
#   '，',
#   '没有',
#   '执照',
#   '，',
#   '月',
#   '收入',
#   '1',
#   '万左右',
#   '，',
#   '其他',
#   '无',
#   '，',
#   '钱',
#   '不是',
#   '很',
#   '急用',
#   '，',
#   '客户',
#   '在',
#   '白云',
#   '那边',
#   '工作',
#   '，',
#   '要',
#   '清明',
#   '过',
#   '了',
#   '才',
#   '有',
#   '时间',
#   '过来',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '说',
#   '目前',
#   '没有',
#   '在',
#   '广州',
#   '，',
#   '在',
#   '茂名',
#   '那边',
#   '，',
#   '有',
#   '时间',
#   '再说'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '用户',
#   '正',
#   '忙'],
#  ['打电话',
#   '打电话',
#   '需要',
#   '10w',
#   '，',
#   '具体',
#   '时间',
#   '定',
#   '不',
#   '下来',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['陈辅',
#   '剑',
#   '103694',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '没',
#   '工作',
#   '没房',
#   '没车',
#   '没',
#   '社保',
#   '没',
#   '保单',
#   '，',
#   '等',
#   '会',
#   '去',
#   '中山',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无',
#   '，',
#   '啥',
#   '都',
#   '没有'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '11'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '需要',
#   '10',
#   '万',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '房子',
#   ' ',
#   ' ',
#   '全款',
#   '房',
#   ' ',
#   ' ',
#   '金堂',
#   ' ',
#   ' ',
#   ' ',
#   '有证',
#   ' ',
#   ' ',
#   '10',
#   '年',
#   ' ',
#   '左右',
#   '市值',
#   '40',
#   '万',
#   ' ',
#   ' ',
#   ' ',
#   '车子',
#   ' ',
#   ' ',
#   '全款',
#   ' ',
#   '几万',
#   ' ',
#   ' ',
#   ' ',
#   '一年',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '太平',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '3',
#   '千多',
#   ' ',
#   ' ',
#   ' ',
#   '12',
#   '年',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '农商',
#   '银行',
#   ' ',
#   ' ',
#   '贷款',
#   '18',
#   '万',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '2',
#   '年期',
#   '先先息',
#   '后',
#   '商业',
#   ' ',
#   '的',
#   '8',
#   '厘',
#   ' ',
#   ' ',
#   ' ',
#   '上班',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '没有',
#   '营业执照',
#   ' ',
#   ' ',
#   '他',
#   '就是',
#   '咨询',
#   '一下',
#   '这笔',
#   '款',
#   '可贷',
#   '可不',
#   '贷',
#   '，',
#   '带来',
#   '还',
#   '农商',
#   '的',
#   '人',
#   '，',
#   '房产证',
#   '押',
#   '在',
#   '农商',
#   '的',
#   ' ',
#   ' ',
#   ' ',
#   '报',
#   '的',
#   '利息',
#   '最低',
#   '3',
#   '厘多',
#   ' ',
#   ' ',
#   '先息',
#   '后本',
#   '5',
#   '厘',
#   '左右',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '说',
#   '考虑',
#   '看要',
#   '不要',
#   '贷'],
#  ['打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机',
#   '打电话',
#   '这',
#   '两天',
#   '就要',
#   '，',
#   '又',
#   '不',
#   '在',
#   '上海',
#   '，',
#   '什么',
#   '时候',
#   '回来',
#   '也',
#   '说',
#   '不准',
#   '，',
#   '说',
#   '2',
#   '万块',
#   '还要',
#   '面签',
#   '，',
#   '不要',
#   '了',
#   '，',
#   '保单',
#   '年',
#   '4k5',
#   '，',
#   '现在',
#   '没有',
#   '工作',
#   '，',
#   '准备',
#   '开店',
#   '，',
#   '说',
#   '了',
#   '网贷',
#   '利息',
#   '高',
#   '就',
#   '说',
#   '不',
#   '需要',
#   '了',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '不',
#   '需要'],
#  ['打电话', '信用卡', '加微信', '1111', '打电话', '客户', '已经', '明确', '表示', '不', '需要'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '在',
#   '忙',
#   '目前',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   '加',
#   '了',
#   '微信',
#   '后续',
#   '跟进'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '项目',
#   '没谈',
#   '好',
#   ' ',
#   '不好',
#   '操作',
#   ' ',
#   '被',
#   '收购',
#   '了',
#   ' ',
#   '不行',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进'],
#  ['打电话',
#   '打电话',
#   '挂断',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '打电话',
#   '打电话',
#   '说',
#   '现在',
#   '已经',
#   '不',
#   '需要',
#   '了',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。'],
#  ['拾回',
#   '自',
#   '跟进',
#   'ke',
#   '客户',
#   '在',
#   '忙',
#   ' ',
#   ' ',
#   '明天',
#   '回复',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话'],
#  ['拾回',
#   '自',
#   '跟进',
#   '想',
#   '做',
#   '高利贷',
#   '。',
#   '、',
#   '联系',
#   '客户',
#   '，',
#   '回复',
#   '请勿',
#   '骚扰',
#   '商务',
#   '签单',
#   '签单'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '有',
#   '负债',
#   '，',
#   '说',
#   '走',
#   '银行',
#   '渠道',
#   '就',
#   '说',
#   '算了算',
#   '了',
#   '，',
#   '说',
#   '走',
#   '其他',
#   '渠道',
#   '也',
#   '说',
#   '算了'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '还是',
#   '说',
#   '没有',
#   '贷款',
#   '的',
#   '需要',
#   ' ',
#   '下次',
#   '短信',
#   '联系'],
#  ['打电话', '打电话', '说', '不', '需要', '贷款', ' ', ' ', ' ', '说', '按时', '还款'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '客户',
#   '有',
#   '打卡',
#   '社保',
#   '公积金',
#   '，',
#   '两个',
#   '月',
#   '之前',
#   '做过',
#   '太多',
#   '的',
#   '网贷',
#   '下',
#   '的',
#   '不',
#   '多点',
#   '的',
#   '多',
#   '，',
#   '昨天',
#   '去',
#   '别的',
#   '公司',
#   '没有',
#   '做',
#   '下来',
#   '，',
#   '我',
#   '说',
#   '最近',
#   '什么',
#   '贷款',
#   '也',
#   '不要',
#   '做',
#   '，',
#   '养',
#   '两个',
#   '月',
#   '征信',
#   '到时候',
#   '我',
#   '联系',
#   '他',
#   '，',
#   '添加',
#   '微信',
#   '了',
#   '，'],
#  ['打电话',
#   '客户',
#   '不',
#   '需要',
#   '了',
#   '，',
#   '使用',
#   '时间',
#   '待定',
#   '，',
#   '预约',
#   '时间',
#   '待定',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '近期',
#   '可能',
#   '需要',
#   '，',
#   '让给',
#   '爱人',
#   '打电话',
#   '打电话',
#   '让',
#   '我',
#   '直接',
#   '问',
#   '她',
#   '爱人',
#   '，',
#   '跟进',
#   '中',
#   '商务',
#   '签单',
#   '签单',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进'],
#  ['打电话', '打电话', '打电话', '打电话', '无人', '应答', '或', '客户', '暂时', '无法', '接听', '3.28'],
#  ['打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '号码',
#   '为',
#   '空号',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['拾回', '自', '跟进', '先息', '后本', '信用贷款', '不', '需要'],
#  ['打电话', '在', '考虑一下', '...............'],
#  ['返',
#   '无效',
#   ',',
#   '原因',
#   '：',
#   '客户',
#   '在',
#   '恩施',
#   '，',
#   '三非',
#   '客户',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话', '今天', '已', '跟进', '，', '客户', '回复', '明', '我们', '太慢', '了', '，'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '征信',
#   '黑名单'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '之前',
#   '来过',
#   '我们',
#   '公司',
#   '查询',
#   '太多',
#   '没',
#   '办法',
#   '办理',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '213'],
#  ['想办', '，', '但是', '没有', '他', '能', '做', '的', '渠道', '啊'],
#  ['商务',
#   '签单',
#   '打电话',
#   '查询',
#   '巨多',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '网贷',
#   '都',
#   '没有',
#   '额度',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '叫',
#   '他',
#   '养下',
#   '征信',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '6',
#   '月份',
#   '左右',
#   '在',
#   '办',
#   '打电话',
#   '朋友',
#   '还',
#   '在',
#   '考虑',
#   '...........',
#   '考虑',
#   '啥子',
#   '嘛',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '又',
#   '不',
#   '说',
#   '签单',
#   '同',
#   '客户',
#   '商机',
#   '成单',
#   '掉',
#   '库',
#   '打电话',
#   '叫',
#   '他',
#   '去',
#   '查下',
#   '征信',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '看看',
#   '几月份',
#   '的',
#   '查询',
#   '比较',
#   '多'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无',
#   ' ',
#   ' ',
#   '同行'],
#  ['打电话', '打电话', '问候', '客户', '...............'],
#  ['打电话', '打电话', '已', '关机', '.........'],
#  ['4', '月', '8', '号', '联系', '.....'],
#  ['打电话',
#   '打电话',
#   '贷',
#   '2',
#   '万',
#   '，',
#   '高',
#   '先生',
#   '，',
#   '公积金',
#   '交',
#   '400',
#   '，',
#   '8',
#   '年',
#   '，',
#   '去',
#   '江苏',
#   '了',
#   '，',
#   '两天',
#   '后',
#   '回来',
#   '，',
#   '加微信',
#   '。',
#   '打电话',
#   '打电话',
#   '告知',
#   '初审',
#   '通过',
#   '，',
#   '直接',
#   '邀约',
#   '打电话',
#   '下午',
#   '两点',
#   '过来',
#   '....',
#   '已',
#   '上门',
#   '签单',
#   '，',
#   '做小贷',
#   '.',
#   '打电话',
#   '让',
#   '客户',
#   '下周一',
#   '去',
#   '普罗',
#   '办理',
#   '明天',
#   '去',
#   '普罗',
#   '办理',
#   '...'],
#  ['打电话',
#   '客户',
#   '说',
#   ' ',
#   '噢',
#   '不',
#   '需要',
#   '，',
#   '谢谢',
#   '。',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '客户',
#   '在',
#   '杭州',
#   '，',
#   '最近',
#   '没',
#   '资金',
#   '需求',
#   '。',
#   '打电话',
#   '打电话',
#   '客户',
#   '比较忙',
#   '，',
#   '过',
#   '两个',
#   '小时',
#   '再',
#   '联系',
#   '。',
#   '跟进',
#   '中',
#   '。'],
#  ['打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机',
#   '打电话',
#   '贷款',
#   '5',
#   '万',
#   '，',
#   '上班',
#   '，',
#   '有',
#   '社保',
#   '公积金',
#   '，',
#   '工资',
#   '3500',
#   '，',
#   '客户',
#   '这',
#   '两天',
#   '有事',
#   '，',
#   '下周一',
#   '休息',
#   '，',
#   '发短信',
#   '，',
#   '约',
#   '下周一',
#   '上门',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '，',
#   '手机',
#   '联系',
#   '拒接',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '修改',
#   '商机',
#   '信息'],
#  ['打电话',
#   '打电话',
#   '广州',
#   '上班',
#   '2',
#   '年代',
#   '发',
#   '5',
#   '千到',
#   '7',
#   '千',
#   '，',
#   '社保',
#   '个',
#   '缴',
#   '380',
#   ' ',
#   '，',
#   '不',
#   '知道',
#   '公积金',
#   '，',
#   '无',
#   '资产',
#   '，',
#   '有',
#   '100',
#   '医疗保险',
#   '家里',
#   '的',
#   '，',
#   '之前',
#   '开店',
#   '有',
#   '执照',
#   '以',
#   '注销',
#   '，',
#   '想贷',
#   '10',
#   '开店',
#   ' ',
#   '4',
#   '月',
#   '联系'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '之前',
#   '办理',
#   '过',
#   '没有',
#   '通过',
#   '，',
#   '现在',
#   '在',
#   '忙',
#   '没有',
#   '空',
#   '，',
#   '说',
#   '下午',
#   '2',
#   '点',
#   '再',
#   '联系',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['部门经理',
#   '分配',
#   '商机',
#   '给',
#   '【',
#   '梁少形',
#   '102825',
#   '】',
#   '部门经理',
#   '分配',
#   '商机',
#   '给',
#   '【',
#   '黄国英',
#   '978062838',
#   '】'],
#  ['无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   ' ',
#   '、',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   ' ',
#   '、',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '客户',
#   '还是',
#   '有',
#   '需求',
#   '，',
#   '下午',
#   '再',
#   '给',
#   '客户',
#   '打电话',
#   '。',
#   '客户',
#   '在',
#   '忙'],
#  ['打电话', '打电话', '常年', '在', '外地', '。', '目前', '不', '需要', '。'],
#  ['杨青',
#   '101025',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打卡',
#   '8000',
#   '左右',
#   '，',
#   '以为',
#   '是',
#   '网贷',
#   '，',
#   '线下',
#   '考虑一下',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '五月份',
#   '要',
#   ' ',
#   '先加',
#   '微信',
#   '，',
#   '，',
#   '打电话',
#   '23',
#   '，',
#   '24',
#   '号',
#   '联系',
#   ' ',
#   '，',
#   '要',
#   '20',
#   '万'],
#  ['拾回',
#   '自',
#   '跟进',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话'],
#  ['打电话',
#   '打电话',
#   '未接',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '发了',
#   '微信',
#   ' ',
#   ' ',
#   '还',
#   '没回',
#   '我',
#   ' ',
#   ' ',
#   '哎',
#   ' ',
#   ' ',
#   ' ',
#   '计划',
#   '建',
#   '的',
#   '不',
#   '准确',
#   '。',
#   '。',
#   '。',
#   '。',
#   '打电话',
#   '打电话',
#   '微信',
#   '联系',
#   '说',
#   ' ',
#   '现在',
#   '资金周转',
#   '过来',
#   '了',
#   ' ',
#   ' ',
#   ' ',
#   '现在',
#   '不',
#   '需要',
#   '了',
#   ' ',
#   ' ',
#   ' ',
#   '后期',
#   '慢慢',
#   '维护',
#   '打电话',
#   '打电话',
#   '未接',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，',
#   '，'],
#  ['打电话', '打电话', '拾回', '自', '跟进', '暂时', '不', '需要', '，', '微信', '跟进', '维护', '。'],
#  ['客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['打电话', '打电话', '客户', '不', '需要', ' ', ' ', '下次', '联系', '一下'],
#  ['打电话', '客户', '说', '是', '没有', '办理', '下来'],
#  ['拾回', '自', '跟进', '打电话', '打电话', '剔除', '商机', '。', '原因', '：', '号码', '不', '准确'],
#  ['客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '暂时',
#   '无法',
#   '接通',
#   '电话',
#   '啊',
#   '在',
#   '联系',
#   ' ',
#   '看看',
#   '打电话',
#   '打电话',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进'],
#  ['移交', '商机', '给', '【', '梁伟平', '100098', '】', '，', '原因', '：', '移交'],
#  ['新增', '商机', '人工', '分配', '商机', '给', '【', '张敏', '101748', '】'],
#  ['打电话',
#   '需要',
#   '1',
#   '万',
#   '，',
#   '时间',
#   '不定',
#   '。',
#   '上班',
#   '在',
#   '东西',
#   '湖',
#   '5',
#   '千',
#   '的',
#   '工资',
#   '，',
#   '孝感',
#   '按揭',
#   '房月',
#   '还',
#   '1600',
#   '，',
#   '还',
#   '了',
#   '8',
#   '年',
#   '，',
#   '按揭',
#   '在',
#   '中国银行',
#   '。',
#   '让',
#   '周末',
#   '再',
#   '联系'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '生病',
#   '了',
#   ' ',
#   '、',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '征信',
#   '黑名单',
#   '、',
#   '号码',
#   '打',
#   '不通'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '周五',
#   '打',
#   '确认',
#   '电话',
#   '，',
#   '周日',
#   '上午',
#   '过来'],
#  ['分配',
#   '商机',
#   '到',
#   '部门',
#   '【',
#   '成都',
#   '融资',
#   '直营',
#   '中心',
#   '商务',
#   '二十三',
#   '部',
#   '】',
#   '分配',
#   '商机',
#   '到',
#   '部门',
#   '【',
#   '成都',
#   '融资',
#   '直营',
#   '中心',
#   '商务',
#   '九部',
#   '】'],
#  ['打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '不是',
#   '本人',
#   '操作',
#   '的'],
#  ['今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进'],
#  ['打电话',
#   '他',
#   '说',
#   '自己',
#   '有',
#   '呆账',
#   ' ',
#   '，',
#   '十年',
#   '前',
#   '的',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '忙',
#   ' ',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   ' ',
#   '搞完',
#   '跟',
#   '我',
#   '联系',
#   '打电话',
#   '打电话',
#   '、',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '联系',
#   '客户',
#   '，',
#   '回复',
#   '请勿',
#   '骚扰',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   '微信',
#   '删',
#   '了',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、',
#   '、'],
#  ['打电话',
#   '客户',
#   '表示',
#   '不',
#   '需要',
#   '，',
#   '客户',
#   '上班',
#   '现金',
#   '工资',
#   '有',
#   '社保',
#   '公积金',
#   '，',
#   '微粒',
#   '贷',
#   '四五千',
#   '信用卡',
#   '两万',
#   '八无',
#   '逾期',
#   '，',
#   '无房',
#   '无车',
#   '无',
#   '保单',
#   '、',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '打电话',
#   '现在',
#   '不',
#   '需要',
#   '了',
#   '现在',
#   '不',
#   '需要',
#   '了',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '现在',
#   '不',
#   '需要',
#   '了'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '没',
#   '接电话',
#   '，',
#   '后面',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '没',
#   '接电话',
#   '，',
#   '继续',
#   '跟进',
#   '哦'],
#  ['分配', '商机', '到', '部门', '【', '北京', '融资', '自创', '四部', '】'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '未接',
#   ' ',
#   ' ',
#   '持续',
#   '跟进',
#   ' ',
#   '维护',
#   ' ',
#   '未接',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '找',
#   '私人',
#   '解决',
#   '了',
#   ' ',
#   ' ',
#   '哎',
#   ' ',
#   ' ',
#   '维护',
#   '即可',
#   ' ',
#   '小',
#   '客户'],
#  ['打电话', '今天', '已', '跟进', '，', '客户', '回复', '在', '忙'],
#  ['打电话', '这个', '月', '暂时', '不用', ' ', ' ', '加微信', ' ', '后期', '聊'],
#  ['打电话', '让', '加微信', '，', '说', '微信加', '了', '细聊', '拾回', '自', '跟进'],
#  ['罗',
#   '彩虹',
#   '37201096',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '需要',
#   '5',
#   '万',
#   '，',
#   '明天',
#   '才',
#   '去',
#   '应聘',
#   '的',
#   '，',
#   '无',
#   '微粒',
#   '贷',
#   '，',
#   '老家',
#   '自建房',
#   '，',
#   '有辆',
#   '二手车',
#   '，',
#   '月',
#   '供',
#   '一千多',
#   '，',
#   '供',
#   '了',
#   '一年',
#   '多',
#   '，',
#   '湖南',
#   '牌',
#   '，',
#   '客户',
#   '在',
#   '东莞',
#   '的',
#   '，',
#   '不是',
#   '广州',
#   '的'],
#  ['拾回', '自', '跟进', '打电话', '客户', '在', '上班', '，', '不', '方便', '接电话'],
#  ['打电话',
#   '有',
#   '按揭',
#   '房',
#   '，',
#   '按揭',
#   '20',
#   '年',
#   '，',
#   '每月',
#   '还款',
#   '6',
#   '千多',
#   '，',
#   '已',
#   '还款',
#   '2',
#   '年',
#   '多',
#   '，',
#   '想贷',
#   '100',
#   '万',
#   '没接',
#   '拾回',
#   '自',
#   '跟进'],
#  ['打电话',
#   '打电话',
#   '这',
#   '两天',
#   '比较忙',
#   ' ',
#   ' ',
#   '下周一',
#   ' ',
#   '说',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '加上',
#   '微信',
#   '了',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '现在',
#   '在',
#   '国外',
#   '呢',
#   '，',
#   '说加',
#   '我',
#   '微信',
#   '在',
#   '微信',
#   '上',
#   '聊',
#   '和',
#   '客户',
#   '在',
#   '微信',
#   '上',
#   '沟通',
#   '，',
#   '预计',
#   '周',
#   '5',
#   '中午',
#   '左右',
#   '客户',
#   '能',
#   '到',
#   '门店',
#   '，',
#   '用',
#   '80',
#   '万'],
#  ['打电话',
#   '打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '还',
#   '没',
#   '中标',
#   ' ',
#   '中标',
#   '了',
#   '就要',
#   ' ',
#   '还要',
#   '等',
#   '几天',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '有氧',
#   ' ',
#   ' ',
#   ' ',
#   '星期一',
#   '来',
#   '、',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['于',
#   '超航',
#   '102042',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '工作',
#   '手机',
#   '打是',
#   '通话',
#   '中',
#   '的',
#   '通话',
#   '应该',
#   '是',
#   '设置',
#   '的',
#   '了',
#   '啊',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '号码',
#   '为',
#   '无法',
#   '接通'],
#  ['打电话',
#   '去',
#   '电',
#   '无法',
#   '接通',
#   ' ',
#   '没有',
#   '沟通',
#   '上',
#   ' ',
#   '周一',
#   '再',
#   '联系',
#   '打电话',
#   '客户',
#   '明显',
#   '表示',
#   '不',
#   '需要',
#   '了',
#   ' ',
#   '资金',
#   '解决',
#   '了'],
#  ['刘中艳',
#   '101941',
#   '抢',
#   '了',
#   '商机',
#   '待',
#   '回复',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '打电话',
#   '打电话',
#   '客户',
#   '需要',
#   '五万',
#   '，',
#   '上班',
#   '现金',
#   '工资',
#   '6K',
#   '左右',
#   '，',
#   '有',
#   '社保',
#   '，',
#   '其他',
#   '无',
#   '，',
#   '芝麻',
#   '分',
#   '643',
#   '，',
#   '约',
#   '在',
#   '下午',
#   '过来'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话', '打电话', '剔除', '商机', '。', '原因', '：', '听', '着', '贷款', '就', '挂', '了'],
#  ['打电话',
#   '加微信',
#   '，',
#   '可能',
#   '2',
#   '年',
#   '后',
#   '用',
#   '，',
#   '看看',
#   '朋友',
#   '用',
#   '不用',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '添加',
#   '了',
#   '微信',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！'],
#  ['拾回', '自', '跟进', '打电话', '打电话', '剔除', '商机', '。', '原因', '：', '客户', '三无'],
#  ['打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通',
#   '，',
#   '能',
#   '打',
#   '，',
#   '但是',
#   '客户',
#   '不接',
#   '，',
#   '挂机'],
#  ['打电话', '打电话', '今天', '这边', '就', '、', '客户', '已经', '明确', '表示', '不', '需要'],
#  ['打电话', '客户', '挂断', '电话', '，', '没', '听懂', '客户', '说', '什么'],
#  ['打电话',
#   '去年',
#   '弄',
#   '过',
#   '，',
#   '嫌弃',
#   '麻烦',
#   '，',
#   '说要',
#   '面审',
#   '，',
#   '又',
#   '要',
#   '电话',
#   '的',
#   '，',
#   '\t',
#   '5',
#   '万',
#   '，',
#   '上班',
#   '部分',
#   '打卡',
#   '，',
#   '部分',
#   '现金',
#   '，',
#   '情况',
#   '还',
#   '没',
#   '了解',
#   '呢',
#   '上来',
#   '就',
#   '问',
#   '利息',
#   '，',
#   '又',
#   '问要',
#   '什么',
#   '资料',
#   '打电话',
#   '老是',
#   '没空',
#   '啊',
#   '，',
#   '去年',
#   '弄',
#   '过',
#   '，',
#   '嫌弃',
#   '麻烦',
#   '，',
#   '说要',
#   '面审',
#   '，',
#   '又',
#   '要',
#   '电话',
#   '的',
#   '，',
#   '\t',
#   '5',
#   '万',
#   '，',
#   '上班',
#   '部分',
#   '打卡',
#   '，',
#   '部分',
#   '现金',
#   '，',
#   '情况',
#   '还',
#   '没',
#   '了解',
#   '呢',
#   '上来',
#   '就',
#   '问',
#   '利息',
#   '，',
#   '又',
#   '问要',
#   '什么',
#   '资料',
#   '打电话',
#   '打电话',
#   '打电话',
#   '不',
#   '需要',
#   '，',
#   '老是',
#   '没空',
#   '啊',
#   '，',
#   '去年',
#   '弄',
#   '过',
#   '，',
#   '嫌弃',
#   '麻烦',
#   '，',
#   '说要',
#   '面审',
#   '，',
#   '又',
#   '要',
#   '电话',
#   '的',
#   '，',
#   '\t',
#   '5',
#   '万',
#   '，',
#   '上班',
#   '部分',
#   '打卡',
#   '，',
#   '部分',
#   '现金',
#   '，',
#   '情况',
#   '还',
#   '没',
#   '了解',
#   '呢',
#   '上来',
#   '就',
#   '问',
#   '利息',
#   '，',
#   '又',
#   '问要',
#   '什么',
#   '资料'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '未',
#   '接听电话',
#   '，',
#   '这些',
#   '人',
#   '啥',
#   '毛病',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['袁小茹', '93065894', '抢', '了', '商机', '稍后', '联系'],
#  ['问',
#   '了',
#   '几句',
#   ' ',
#   '就',
#   '说',
#   '暂时',
#   '不',
#   '需要',
#   '。',
#   '。',
#   '。',
#   '。',
#   '打电话',
#   '打电话',
#   '无人',
#   '接听',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '、',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无'],
#  ['打电话',
#   '刘婷',
#   '给',
#   '客户',
#   '回访',
#   '的',
#   '，',
#   '客户',
#   '说',
#   '自己',
#   '在',
#   '招行',
#   '的',
#   '什么',
#   '贷',
#   '搞',
#   '了',
#   '10',
#   '万',
#   '，',
#   '装修',
#   '贷',
#   '6.2',
#   '万',
#   '，',
#   '中信',
#   '搞',
#   '了',
#   '20',
#   '万',
#   '，',
#   '是',
#   '买',
#   '单位',
#   '分',
#   '的',
#   '福利',
#   '房',
#   '，',
#   '第一次',
#   '说',
#   '是',
#   '侄儿',
#   '开',
#   '公司',
#   '投资',
#   '，',
#   '这个',
#   '贷款',
#   '也',
#   '都',
#   '是',
#   '自己',
#   '找',
#   '银行',
#   '搞',
#   '得',
#   '，',
#   '客户',
#   '不想',
#   '找',
#   '中介',
#   '，',
#   '说',
#   '中介',
#   '还要',
#   '收费',
#   '用',
#   '，',
#   '哎',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '报完',
#   '家门',
#   '直接',
#   '挂',
#   '电话',
#   '；',
#   '了',
#   '，',
#   '，',
#   '，'],
#  ['打电话',
#   '打电话',
#   '要',
#   '清明节',
#   '之后',
#   '才',
#   '会',
#   '回',
#   '长沙',
#   '，',
#   '这',
#   '几天',
#   '在',
#   '外地',
#   '，',
#   '在',
#   '忙',
#   '突然',
#   '挂断',
#   '，',
#   '下次',
#   '电话',
#   '定个',
#   '预约',
#   '时间',
#   '打电话',
#   '客户',
#   '比较',
#   '敷衍',
#   '，',
#   '说',
#   '月底',
#   '才',
#   '会',
#   '回来',
#   '，',
#   '不太想',
#   '过来'],
#  ['移交', '商机', '给', '【', '刘长英', '1133950', '】', '，', '原因', '：', '移交'],
#  ['杜猛',
#   '926317569',
#   '抢',
#   '了',
#   '商机',
#   '马上',
#   '打',
#   '马上',
#   '打',
#   '马上',
#   '打',
#   '马上',
#   '打',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '做生意',
#   '，',
#   '需要',
#   '2',
#   '万',
#   '，',
#   '流水',
#   '1',
#   '万',
#   '，',
#   '信用卡',
#   '有',
#   '，',
#   '芝麻',
#   '分',
#   '600',
#   '多分',
#   '，',
#   '时间',
#   '还',
#   '不',
#   '确定',
#   '打电话',
#   '打电话'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '号码',
#   '通话',
#   '中'],
#  ['打电话',
#   '打电话',
#   '拒接',
#   '11111111111111',
#   '打电话',
#   '打电话',
#   '就',
#   '这',
#   '段时间',
#   '要钱',
#   '，',
#   '说',
#   '还',
#   '不',
#   '了解',
#   '，',
#   '邀约',
#   '了',
#   '啥时候',
#   '过来',
#   '先',
#   '了解',
#   '，',
#   '发短信',
#   '打电话',
#   '打电话',
#   '说',
#   '你们',
#   '利息',
#   '太高',
#   '了',
#   '，',
#   '强调',
#   '了',
#   '利息',
#   '四',
#   '里',
#   '，',
#   '费用',
#   '2000',
#   '左右',
#   '，',
#   '考虑',
#   '下',
#   '，',
#   '感觉',
#   '是',
#   '个',
#   '水货'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '现在',
#   ' ',
#   '在',
#   '忙',
#   ' ',
#   ' ',
#   '等会儿',
#   '回',
#   '电话',
#   '..'],
#  ['打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['打电话',
#   '现在',
#   '在',
#   '有事',
#   '，',
#   '晚点',
#   '联系',
#   '打电话',
#   '未接',
#   '，',
#   '又',
#   '说',
#   '不',
#   '需要',
#   '了',
#   '，',
#   '再',
#   '联系',
#   '联系',
#   '吧',
#   '未接',
#   '，',
#   '又',
#   '说',
#   '不',
#   '需要',
#   '了',
#   '，',
#   '再',
#   '联系',
#   '联系',
#   '吧',
#   '打电话',
#   '未接',
#   '，',
#   '又',
#   '说',
#   '不',
#   '需要',
#   '了',
#   '，',
#   '再',
#   '联系',
#   '联系',
#   '吧'],
#  ['打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机',
#   '打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '不',
#   '需要'],
#  ['蒋',
#   '欢欢',
#   '89426428',
#   '抢',
#   '了',
#   '商机',
#   '移交',
#   '商机',
#   '给',
#   '【',
#   '刘志营',
#   '101927',
#   '】',
#   '，',
#   '原因',
#   '：',
#   '移交',
#   '移交',
#   '商机',
#   '给',
#   '【',
#   '孙欣',
#   '948267774',
#   '】',
#   '，',
#   '原因',
#   '：',
#   '签单',
#   '下单',
#   '写单'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '客户',
#   '对',
#   '客服',
#   '人员',
#   '不',
#   '满意',
#   '，',
#   '收费',
#   '高',
#   '打电话',
#   '打电话',
#   '客户',
#   '现在',
#   '在',
#   '外地',
#   '的',
#   '，',
#   '收费',
#   '高',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['打电话',
#   '打电话',
#   '今日',
#   '已',
#   '跟进',
#   '，',
#   '已',
#   '签单',
#   '，',
#   '联系',
#   '后台',
#   '进件',
#   '，',
#   '通知',
#   '客户',
#   '所',
#   '需',
#   '资料'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话'],
#  ['马灿森',
#   '102473',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '打电话',
#   '客户',
#   '做',
#   '养殖',
#   '生意',
#   '的',
#   '，',
#   '没',
#   '营业执照',
#   '，',
#   '银行',
#   '流水',
#   '才',
#   '1',
#   '~',
#   '2',
#   '万',
#   '，',
#   '有',
#   '全款',
#   '房',
#   '，',
#   '问',
#   '到',
#   '一半',
#   '就',
#   '拒接',
#   '了',
#   '，',
#   '明',
#   '继续',
#   '跟进',
#   '。',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '三无',
#   '、',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '客户',
#   '三无',
#   '、',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无'],
#  ['说',
#   '的',
#   '四月',
#   '初',
#   '需要',
#   '资金',
#   '说',
#   '的',
#   '四月',
#   '初',
#   '需要',
#   '资金',
#   '打电话',
#   '打电话',
#   '未接',
#   '未接',
#   '未接',
#   '未接',
#   '未接',
#   '未接',
#   '打电话',
#   '打电话',
#   '座机',
#   '不接',
#   '，',
#   '手机',
#   '联系',
#   '了',
#   '，',
#   '下个星期',
#   '联系',
#   '，',
#   '现在',
#   '在',
#   '外面',
#   '手机',
#   '联系',
#   '了',
#   '，',
#   '说',
#   '的',
#   '节后',
#   '过来',
#   '办理',
#   '打电话',
#   '打电话',
#   '等',
#   '会',
#   '晚点',
#   '手机',
#   '联系',
#   '154515',
#   '座机',
#   '不接',
#   '手机',
#   '联系',
#   '了',
#   '，',
#   '说',
#   '星期四',
#   '过来',
#   '、',
#   '手机',
#   '联系',
#   '没有',
#   '接',
#   ' ',
#   '，',
#   '晚点',
#   '联系',
#   '两个',
#   '手机',
#   '都',
#   '不接',
#   '，',
#   ' ',
#   '明天',
#   '联系',
#   '了'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['打电话', '打电话', '现在', '不', '需要', '了', ' ', ' ', ' ', '继续', '根基', '客户'],
#  ['打电话',
#   '客户',
#   '去',
#   '了',
#   '很多',
#   '家',
#   '都',
#   '说',
#   '做不了',
#   '。',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '征信',
#   '黑名单'],
#  ['打电话', '客户', '信用卡', '当前', '逾期', '10', '万有', '2', '年', '了'],
#  ['打电话',
#   '再',
#   '添加',
#   '一次',
#   '客户',
#   '微信',
#   ' ',
#   '到',
#   '时',
#   '微信',
#   '联系',
#   '我',
#   '喔',
#   '这边',
#   '告知',
#   '客户',
#   '情况',
#   '初审',
#   '通过'],
#  ['打电话', '拾回', '自', '跟进', '客户', '表示', '资金', '已经', '解决', '，', '目前', '不', '需要'],
#  ['打电话', '打电话', '不', '想到', '成都', '来', ' ', ' ', '在', '大邑县'],
#  ['无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   ' ',
#   '接挂',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要'],
#  ['打电话',
#   '打电话',
#   '4',
#   '-',
#   '5',
#   '千',
#   '收入',
#   ' ',
#   '1900',
#   '+',
#   '打卡',
#   ' ',
#   '公积金',
#   '单边',
#   '缴',
#   '245',
#   ' ',
#   '有',
#   '需求',
#   ' ',
#   '微信',
#   '联系',
#   '打电话',
#   '打电话',
#   '暂定',
#   '3.29',
#   '号',
#   ' ',
#   '下午',
#   '上门',
#   '办理',
#   ' ',
#   ' ',
#   '28',
#   '号',
#   '再',
#   '联系',
#   '确定',
#   '时间',
#   '商务',
#   '签单',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '签单'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '脾气',
#   '很',
#   '暴躁',
#   '。',
#   '骂人',
#   '，',
#   '，'],
#  ['移交', '商机', '给', '【', '樊晓铭', '2102231', '】', '，', '原因', '：', '移交'],
#  ['打电话', '打电话', '暂时', '不', '需要', ' ', ' ', '后面', '再说', '吧'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '修改',
#   '商机',
#   '信息',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['新增',
#   '商机',
#   '近期',
#   '比较忙',
#   '，',
#   '没有',
#   '时间',
#   '过来',
#   '，',
#   '大概',
#   '6',
#   '月份',
#   '才',
#   '有',
#   '时间',
#   '过来'],
#  ['打电话',
#   '刚',
#   '接听',
#   '后',
#   '客户',
#   '就',
#   '挂断',
#   '电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '表明',
#   '身份',
#   '后',
#   '客户',
#   '挂断',
#   '电话'],
#  ['打电话',
#   '打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '需要',
#   '几千块',
#   '，',
#   '上班',
#   '，',
#   '2',
#   '千多',
#   '，',
#   '有',
#   '社保',
#   '公积金',
#   '。',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '不',
#   '需要'],
#  ['打电话', '话', '没', '说完', ' ', '挂', '++++++'],
#  ['郑恒',
#   '98419826',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '打电话',
#   '返',
#   '无效',
#   ',',
#   '原因',
#   '：',
#   '首次',
#   '联系',
#   '表示',
#   '未',
#   '咨询'],
#  ['打电话',
#   '需要',
#   '1',
#   '-',
#   '2',
#   '万',
#   ' ',
#   ' ',
#   '上班',
#   '发现',
#   '金',
#   ' ',
#   '芝麻',
#   '分',
#   '670',
#   ' ',
#   '无',
#   '信用卡',
#   '，',
#   '约',
#   '明天',
#   '说',
#   '看',
#   '情况',
#   '、',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无'],
#  ['程波',
#   '28755839',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '客户',
#   '要',
#   '2',
#   '万',
#   '，',
#   '上班',
#   '半年',
#   '左右',
#   '，',
#   '月',
#   '收入',
#   '1',
#   '万',
#   '，',
#   '现金',
#   '工资',
#   '，',
#   '没有',
#   '社保',
#   '公积金',
#   '，',
#   '名下',
#   '没有',
#   '房',
#   '没有',
#   '保单',
#   '，',
#   '但是',
#   '有',
#   '一台',
#   '货车',
#   '价值',
#   '不详',
#   '，',
#   '无',
#   '微粒',
#   '贷',
#   '，',
#   '以前',
#   '有点',
#   '过',
#   '网贷',
#   '放款',
#   '大概',
#   '2',
#   '万左右',
#   '，',
#   '虽然',
#   '没有',
#   '条件',
#   '但是',
#   '也',
#   '邀约',
#   '今天',
#   '过来',
#   '办理',
#   '，',
#   '现在',
#   '暂时',
#   '不',
#   '确定',
#   '时间',
#   '也',
#   '不',
#   '确定',
#   '能',
#   '不能',
#   '过来',
#   '，',
#   '加微信',
#   '跟进',
#   '。'],
#  ['打电话',
#   '说',
#   '有',
#   '需要',
#   ' ',
#   ' ',
#   '说',
#   '没',
#   '时间',
#   '过来',
#   '办理',
#   ' ',
#   ' ',
#   '然后',
#   '刚问',
#   '保单',
#   '就',
#   '挂',
#   '了',
#   ' ',
#   ' ',
#   '后期',
#   '再',
#   '跟',
#   '拾回',
#   '自',
#   '跟进',
#   '有',
#   '需要',
#   ' ',
#   ' ',
#   '换',
#   '一个',
#   '人',
#   '跟',
#   ' ',
#   '、',
#   '、',
#   '、',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机',
#   '打电话',
#   '11',
#   '听到',
#   '贷款',
#   '挂断',
#   '电话'],
#  ['事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
#   '拨打',
#   '后',
#   '隐藏',
#   '事业部',
#   '库',
# ...
#   '五个',
#   '点',
#   '。',
#   '客户',
#   '现在',
#   '已经',
#   '不接',
#   '我',
#   '的',
#   '电话',
#   '了',
#   '。'],
#  ['拾回', '自', '跟进', '也', '是', '报', '身份', '就', '挂', '了', '的', '啊'],
#  ['邓霖',
#   '101860',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '客户',
#   '需要',
#   '30',
#   '万',
#   ' ',
#   '什么',
#   '都',
#   '没有',
#   ' ',
#   '后期',
#   '开发',
#   '跟进'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '说',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   '挂断',
#   '电话',
#   ' ',
#   '继续',
#   '跟进',
#   '客户'],
#  ['打电话',
#   '打电话',
#   'dia',
#   '、',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '客户',
#   '告知',
#   '要',
#   '4',
#   '月初',
#   '在',
#   '需要',
#   '资金',
#   '办理',
#   '的',
#   '嘛'],
#  ['拾回', '自', '跟进', '拨打', '电话', '提示', '号码', '为', '空号'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '告诉',
#   '我',
#   '现在',
#   '没空',
#   ' ',
#   ' ',
#   ' ',
#   '就',
#   '给',
#   '我',
#   '挂',
#   '了',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '日常',
#   '备注',
#   '一下',
#   ' ',
#   ' ',
#   ' ',
#   '防止',
#   '调库',
#   ' ',
#   ' ',
#   '明天',
#   '跟进',
#   '日常',
#   '备注',
#   '一下',
#   ' ',
#   '防止',
#   '调库',
#   ' ',
#   '明天',
#   '跟进',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '打电话',
#   '推荐',
#   '0.33',
#   '的',
#   '信用贷款',
#   '，',
#   '客户',
#   '这边',
#   '不',
#   '需要',
#   '资金',
#   '祝福',
#   '短信',
#   '.............'],
#  ['打电话', '可能', '要', '四月', '中下旬', '才', '有', '时间'],
#  ['给',
#   '客户',
#   '发微信',
#   '就',
#   '可以',
#   '了',
#   '哦',
#   '给',
#   '客户',
#   '发微信',
#   '就',
#   '可以',
#   '了',
#   '哦'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '电话',
#   '未',
#   '接通',
#   '。',
#   '下午',
#   '联系',
#   '打电话',
#   '未',
#   '接通',
#   '............',
#   '呼入',
#   '限制'],
#  ['胡锦泓',
#   '103459',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '首次',
#   '拨打',
#   '，',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '再',
#   '联系',
#   '第二次',
#   '拨打',
#   '，',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '再',
#   '联系',
#   '打电话',
#   '打电话',
#   '第三次',
#   '拨打',
#   '，',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '在',
#   '保持联系',
#   '打电话',
#   '拨打',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '再',
#   '联系',
#   '打电话',
#   '拨打',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '再',
#   '联系',
#   '，',
#   '下次',
#   '用',
#   '手机',
#   '拨打',
#   '打电话',
#   '拨打',
#   '的',
#   '号码',
#   '暂无',
#   '接听',
#   '，',
#   '在',
#   '保持联系'],
#  ['拾回', '自', '跟进', '剔除', '商机', '。', '原因', '：', '客户', '不要', '了'],
#  ['拾回',
#   '自',
#   '跟进',
#   '上班',
#   '，',
#   '打卡',
#   '6000',
#   '，',
#   '公积金',
#   '1200',
#   '，',
#   '社保',
#   '1200',
#   '，',
#   '有过',
#   '两三次',
#   '逾期'],
#  ['手机', '打', '5', '年期', '先息', '后本', '，', '不', '需要'],
#  ['打电话',
#   '打电话',
#   '他',
#   '说',
#   '他',
#   '也',
#   '是',
#   '搞',
#   '贷款',
#   '的',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['谭罗旭',
#   '102085',
#   '抢',
#   '了',
#   '商机',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打',
#   '了',
#   '两次',
#   '电话',
#   '都',
#   '是',
#   '未接',
#   '状态',
#   '打电话',
#   '打电话',
#   '昨天',
#   '请假',
#   '，',
#   '由',
#   '同事',
#   '王玉',
#   '萧',
#   '联系',
#   '不',
#   '需要',
#   '了',
#   '。',
#   '资金',
#   '回流',
#   '。',
#   '可',
#   '查',
#   '录音',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['工手',
#   ' ',
#   '不接',
#   ' ',
#   '上海',
#   '的',
#   '号码',
#   ' ',
#   '、',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '打电话',
#   '打电话',
#   '成都',
#   '上班',
#   '的',
#   '，',
#   '之前',
#   '贷款',
#   '买房',
#   '，',
#   '说',
#   '买',
#   '了',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   ' ',
#   '回访',
#   ' ',
#   '挂断'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '已',
#   '上门',
#   '没',
#   '签单',
#   '、',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进'],
#  ['03',
#   '/',
#   '28',
#   ' ',
#   ' ',
#   '有',
#   '意向',
#   ' ',
#   ' ',
#   '加微信',
#   ' ',
#   '约',
#   '下周',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['新增',
#   '商机',
#   '打电话',
#   '打电话',
#   '客户',
#   '青白江',
#   '按揭',
#   '房',
#   '，',
#   '有证',
#   '，',
#   '现在',
#   '信用卡',
#   '当前',
#   '逾期',
#   '几万',
#   '哟',
#   '，',
#   '想贷',
#   '20',
#   '万',
#   '打电话',
#   '打电话',
#   '在',
#   '忙',
#   '办',
#   '出入境',
#   '证',
#   '，',
#   '说',
#   '等',
#   '下',
#   '联系',
#   '我',
#   '打电话',
#   '打电话',
#   '还是',
#   '准备',
#   '卖房子',
#   '，',
#   '卖',
#   '了',
#   '依',
#   '其他人',
#   '名义',
#   '去',
#   '新',
#   '都',
#   '买'],
#  ['打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '不',
#   '说话',
#   ' ',
#   ' ',
#   '不',
#   '吱声',
#   '啊',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '啊啊啊',
#   '啊',
#   '啊'],
#  ['打电话', '客户', '挂断', '电话', '，', '稍后', '联系', '拾回', '自', '跟进'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '客户',
#   '有',
#   '意向',
#   '近期',
#   '不',
#   '需要',
#   '，',
#   '后期',
#   '及时',
#   '跟进'],
#  ['打电话',
#   '做',
#   '工程',
#   '，',
#   '现在',
#   '不',
#   '考虑',
#   '资金',
#   '贷款',
#   '这方面',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['打电话',
#   '打电话',
#   '说',
#   '的',
#   '是',
#   '当时',
#   '身份证',
#   '消磁',
#   '了',
#   '没办',
#   '下来',
#   '。',
#   '。',
#   '。',
#   '。',
#   '现在',
#   '没有',
#   '需求'],
#  ['返',
#   '无效',
#   '商机',
#   '审核',
#   '通过',
#   '。',
#   '原因',
#   '：',
#   '"',
#   '返',
#   '无效',
#   '成功',
#   '，',
#   '客户',
#   '表示',
#   '未',
#   '咨询',
#   '。',
#   '\r\n',
#   '"'],
#  ['客户',
#   '已',
#   '退单',
#   '，',
#   '再',
#   '沟通',
#   '其他',
#   '渠道',
#   '，',
#   '客户',
#   '再',
#   '考虑',
#   '下',
#   '商务',
#   '签单'],
#  ['打电话',
#   '表示',
#   '服务满意',
#   '，',
#   '询问',
#   '什么',
#   '原因',
#   '没有',
#   '下办',
#   '下来',
#   '，',
#   '客户',
#   '不',
#   '愿意',
#   '透露',
#   '，',
#   '后期',
#   '再',
#   '联系'],
#  ['打电话',
#   '客户',
#   '说',
#   '反正',
#   '是',
#   '不会',
#   '来',
#   '公司',
#   '的',
#   '打电话',
#   '打电话',
#   '客户',
#   '接',
#   '了',
#   '，',
#   '听不见',
#   '声音',
#   '打电话',
#   '5',
#   '万',
#   '，',
#   '上班',
#   '，',
#   '客户',
#   '说',
#   '没有',
#   '休息时间',
#   '。'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '目前',
#   '需要',
#   '5',
#   '万',
#   '，',
#   '这',
#   '几天',
#   '要',
#   '，',
#   '在',
#   '佛山',
#   '那边',
#   '上班',
#   '，',
#   '税后',
#   '工资',
#   '6k',
#   '，',
#   '没有',
#   '社保',
#   '公积金',
#   '，',
#   '没有',
#   '固定资产',
#   '，',
#   '有点',
#   '不太想',
#   '上门',
#   '，',
#   '继续',
#   '邀约'],
#  ['打电话', '客户', '未', '咨询', '过', '相关', '业务'],
#  ['拾回',
#   '自',
#   '跟进',
#   '上',
#   '一个',
#   '商务',
#   '刚',
#   '跟',
#   '不久',
#   ' ',
#   ' ',
#   '缓缓',
#   '跟',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进'],
#  ['打电话',
#   '说',
#   '在',
#   '别的',
#   '地方',
#   '贷款',
#   '贷',
#   '不了',
#   '，',
#   '我',
#   '说',
#   '我们',
#   '这边',
#   '产品',
#   '比较',
#   '多元化',
#   '，',
#   '他',
#   '在',
#   '阳光',
#   '那边',
#   '办',
#   '，',
#   '大',
#   '数据',
#   '过',
#   '不了',
#   '，',
#   '问',
#   '了',
#   '利息',
#   '和',
#   '手续费',
#   '8877886',
#   '，',
#   '保单',
#   '年缴',
#   '8000',
#   '多',
#   ' ',
#   ' ',
#   '三年',
#   ' ',
#   ' ',
#   ' ',
#   '说明',
#   '上午',
#   '来',
#   '打电话',
#   '说',
#   '上午',
#   '10',
#   '点来',
#   '，',
#   '等',
#   '会',
#   '出发',
#   '、',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '客户',
#   '上门',
#   '未',
#   '签单',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '客户',
#   '大地',
#   '阳光',
#   '都',
#   '被',
#   '拒',
#   '了',
#   ' ',
#   ' ',
#   ' ',
#   '客户',
#   '征信',
#   '查询',
#   '多',
#   ' ',
#   ' ',
#   '只能',
#   '做',
#   '不',
#   '看',
#   '征信',
#   '的',
#   '产品',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '客户',
#   '只能',
#   '做',
#   '不',
#   '看',
#   '查询',
#   '的',
#   '产品',
#   ' ',
#   ' ',
#   ' ',
#   '客户',
#   '表示',
#   '只能',
#   '接受',
#   '1.2',
#   '以下',
#   '的',
#   '利息',
#   ' ',
#   ' ',
#   ' ',
#   '汪志华',
#   '帮忙',
#   '压单',
#   ' ',
#   ' ',
#   ' ',
#   '还是',
#   '接受',
#   '不了',
#   '利息',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '年龄',
#   '不',
#   '满足要求'],
#  ['打电话',
#   '打电话',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   ' ',
#   '后期',
#   '有',
#   '需要',
#   '联系',
#   '。',
#   '。',
#   '。',
#   '。'],
#  ['打电话', '打电话', '客户', '说', '现在', '没', '得', '资金', '需要', '的', '哈', '。'],
#  ['打电话',
#   '打电话',
#   '客户',
#   '说',
#   '之前',
#   '是',
#   '找',
#   '朋友',
#   '借',
#   '的',
#   '，',
#   '已经',
#   '解决',
#   '了',
#   '，',
#   '暂时',
#   '不',
#   '需要',
#   '，'],
#  ['打电话', '打电话', '不', '需要', '了', '谢谢', '啊', '，', '发短信'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '现在',
#   '暂时',
#   '不',
#   '需要',
#   '，',
#   '以后',
#   '有',
#   '需要',
#   '，',
#   '维护',
#   '着'],
#  ['打电话', '打电话', '客户', '说', '回去', '问', '一下', '公司', '需不需要', '资金周转'],
#  ['打电话',
#   '客户',
#   '现在',
#   '不',
#   '在',
#   '北京',
#   ' ',
#   '等',
#   '回来',
#   '北京',
#   '安排',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话',
#   '打电话',
#   '说',
#   '不',
#   '回',
#   '北京',
#   '啦',
#   ' ',
#   ' ',
#   '不要',
#   '啦',
#   ' ',
#   ' ',
#   '、',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['打电话',
#   '打电话',
#   '说',
#   '现在',
#   '暂时',
#   '不',
#   '需要',
#   '，',
#   '喊加',
#   '微信',
#   '，',
#   '说',
#   '下个月',
#   '有',
#   '可能',
#   '需要'],
#  ['打电话',
#   '、',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '最近',
#   '比较忙',
#   '，',
#   '给',
#   '不了',
#   '确切',
#   '时间',
#   '，',
#   '有',
#   '时间',
#   '就',
#   '联系',
#   '我'],
#  ['打电话', '打电话', '打电话', '通话', '中', '。', '。', '。', '。', '。', '。', '。'],
#  ['打电话',
#   '打电话',
#   '联系',
#   '客户',
#   '，',
#   '在',
#   '西昌',
#   '工地',
#   '上',
#   '没',
#   '时间',
#   '的',
#   '打电话',
#   '打电话',
#   '联系',
#   '客户',
#   '，',
#   '回复',
#   '没',
#   '得',
#   '时间',
#   '来',
#   '办理',
#   '，',
#   '西昌',
#   '那边'],
#  ['打电话',
#   '客户',
#   '直接',
#   '说',
#   '不',
#   '需要',
#   '了',
#   '的',
#   ' ',
#   ' ',
#   ' ',
#   '挂断',
#   '了',
#   '电话',
#   '了',
#   '的',
#   '。'],
#  ['打电话',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '下午',
#   '过来',
#   '联系',
#   '我',
#   '打电话',
#   '打电话',
#   '客户',
#   '说',
#   '自己',
#   '这周',
#   '很',
#   '忙',
#   '，',
#   '加他',
#   '微信',
#   '，',
#   '过来',
#   '之前',
#   '联系',
#   '我',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '客户',
#   '自己',
#   '在',
#   '平安',
#   '普惠',
#   '撸',
#   '了',
#   '5',
#   '万',
#   '额度',
#   '，',
#   '（',
#   '跟',
#   '客户',
#   '报',
#   '了',
#   '银行利息',
#   '，',
#   '加微信',
#   '跟进',
#   '）'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['客户',
#   '暂时',
#   '不',
#   '需要',
#   '了',
#   '，',
#   '需要',
#   '联系',
#   '打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '暂时',
#   '不',
#   '需要',
#   '了',
#   '，',
#   '有',
#   '需要',
#   '联系',
#   '，',
#   '加微信',
#   '了',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '工程款',
#   '收不到',
#   ' ',
#   ' ',
#   '不',
#   '需要',
#   '钱',
#   '了',
#   '，',
#   '不',
#   '准备',
#   '做',
#   '工程',
#   '了',
#   '，',
#   '，',
#   '现在',
#   '就',
#   '等',
#   '收',
#   '工程款'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '直接',
#   '说',
#   '了',
#   '贷款',
#   '开头',
#   '就',
#   '给',
#   '我',
#   '挂',
#   '了',
#   ' ',
#   ' ',
#   '下次',
#   '需要',
#   '换',
#   '开守',
#   '了'],
#  ['打电话',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '号码',
#   '打',
#   '不通',
#   '打电话'],
#  ['杨林',
#   '25192378',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话', '客户', '暂时', '不', '需要', '，', '直接', '挂断', '，', '跟进', '中', '。'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '未接',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。'],
#  ['手机', '拨号', '，', '客户', '未', '接电话'],
#  ['拾',
#   '回转',
#   '介绍',
#   '修改',
#   '商机',
#   '人工',
#   '分配',
#   '商机',
#   '给',
#   '【',
#   '郭健',
#   '102268',
#   '】'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '打算',
#   '用',
#   '50',
#   '万',
#   '买房',
#   ' ',
#   ' ',
#   '上班',
#   ' ',
#   '工资',
#   '打卡',
#   ' ',
#   '社保',
#   '2000',
#   '多',
#   ' ',
#   ' ',
#   '公积金',
#   '2000',
#   ' ',
#   '添加',
#   '微信',
#   ' ',
#   ' ',
#   '发送',
#   '公司地址',
#   ' ',
#   '过来',
#   '联系',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   ' ',
#   ' ',
#   '客户',
#   '在',
#   '开会',
#   '已',
#   '发短信',
#   '打电话',
#   '打电话',
#   '添加',
#   '客户',
#   '微信',
#   ' ',
#   ' ',
#   '没有',
#   '通过',
#   ' ',
#   '和',
#   '客户',
#   '在',
#   '说',
#   '添加',
#   ' ',
#   '发送',
#   '位置',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '现在',
#   '在',
#   '开车',
#   ' ',
#   '继续',
#   '跟进',
#   '客户',
#   '打电话',
#   '继续',
#   '很近',
#   '客户',
#   '不',
#   '需要',
#   '资金',
#   ' ',
#   '继续',
#   '跟进',
#   '客户',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '客户',
#   '有',
#   '意向',
#   ' ',
#   '说',
#   '过',
#   '几天',
#   '来',
#   ' ',
#   '已经',
#   '加',
#   '了',
#   '微信'],
#  ['打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '移交',
#   '商机',
#   '给',
#   '【',
#   '谷宇佳',
#   '104049',
#   '】',
#   '，',
#   '原因',
#   '：',
#   '长期',
#   '未',
#   '跟进'],
#  ['打电话', '说', '我们', '八厘多', '简直', '是', '高利贷'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '今天',
#   '已',
#   '跟进',
#   '，',
#   '客户',
#   '回复',
#   '明日',
#   '再',
#   '跟进',
#   '打电话',
#   '打电话',
#   '拨打',
#   '电话',
#   '提示',
#   '客户',
#   '已',
#   '关机'],
#  ['打电话',
#   '夏',
#   '女士',
#   '，',
#   '20',
#   '万',
#   '，',
#   '做生意',
#   '，',
#   '占股',
#   '30%',
#   '，',
#   '一年',
#   '半',
#   '，',
#   '年收入',
#   '50',
#   '万',
#   '，',
#   '本地',
#   '户口',
#   '，',
#   '房子',
#   '父亲',
#   '名下',
#   '，',
#   '最近',
#   '3',
#   '个',
#   '月',
#   '7.8',
#   '万',
#   '流水',
#   '，',
#   '无',
#   '社保',
#   '公积金',
#   '，',
#   '无',
#   '保单',
#   '微粒',
#   '贷',
#   '打电话',
#   '不',
#   '需要',
#   '了',
#   '，',
#   '20',
#   '万',
#   '，',
#   '做生意',
#   '，',
#   '占股',
#   '30%',
#   '，',
#   '一年',
#   '半',
#   '，',
#   '年收入',
#   '50',
#   '万',
#   '，',
#   '本地',
#   '户口',
#   '，',
#   '房子',
#   '父亲',
#   '名下',
#   '，',
#   '最近',
#   '3',
#   '个',
#   '月',
#   '7.8',
#   '万',
#   '流水',
#   '，',
#   '无',
#   '社保',
#   '公积金',
#   '，',
#   '无',
#   '保单',
#   '微粒',
#   '贷'],
#  ['宋科军',
#   '102100',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '1W',
#   '，',
#   '刚到',
#   '餐饮店',
#   '上班',
#   '，',
#   '不到',
#   '一个月',
#   '，',
#   '没有',
#   '其他',
#   '条件',
#   '，',
#   '无',
#   '方案',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '三无'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '平安',
#   '保单',
#   '年交',
#   '900',
#   '.',
#   '。',
#   '，',
#   '，',
#   '。',
#   '。',
#   '，',
#   '。',
#   '，',
#   '。',
#   '剔除',
#   '商机',
#   '。',
#   '原因',
#   '：',
#   '客户',
#   '征信',
#   '黑名单'],
#  ['工作',
#   '手机',
#   '联系',
#   '，',
#   '推荐',
#   '0.33',
#   '的',
#   '信用贷款',
#   '，',
#   '客户',
#   '这边',
#   '暂时',
#   '不',
#   '考虑',
#   '。',
#   '二抵',
#   '短信',
#   '..............'],
#  ['梁蜜',
#   '102338',
#   '抢',
#   '了',
#   '商机',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '挂断',
#   '电话',
#   '，',
#   '稍后',
#   '联系',
#   '打电话'],
#  ['手机', '联系', '，', '客户', '拒接', '.'],
#  ['拾回',
#   '自',
#   '跟进',
#   '客户',
#   '有',
#   '意向',
#   '，',
#   '后期',
#   '及时',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话'],
#  ['打电话',
#   '打电话',
#   '资金',
#   '家里',
#   '解决',
#   '了',
#   '，',
#   '后期',
#   '可能',
#   '不太',
#   '需要',
#   '了',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。',
#   '。'],
#  ['打电话',
#   '拾回',
#   '自',
#   '跟进',
#   '番禺',
#   '上班',
#   '，',
#   '社保',
#   '公积金',
#   '买',
#   '最低',
#   '，',
#   '代发',
#   '三四千',
#   '，',
#   '电镀',
#   '版',
#   '公司',
#   '上班',
#   '七八年',
#   '，',
#   '微粒',
#   '贷',
#   '3',
#   '万',
#   '，',
#   '负债',
#   '6',
#   '万多',
#   '，',
#   '需求',
#   '5',
#   '万左右',
#   '打电话',
#   '打电话'],
#  ['拾回',
#   '自',
#   '跟进',
#   '上门',
#   '签过',
#   '单',
#   '了',
#   '，',
#   '但',
#   '没有',
#   '批下去',
#   '，',
#   '什么',
#   '原因',
#   '不',
#   '了解',
#   '，',
#   '跟进',
#   '一下',
#   '看看',
#   '打电话',
#   '无人',
#   '应答',
#   '或',
#   '客户',
#   '暂时',
#   '无法',
#   '接听'],
#  ['打电话',
#   '打电话',
#   '短信',
#   '按揭',
#   '昂',
#   '信用贷款',
#   '的',
#   '随借',
#   '随',
#   '还',
#   'v',
#   '再',
#   '不',
#   '需要',
#   '打电话',
#   '打电话',
#   '未接',
#   '为',
#   '未接',
#   '54545151514'],
#  ['拾回',
#   '自',
#   '跟进',
#   '打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '已经',
#   '明确',
#   '表示',
#   '不',
#   '需要',
#   ' ',
#   ' ',
#   '态度',
#   '还是',
#   '挺不错',
#   '的'],
#  ['打电话',
#   '打电话',
#   '打电话',
#   '打电话',
#   '客户',
#   '要',
#   '两万块',
#   '钱',
#   '，',
#   '打电话',
#   '一直',
#   '拖',
#   '一直',
#   '拖',
#   '，',
#   '现在',
#   '又',
#   '说',
#   '下个月',
#   '要',
#   '，',
#   '月初',
#   '在',
#   '联系',
#   '一下',
#   '。',
#   '打电话',
#   '打电话',
#   '客户',
#   '说',
#   '是',
#   '明天',
#   '上午',
#   '十点',
#   '，',
#   '上门',
#   '。',
#   '打电话',
#   '打电话',
#   '客户',
#   '说',
#   '的',
#   '是',
#   '上午',
#   '有事',
#   '，',
#   '换',
#   '到',
#   '下午',
#   '两点',
#   '。',
#   '商务',
#   '签单'],
#  ...]

# %%
def dosegment_all(sentence):
    '''
    带词性标注，对句子进行分词，不排除停词等
    :param sentence:输入字符
    :return:
    '''
    sentence_seged = jieba.posseg.cut(sentence.strip())
    outstr = ''
    for x in sentence_seged:
        outstr+="{}/{},".format(x.word,x.flag)
    #上面的for循环可以用python递推式构造生成器完成
    # outstr = ",".join([("%s/%s" %(x.word,x.flag)) for x in sentence_seged])
    return outstr
if '没','无' in line:# 新词发现 如 没有资金  不需要  不想要等等
    dosegment_all('打电话现在没有资金缺口、客户已经明确表示不需要')
# Out:
# '打电话/l,现在/t,没有/v,资金/n,缺口/n,、/x,客户/n,已经/d,明确/ad,表示/v,不/d,需要/v,'

# %%
360 同金额中过滤
要一千万 作为异常值过滤
手续费高
利息高

# %% [markdown]
# ## 停用词处理

# %%
stopwords=pd.read_csv("stopwords.txt",index_col=False,sep="\t",quoting=3,names=['stopword'], encoding='utf-8')
stopwords = stopwords.stopword.values.tolist()
print(len(stopwords))
# Out:
# 1516

# %%
def drop_stopwords(contents,stopwords):
    contents_clean = []
    all_words = []
    for line in contents:
        line_clean = []
        for word in line:
            word = word.strip()
            if len(word) == 0:
                continue
            if word in stopwords:
                continue
            line_clean.append(word)
            all_words.append(str(word))
        contents_clean.append(line_clean)
    return contents_clean,all_words

contents_clean,all_words = drop_stopwords(contents,stopwords)

# %% [markdown]
# ## 做词云图

# %%
df_allWords = pd.DataFrame({'all_words':all_words})
allWords_count = df_allWords.groupby(by=['all_words'])['all_words'].agg({'count':np.size})
print(allWords_count['all_words'].values.tolist())
print(allWords_count.head())
allWords_count = allWords_count.reset_index().sort_values(by = ['count'],ascending=False)
print(allWords_count.shape)
allWords_count.head()
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow_gpu\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#            count
# all_words
# !           1609
# %             14
# %%%            1
# %%%%           1
# ++            28
# (22006, 2)
#       all_words   count
# 12850       打电话  313561
# 10782        客户  163305
# 13206        拨打   93334
# 21340        隐藏   86759
# 11566         库   86651

# %%
wordcloud2 = WordCloud(font_path='simhei.ttf',background_color='white',max_font_size = 80)
word_frequence = {x[0]:x[1] for x in allWords_count.head(100).values}
wordcloud3 = wordcloud2.fit_words(word_frequence)
mpl.rcParams['figure.figsize'] = (30.0, 15.0) # set default size of plots
plt.imshow(wordcloud3)

# %%
from PIL import Image
from wordcloud import ImageColorGenerator

alice_coloring = np.array(Image.open(r"D:\360安全浏览器下载\business.png"))
wordcloud2 = WordCloud(font_path='simhei.ttf',background_color="white", max_words=2000, mask=alice_coloring, max_font_size=80, random_state=42)
wordcloud3 = wordcloud2.fit_words(word_frequence)
plt.axis("off") # 去掉坐标轴
# 在只设置mask的情况下,你将会得到一个拥有图片形状的词云
plt.imshow(wordcloud3, interpolation="bilinear")

# %%
plt.figure()
image_colors = ImageColorGenerator(alice_coloring)
plt.axis("off")
# recolor wordcloud and show
# we could also give color_func=image_colors directly in the constructor
# 我们还可以直接在构造函数中直接给颜色
# 通过这种方式词云将会按照给定的图片颜色布局生成字体颜色策略
plt.imshow(wordcloud2.recolor(color_func=image_colors), interpolation="bilinear")
